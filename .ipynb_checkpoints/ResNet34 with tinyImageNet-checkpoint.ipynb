# %% [markdown]
# The dataset Tiny ImageNet has to be in the 'data/' folder

# %% [markdown]
# Instruction to download and extract the data:
#
# wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
#
# unzip tiny-imagenet-200.zip
#
# rm tiny-imagenet-200.zip

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
from tensorflow.python.client import device_lib
def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]
print(get_available_devices()) 

import os
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# ['/device:CPU:0', '/device:GPU:0']

# %% [markdown]
# # 0. Loading the data

# %% [markdown]
# ### TinyImageNet does not have labels for the testing data. We will use the 10k validation images for the testing data.

# %%
#Generate dataset
from utils.tiny_imageNet import labels_order
###### TRAINING DATA #######
#Load Training images and labels
train_directory = "./data/tiny-imagenet-200/train" 
image_list=[]
label_list=[]

label_dic=labels_order() #convert label str to int from 0 



for l,sub_dir in enumerate(os.listdir(train_directory)):
    if not sub_dir in label_dic:
        label_dic[sub_dir]=l
    sub_dir_name=os.path.join(train_directory,sub_dir,'images')
    n=0
    for file in os.listdir(sub_dir_name):
        filename = os.fsdecode(file)
        if filename.endswith(".JPEG")  or filename.endswith(".jpg") or filename.endswith(".png"):
            img=np.array(Image.open(os.path.join(sub_dir_name,file)))
            if(img.shape == (64, 64, 3)): #removing images without 3 channels
                image_list.append(img)
                label_list.append(int(label_dic[sub_dir]))
                n+=1
    print(n,'pictures in folder',sub_dir,sep=' ' )
            
X_tot=np.array(image_list)
y_tot=np.array(label_list)

###### TEST DATA #######

#getting the labels from the txt file
df = pd.read_table('./data/tiny-imagenet-200/val/val_annotations.txt', header=None)
test_labels={} 
for index, row in df.iterrows():
    test_labels[str(row[0])]= row[1]


test_directory = "./data/tiny-imagenet-200/val/images" 

test_image_list=[]
test_label_list=[]

for file in os.listdir(test_directory):
    filename = os.fsdecode(file)
  
    if filename.endswith(".JPEG")  or filename.endswith(".jpg") or filename.endswith(".png"):
        img=np.array(Image.open(os.path.join(test_directory,file)))
        if(img.shape == (64, 64, 3)): #removing images without 3 channels
            test_image_list.append(img)
            test_label_list.append(label_dic[test_labels[filename]])
            
X_test=np.array(test_image_list)
y_test=tf.keras.utils.to_categorical(np.array(test_label_list))
# Out:
# 497 pictures in folder n03617480
# 499 pictures in folder n09332890
# 499 pictures in folder n01917289
# 497 pictures in folder n04398044
# 496 pictures in folder n03977966
# 491 pictures in folder n04486054
# 485 pictures in folder n02481823
# 499 pictures in folder n01910747
# 500 pictures in folder n01443537
# 495 pictures in folder n02823428
# 497 pictures in folder n04254777
# 487 pictures in folder n03837869
# 500 pictures in folder n07695742
# 493 pictures in folder n03983396
# 500 pictures in folder n04597913
# 495 pictures in folder n02395406
# 500 pictures in folder n02132136
# 492 pictures in folder n04259630
# 500 pictures in folder n02279972
# 493 pictures in folder n04371430
# 500 pictures in folder n03980874
# 454 pictures in folder n03763968
# 499 pictures in folder n07768694
# 497 pictures in folder n02948072
# 497 pictures in folder n02231487
# 497 pictures in folder n02206856
# 494 pictures in folder n09428293
# 498 pictures in folder n03100240
# 473 pictures in folder n04532670
# 495 pictures in folder n01944390
# 495 pictures in folder n02099712
# 491 pictures in folder n03733131
# 500 pictures in folder n07579787
# 500 pictures in folder n01983481
# 499 pictures in folder n02415577
# 500 pictures in folder n03662601
# 496 pictures in folder n01698640
# 497 pictures in folder n01774384
# 465 pictures in folder n04356056
# 466 pictures in folder n03388043
# 481 pictures in folder n03599486
# 485 pictures in folder n04399382
# 495 pictures in folder n02233338
# 480 pictures in folder n03404251
# 498 pictures in folder n04251144
# 491 pictures in folder n02808440
# 485 pictures in folder n02814860
# 498 pictures in folder n02058221
# 491 pictures in folder n02906734
# 471 pictures in folder n04376876
# 498 pictures in folder n03796401
# 499 pictures in folder n03089624
# 473 pictures in folder n03891332
# 500 pictures in folder n09256479
# 495 pictures in folder n04070727
# 490 pictures in folder n03970156
# 494 pictures in folder n02815834
# 498 pictures in folder n04456115
# 480 pictures in folder n03126707
# 483 pictures in folder n03160309
# 500 pictures in folder n02730930
# 480 pictures in folder n04023962
# 491 pictures in folder n02113799
# 496 pictures in folder n03706229
# 477 pictures in folder n04507155
# 500 pictures in folder n07734744
# 500 pictures in folder n02226429
# 500 pictures in folder n01984695
# 497 pictures in folder n02125311
# 489 pictures in folder n03584254
# 500 pictures in folder n01950731
# 499 pictures in folder n02268443
# 496 pictures in folder n03444034
# 496 pictures in folder n02364673
# 473 pictures in folder n04366367
# 500 pictures in folder n07875152
# 498 pictures in folder n02074367
# 497 pictures in folder n03014705
# 494 pictures in folder n03854065
# 497 pictures in folder n02699494
# 494 pictures in folder n09193705
# 484 pictures in folder n04275548
# 494 pictures in folder n03042490
# 485 pictures in folder n04008634
# 496 pictures in folder n12267677
# 479 pictures in folder n03255030
# 500 pictures in folder n07583066
# 467 pictures in folder n03930313
# 492 pictures in folder n04560804
# 494 pictures in folder n02099601
# 479 pictures in folder n04074963
# 499 pictures in folder n04118538
# 500 pictures in folder n07614500
# 494 pictures in folder n02988304
# 500 pictures in folder n01629819
# 498 pictures in folder n01855672
# 495 pictures in folder n02486410
# 498 pictures in folder n01644900
# 473 pictures in folder n04311004
# 474 pictures in folder n02837789
# 500 pictures in folder n07747607
# 486 pictures in folder n02843684
# 488 pictures in folder n03937543
# 494 pictures in folder n02410509
# 481 pictures in folder n04067472
# 500 pictures in folder n01641577
# 500 pictures in folder n07873807
# 496 pictures in folder n03355925
# 492 pictures in folder n02123394
# 497 pictures in folder n01945685
# 497 pictures in folder n02802426
# 453 pictures in folder n02791270
# 498 pictures in folder n02769748
# 500 pictures in folder n02963159
# 499 pictures in folder n01742172
# 474 pictures in folder n04179913
# 497 pictures in folder n02927161
# 493 pictures in folder n02977058
# 485 pictures in folder n03976657
# 498 pictures in folder n04146614
# 500 pictures in folder n04532106
# 493 pictures in folder n02403003
# 492 pictures in folder n03670208
# 492 pictures in folder n01768244
# 473 pictures in folder n04562935
# 499 pictures in folder n02509815
# 494 pictures in folder n04487081
# 499 pictures in folder n03026506
# 499 pictures in folder n02002724
# 499 pictures in folder n03393912
# 495 pictures in folder n03770439
# 474 pictures in folder n03992509
# 468 pictures in folder n03804744
# 491 pictures in folder n03814639
# 497 pictures in folder n01770393
# 500 pictures in folder n02056570
# 497 pictures in folder n02094433
# 498 pictures in folder n07920052
# 497 pictures in folder n02085620
# 499 pictures in folder n07720875
# 495 pictures in folder n03400231
# 492 pictures in folder n02892201
# 496 pictures in folder n02504458
# 480 pictures in folder n03424325
# 479 pictures in folder n02950826
# 497 pictures in folder n04149813
# 452 pictures in folder n03544143
# 496 pictures in folder n02423022
# 482 pictures in folder n04328186
# 474 pictures in folder n03250847
# 491 pictures in folder n02814533
# 491 pictures in folder n02480495
# 477 pictures in folder n03902125
# 471 pictures in folder n02841315
# 481 pictures in folder n02793495
# 497 pictures in folder n02190166
# 466 pictures in folder n03085013
# 500 pictures in folder n07871810
# 460 pictures in folder n02883205
# 488 pictures in folder n04417672
# 484 pictures in folder n03637318
# 500 pictures in folder n01784675
# 465 pictures in folder n02788148
# 473 pictures in folder n04501370
# 488 pictures in folder n02909870
# 492 pictures in folder n02106662
# 499 pictures in folder n07749582
# 499 pictures in folder n02236044
# 500 pictures in folder n02281406
# 463 pictures in folder n03838899
# 485 pictures in folder n04099969
# 495 pictures in folder n04285008
# 488 pictures in folder n02669723
# 492 pictures in folder n02666196
# 493 pictures in folder n07753592
# 498 pictures in folder n07615774
# 480 pictures in folder n04465501
# 484 pictures in folder n02795169
# 492 pictures in folder n02917067
# 495 pictures in folder n04133789
# 495 pictures in folder n01774750
# 499 pictures in folder n01882714
# 495 pictures in folder n03649909
# 500 pictures in folder n02321529
# 497 pictures in folder n06596364
# 492 pictures in folder n02123045
# 492 pictures in folder n02124075
# 493 pictures in folder n02129165
# 500 pictures in folder n02165456
# 496 pictures in folder n09246464
# 500 pictures in folder n07711569
# 490 pictures in folder n04265275
# 497 pictures in folder n07715103
# 493 pictures in folder n03179701
# 480 pictures in folder n03447447
# 494 pictures in folder n04596742
# 500 pictures in folder n03201208
# 472 pictures in folder n02999410
# 498 pictures in folder n02437312
# 494 pictures in folder n04540053

# %%
shuffler=np.random.RandomState(seed=10).permutation(len(X_tot))
X_tot = X_tot[shuffler]
y_tot = y_tot[shuffler]
y_tot=tf.keras.utils.to_categorical(y_tot)

X_train = X_tot[5000:]
y_train =  y_tot[5000:]
X_val = X_tot[:5000]
y_val =  y_tot[:5000]


print('test data:')
print(X_test.shape)
print(y_test.shape)

print('train data:')
print(X_train.shape)
print(y_train.shape)

print('val data:')
print(X_val.shape)
print(y_val.shape)
# Out:
# test data:
# (9832, 64, 64, 3)
# (9832, 200)
# train data:
# (93179, 64, 64, 3)
# (93179, 200)
# val data:
# (5000, 64, 64, 3)
# (5000, 200)

# %% [markdown]
# #### Saving the variables allows faster loading in the future

# %%
#save for future use without having to reload from the images folders
np.save('data/X_test.npy', X_test)
np.save('data/y_test.npy', y_test)
np.save('data/X_train.npy', X_train)
np.save('data/y_train.npy', y_train)
np.save('data/X_val.npy', X_val)
np.save('data/y_val.npy', y_val)

# %%
print('script running in '+os.path.abspath("."))
X_test = np.load('./data/X_test.npy')
y_test = np.load('./data/y_test.npy')
X_train = np.load('./data/X_train.npy')
y_train = np.load('./data/y_train.npy')
X_val = np.load('./data/X_val.npy')
y_val = np.load('./data/y_val.npy')
# Out:
# script running in /home/ecbm4040/envTF24/e4040-2021fall-project-fren-an3078-wab2138-av3023

# %% [markdown]
# # 1. Using ResNet34 with ImageNet

# %% [markdown]
# ### We use our custom resnet model generator to get any resnet
#
# Imagenet has 200 different labels and is downsampled from ImageNet to a resolution of 64x64

# %%
from utils.custom_resnet import custom_resnet34
from utils.train_TinyImageNet_SE_ResNet import tinyImageNet_resnet_train
# tinyImageNet_resnet_train(model,path,X_train,y_train,X_val,y_val,data_aug=False,learning_rate=0.6,steps=14,epochs=45,batch_size=128,es_patience=8)
resnet_34=custom_resnet34(input_shape=(64,64,3),n_classes=200)
resnet_34.summary()
# Out:
# Model: "custom_resnet34"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 32, 32, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 32, 32, 64)   0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 16, 16, 64)   0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 16, 16, 64)   36928       pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (ReLU)      (None, 16, 16, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 16, 16, 64)   36928       pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 16, 16, 64)   0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_relu (ReLU)        (None, 16, 16, 64)   0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (ReLU)      (None, 16, 16, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 16, 16, 64)   0           conv2_block1_relu[0][0]
#                                                                  conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_relu (ReLU)        (None, 16, 16, 64)   0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (ReLU)      (None, 16, 16, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 16, 16, 64)   0           conv2_block2_relu[0][0]
#                                                                  conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_relu (ReLU)        (None, 16, 16, 64)   0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 8, 8, 128)    73856       conv2_block3_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (ReLU)      (None, 8, 8, 128)    0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 8, 8, 128)    73856       conv2_block3_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 8, 8, 128)    0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_relu (ReLU)        (None, 8, 8, 128)    0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (ReLU)      (None, 8, 8, 128)    0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 8, 8, 128)    0           conv3_block1_relu[0][0]
#                                                                  conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_relu (ReLU)        (None, 8, 8, 128)    0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (ReLU)      (None, 8, 8, 128)    0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 8, 8, 128)    0           conv3_block2_relu[0][0]
#                                                                  conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_relu (ReLU)        (None, 8, 8, 128)    0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block3_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (ReLU)      (None, 8, 8, 128)    0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 8, 8, 128)    0           conv3_block3_relu[0][0]
#                                                                  conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_relu (ReLU)        (None, 8, 8, 128)    0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 4, 4, 256)    295168      conv3_block4_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 4, 4, 256)    295168      conv3_block4_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 4, 4, 256)    0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 4, 4, 256)    0           conv4_block1_relu[0][0]
#                                                                  conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 4, 4, 256)    0           conv4_block2_relu[0][0]
#                                                                  conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 4, 4, 256)    0           conv4_block3_relu[0][0]
#                                                                  conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block4_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 4, 4, 256)    0           conv4_block4_relu[0][0]
#                                                                  conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block5_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 4, 4, 256)    0           conv4_block5_relu[0][0]
#                                                                  conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 2, 2, 512)    1180160     conv4_block6_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (ReLU)      (None, 2, 2, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 2, 2, 512)    1180160     conv4_block6_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 2, 2, 512)    0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_relu (ReLU)        (None, 2, 2, 512)    0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (ReLU)      (None, 2, 2, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 2, 2, 512)    0           conv5_block1_relu[0][0]
#                                                                  conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_relu (ReLU)        (None, 2, 2, 512)    0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (ReLU)      (None, 2, 2, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 2, 2, 512)    0           conv5_block2_relu[0][0]
#                                                                  conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_relu (ReLU)        (None, 2, 2, 512)    0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# pool_out (GlobalAveragePooling2 (None, 512)          0           conv5_block3_relu[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 200)          102600      pool_out[0][0]
# ==================================================================================================
# Total params: 22,826,248
# Trainable params: 22,809,096
# Non-trainable params: 17,152
# __________________________________________________________________________________________________

# %% [markdown]
# ## 1.1 Resnet34 without data augmentation

# %%
hist_resnet_34= tinyImageNet_resnet_train(resnet_34,
                          './models/tinyImageNet/resnet_34_best.hdf5', #path for weights of best model
                          X_train,y_train,
                          X_val,
                          y_val,
                          data_aug=False, #no data aug
                          learning_rate=0.6, #starting learning rate
                          steps=20, #number of epochs between learning rate modification (* 0.1)
                          epochs=60,
                          batch_size=128,
                          es_patience=20) #early stopping
# Out:
# Epoch 1/60
# steps before lr change:  20
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 79s 100ms/step - loss: 5.9251 - acc: 0.0082 - val_loss: 5.1338 - val_acc: 0.0142
#
# Epoch 00001: val_acc improved from -inf to 0.01420, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 2/60
# steps before lr change:  19
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 5.1177 - acc: 0.0139 - val_loss: 5.1026 - val_acc: 0.0156
#
# Epoch 00002: val_acc improved from 0.01420 to 0.01560, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 3/60
# steps before lr change:  18
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 96ms/step - loss: 5.0819 - acc: 0.0153 - val_loss: 5.2727 - val_acc: 0.0088
#
# Epoch 00003: val_acc did not improve from 0.01560
# Epoch 4/60
# steps before lr change:  17
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 96ms/step - loss: 5.0362 - acc: 0.0180 - val_loss: 5.0501 - val_acc: 0.0152
#
# Epoch 00004: val_acc did not improve from 0.01560
# Epoch 5/60
# steps before lr change:  16
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 96ms/step - loss: 4.9467 - acc: 0.0225 - val_loss: 4.9614 - val_acc: 0.0258
#
# Epoch 00005: val_acc improved from 0.01560 to 0.02580, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 6/60
# steps before lr change:  15
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 4.8312 - acc: 0.0323 - val_loss: 4.9805 - val_acc: 0.0334
#
# Epoch 00006: val_acc improved from 0.02580 to 0.03340, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 7/60
# steps before lr change:  14
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 4.6930 - acc: 0.0429 - val_loss: 4.8020 - val_acc: 0.0408
#
# Epoch 00007: val_acc improved from 0.03340 to 0.04080, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 8/60
# steps before lr change:  13
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 96ms/step - loss: 4.5525 - acc: 0.0563 - val_loss: 5.0161 - val_acc: 0.0364
#
# Epoch 00008: val_acc did not improve from 0.04080
# Epoch 9/60
# steps before lr change:  12
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 4.4130 - acc: 0.0714 - val_loss: 4.3817 - val_acc: 0.0766
#
# Epoch 00009: val_acc improved from 0.04080 to 0.07660, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 10/60
# steps before lr change:  11
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 4.2539 - acc: 0.0930 - val_loss: 4.6219 - val_acc: 0.0738
#
# Epoch 00010: val_acc did not improve from 0.07660
# Epoch 11/60
# steps before lr change:  10
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 4.0583 - acc: 0.1169 - val_loss: 4.4406 - val_acc: 0.0828
#
# Epoch 00011: val_acc improved from 0.07660 to 0.08280, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 12/60
# steps before lr change:  9
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 3.8969 - acc: 0.1444 - val_loss: 4.5530 - val_acc: 0.0890
#
# Epoch 00012: val_acc improved from 0.08280 to 0.08900, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 13/60
# steps before lr change:  8
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 3.7877 - acc: 0.1621 - val_loss: 4.0428 - val_acc: 0.1362
#
# Epoch 00013: val_acc improved from 0.08900 to 0.13620, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 14/60
# steps before lr change:  7
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 3.6602 - acc: 0.1771 - val_loss: 3.9263 - val_acc: 0.1410
#
# Epoch 00014: val_acc improved from 0.13620 to 0.14100, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 15/60
# steps before lr change:  6
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 3.5627 - acc: 0.1973 - val_loss: 3.9751 - val_acc: 0.1460
#
# Epoch 00015: val_acc improved from 0.14100 to 0.14600, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 16/60
# steps before lr change:  5
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 3.4644 - acc: 0.2146 - val_loss: 4.0356 - val_acc: 0.1474
#
# Epoch 00016: val_acc improved from 0.14600 to 0.14740, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 17/60
# steps before lr change:  4
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 3.4017 - acc: 0.2235 - val_loss: 4.7289 - val_acc: 0.0994
#
# Epoch 00017: val_acc did not improve from 0.14740
# Epoch 18/60
# steps before lr change:  3
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 3.2833 - acc: 0.2447 - val_loss: 3.8286 - val_acc: 0.1714
#
# Epoch 00018: val_acc improved from 0.14740 to 0.17140, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 19/60
# steps before lr change:  2
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 3.1932 - acc: 0.2583 - val_loss: 3.7330 - val_acc: 0.1814
#
# Epoch 00019: val_acc improved from 0.17140 to 0.18140, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 20/60
# steps before lr change:  1
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 3.1014 - acc: 0.2760 - val_loss: 3.9912 - val_acc: 0.1758
#
# Epoch 00020: val_acc did not improve from 0.18140
# Epoch 21/60
# steps before lr change:  20
# new learning rate:  0.6000000238418579
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 2.7936 - acc: 0.3402 - val_loss: 3.1525 - val_acc: 0.2800
#
# Epoch 00021: val_acc improved from 0.18140 to 0.28000, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 22/60
# steps before lr change:  19
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 2.5541 - acc: 0.3843 - val_loss: 3.1350 - val_acc: 0.2874
#
# Epoch 00022: val_acc improved from 0.28000 to 0.28740, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 23/60
# steps before lr change:  18
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 2.4647 - acc: 0.4027 - val_loss: 3.1947 - val_acc: 0.2782
#
# Epoch 00023: val_acc did not improve from 0.28740
# Epoch 24/60
# steps before lr change:  17
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 2.3962 - acc: 0.4170 - val_loss: 3.1573 - val_acc: 0.2882
#
# Epoch 00024: val_acc improved from 0.28740 to 0.28820, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 25/60
# steps before lr change:  16
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 2.3092 - acc: 0.4311 - val_loss: 3.2096 - val_acc: 0.2846
#
# Epoch 00025: val_acc did not improve from 0.28820
# Epoch 26/60
# steps before lr change:  15
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 2.2363 - acc: 0.4484 - val_loss: 3.2372 - val_acc: 0.2892
#
# Epoch 00026: val_acc improved from 0.28820 to 0.28920, saving model to ./models/tinyImageNet/resnet_34_best.hdf5
# Epoch 27/60
# steps before lr change:  14
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 71s 97ms/step - loss: 2.1282 - acc: 0.4717 - val_loss: 3.3179 - val_acc: 0.2794
#
# Epoch 00027: val_acc did not improve from 0.28920
# Epoch 28/60
# steps before lr change:  13
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 2.0169 - acc: 0.4950 - val_loss: 3.3577 - val_acc: 0.2814
#
# Epoch 00028: val_acc did not improve from 0.28920
# Epoch 29/60
# steps before lr change:  12
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 1.8829 - acc: 0.5252 - val_loss: 3.4853 - val_acc: 0.2748
#
# Epoch 00029: val_acc did not improve from 0.28920
# Epoch 30/60
# steps before lr change:  11
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 1.7418 - acc: 0.5534 - val_loss: 3.5603 - val_acc: 0.2710
#
# Epoch 00030: val_acc did not improve from 0.28920
# Epoch 31/60
# steps before lr change:  10
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 71s 97ms/step - loss: 1.5862 - acc: 0.5938 - val_loss: 3.7041 - val_acc: 0.2646
#
# Epoch 00031: val_acc did not improve from 0.28920
# Epoch 32/60
# steps before lr change:  9
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 1.4167 - acc: 0.6310 - val_loss: 3.9411 - val_acc: 0.2498
#
# Epoch 00032: val_acc did not improve from 0.28920
# Epoch 33/60
# steps before lr change:  8
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 1.2415 - acc: 0.6698 - val_loss: 4.1164 - val_acc: 0.2466
#
# Epoch 00033: val_acc did not improve from 0.28920
# Epoch 34/60
# steps before lr change:  7
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 71s 97ms/step - loss: 1.0654 - acc: 0.7127 - val_loss: 4.2688 - val_acc: 0.2538
#
# Epoch 00034: val_acc did not improve from 0.28920
# Epoch 35/60
# steps before lr change:  6
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 71s 97ms/step - loss: 0.8844 - acc: 0.7585 - val_loss: 4.4545 - val_acc: 0.2538
#
# Epoch 00035: val_acc did not improve from 0.28920
# Epoch 36/60
# steps before lr change:  5
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 0.7269 - acc: 0.7991 - val_loss: 4.8962 - val_acc: 0.2376
#
# Epoch 00036: val_acc did not improve from 0.28920
# Epoch 37/60
# steps before lr change:  4
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 0.5923 - acc: 0.8312 - val_loss: 5.1958 - val_acc: 0.2336
#
# Epoch 00037: val_acc did not improve from 0.28920
# Epoch 38/60
# steps before lr change:  3
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 0.4818 - acc: 0.8638 - val_loss: 5.6382 - val_acc: 0.2236
#
# Epoch 00038: val_acc did not improve from 0.28920
# Epoch 39/60
# steps before lr change:  2
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 70s 97ms/step - loss: 0.3854 - acc: 0.8872 - val_loss: 5.6804 - val_acc: 0.2302
#
# Epoch 00039: val_acc did not improve from 0.28920
# Epoch 40/60
# steps before lr change:  1
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 71s 97ms/step - loss: 0.2826 - acc: 0.9188 - val_loss: 5.9889 - val_acc: 0.2250
#
# Epoch 00040: val_acc did not improve from 0.28920
# Epoch 41/60
# steps before lr change:  20
# new learning rate:  0.06000000238418579
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.006000000238418579.
# 727/727 [==============================] - 71s 97ms/step - loss: 0.2105 - acc: 0.9429 - val_loss: 5.7674 - val_acc: 0.2540
#
# Epoch 00041: val_acc did not improve from 0.28920
# Epoch 42/60
# steps before lr change:  19
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 70s 97ms/step - loss: 0.0840 - acc: 0.9862 - val_loss: 5.8496 - val_acc: 0.2542
#
# Epoch 00042: val_acc did not improve from 0.28920
# Epoch 43/60
# steps before lr change:  18
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 70s 97ms/step - loss: 0.0606 - acc: 0.9929 - val_loss: 5.8988 - val_acc: 0.2548
#
# Epoch 00043: val_acc did not improve from 0.28920
# Epoch 44/60
# steps before lr change:  17
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 70s 97ms/step - loss: 0.0501 - acc: 0.9950 - val_loss: 5.9639 - val_acc: 0.2582
#
# Epoch 00044: val_acc did not improve from 0.28920
# Epoch 45/60
# steps before lr change:  16
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 71s 97ms/step - loss: 0.0422 - acc: 0.9966 - val_loss: 5.9995 - val_acc: 0.2552
#
# Epoch 00045: val_acc did not improve from 0.28920
# Epoch 46/60
# steps before lr change:  15
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 70s 97ms/step - loss: 0.0378 - acc: 0.9972 - val_loss: 6.0512 - val_acc: 0.2554
#
# Epoch 00046: val_acc did not improve from 0.28920

# %% [markdown]
# Accuracy and loss graphs

# %% [markdown]
# ## Early stopping, learning rate reduction was used, best model was saved

# %%
from utils.train_TinyImageNet_SE_ResNet import plot_model
plot_model(hist_resnet_34)

# %% [markdown]
# #### Why we used check points

# %%
# Evaluate the model
loss, acc = resnet_34.evaluate(X_test, y_test, verbose=2)
print("last epoch model, accuracy: {:5.2f}%".format(100 * acc))
# reload from saved weights:
model = custom_resnet34(input_shape=(64,64,3),n_classes=200)
model.load_weights('./models/tinyImageNet/resnet_34_best.hdf5')

# Evaluate the model
model.compile(loss='categorical_crossentropy', metrics = ['acc'])
loss, acc = model.evaluate(X_test, y_test, verbose=2)
print("best saved model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 308/308 - 4s - loss: 6.1013 - acc: 0.2551
# last epoch model, accuracy: 25.51%
# 308/308 - 5s - loss: 3.2606 - acc: 0.2855
# best saved model, accuracy: 28.55%

# %% [markdown]
# ### Top n scores

# %%
from utils.evaluate_model import score
from utils.custom_resnet import custom_resnet34 #

    
model.save('./full_models/tinyImageNet/resnet_34_best.h5')#
del model  # deletes the existing model       #
model = tf.keras.models.load_model('./full_models/tinyImageNet/resnet_34_best.h5')#

score(model,X_test,y_test,[1,3,5])
# Out:
# 308/308 - 8s - loss: 3.2606 - acc: 0.2855
# best saved model, accuracy: 28.55%
# 308/308 - 5s - loss: 3.2606 - acc: 0.2855
# custom_resnet34
# model accuracy: 28.55%
# top 1 accuracy: 28.5496324300766
# top 3 accuracy: 45.55532932281494
# top 5 accuracy: 55.09560704231262

# %% [markdown]
# ## 1.2 Resnet34 With data augmentation

# %%
from utils.train_TinyImageNet_SE_ResNet import tinyImageNet_resnet_train,plot_model

# %%
from utils.custom_resnet import custom_resnet34

resnet_34_aug=custom_resnet34(input_shape=(64,64,3),n_classes=200)
path='./models/tinyImageNet/resnet_34_aug_best.hdf5'
history_resnet_34_aug= tinyImageNet_resnet_train(resnet_34_aug,
                          path, #path for weights of best model
                          X_train,y_train,
                          X_val,
                          y_val,
                          data_aug=True, #no data aug
                          learning_rate=0.6, #starting learning rate
                          steps=20, #number of epochs between learning rate modification (* 0.1)
                          epochs=60,
                          batch_size=128,
                          es_patience=20) #early stopping
# Out:
# Epoch 1/60
# steps before lr change:  20
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 164s 174ms/step - loss: 5.8390 - acc: 0.0088 - val_loss: 5.1087 - val_acc: 0.0154
#
# Epoch 00001: val_acc improved from -inf to 0.01540, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 2/60
# steps before lr change:  19
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 125s 172ms/step - loss: 5.0017 - acc: 0.0239 - val_loss: 4.8904 - val_acc: 0.0336
#
# Epoch 00002: val_acc improved from 0.01540 to 0.03360, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 3/60
# steps before lr change:  18
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 126s 173ms/step - loss: 4.7751 - acc: 0.0416 - val_loss: 4.6312 - val_acc: 0.0574
#
# Epoch 00003: val_acc improved from 0.03360 to 0.05740, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 4/60
# steps before lr change:  17
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 125s 171ms/step - loss: 4.5078 - acc: 0.0698 - val_loss: 4.5049 - val_acc: 0.0766
#
# Epoch 00004: val_acc improved from 0.05740 to 0.07660, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 5/60
# steps before lr change:  16
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 125s 172ms/step - loss: 4.2609 - acc: 0.1017 - val_loss: 4.1995 - val_acc: 0.1142
#
# Epoch 00005: val_acc improved from 0.07660 to 0.11420, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 6/60
# steps before lr change:  15
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 125s 171ms/step - loss: 4.0545 - acc: 0.1272 - val_loss: 4.0553 - val_acc: 0.1442
#
# Epoch 00006: val_acc improved from 0.11420 to 0.14420, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 7/60
# steps before lr change:  14
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 125s 172ms/step - loss: 3.8743 - acc: 0.1554 - val_loss: 4.3320 - val_acc: 0.1182
#
# Epoch 00007: val_acc did not improve from 0.14420
# Epoch 8/60
# steps before lr change:  13
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 125s 171ms/step - loss: 3.7233 - acc: 0.1770 - val_loss: 3.9464 - val_acc: 0.1546
#
# Epoch 00008: val_acc improved from 0.14420 to 0.15460, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 9/60
# steps before lr change:  12
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 3.5942 - acc: 0.1980 - val_loss: 3.9677 - val_acc: 0.1580
#
# Epoch 00009: val_acc improved from 0.15460 to 0.15800, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 10/60
# steps before lr change:  11
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 3.5016 - acc: 0.2149 - val_loss: 3.4993 - val_acc: 0.2222
#
# Epoch 00010: val_acc improved from 0.15800 to 0.22220, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 11/60
# steps before lr change:  10
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 3.3817 - acc: 0.2314 - val_loss: 3.4428 - val_acc: 0.2320
#
# Epoch 00011: val_acc improved from 0.22220 to 0.23200, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 12/60
# steps before lr change:  9
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 3.2934 - acc: 0.2492 - val_loss: 3.6930 - val_acc: 0.2024
#
# Epoch 00012: val_acc did not improve from 0.23200
# Epoch 13/60
# steps before lr change:  8
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 3.1925 - acc: 0.2678 - val_loss: 3.3975 - val_acc: 0.2404
#
# Epoch 00013: val_acc improved from 0.23200 to 0.24040, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 14/60
# steps before lr change:  7
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 3.0903 - acc: 0.2853 - val_loss: 3.5943 - val_acc: 0.2232
#
# Epoch 00014: val_acc did not improve from 0.24040
# Epoch 15/60
# steps before lr change:  6
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 3.0241 - acc: 0.2952 - val_loss: 3.2679 - val_acc: 0.2608
#
# Epoch 00015: val_acc improved from 0.24040 to 0.26080, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 16/60
# steps before lr change:  5
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 123s 169ms/step - loss: 2.9477 - acc: 0.3115 - val_loss: 3.1809 - val_acc: 0.2758
#
# Epoch 00016: val_acc improved from 0.26080 to 0.27580, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 17/60
# steps before lr change:  4
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 123s 170ms/step - loss: 2.8480 - acc: 0.3284 - val_loss: 3.1504 - val_acc: 0.2884
#
# Epoch 00017: val_acc improved from 0.27580 to 0.28840, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 18/60
# steps before lr change:  3
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 2.7786 - acc: 0.3420 - val_loss: 3.1732 - val_acc: 0.2868
#
# Epoch 00018: val_acc did not improve from 0.28840
# Epoch 19/60
# steps before lr change:  2
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 2.7280 - acc: 0.3535 - val_loss: 3.1160 - val_acc: 0.3012
#
# Epoch 00019: val_acc improved from 0.28840 to 0.30120, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 20/60
# steps before lr change:  1
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 2.6408 - acc: 0.3712 - val_loss: 3.3543 - val_acc: 0.2704
#
# Epoch 00020: val_acc did not improve from 0.30120
# Epoch 21/60
# steps before lr change:  20
# new learning rate:  0.6000000238418579
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 2.3703 - acc: 0.4212 - val_loss: 2.7458 - val_acc: 0.3704
#
# Epoch 00021: val_acc improved from 0.30120 to 0.37040, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 22/60
# steps before lr change:  19
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 2.1800 - acc: 0.4638 - val_loss: 2.7552 - val_acc: 0.3682
#
# Epoch 00022: val_acc did not improve from 0.37040
# Epoch 23/60
# steps before lr change:  18
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 2.1188 - acc: 0.4730 - val_loss: 2.7043 - val_acc: 0.3712
#
# Epoch 00023: val_acc improved from 0.37040 to 0.37120, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 24/60
# steps before lr change:  17
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 2.0699 - acc: 0.4852 - val_loss: 2.7154 - val_acc: 0.3742
#
# Epoch 00024: val_acc improved from 0.37120 to 0.37420, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 25/60
# steps before lr change:  16
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 2.0343 - acc: 0.4922 - val_loss: 2.7387 - val_acc: 0.3712
#
# Epoch 00025: val_acc did not improve from 0.37420
# Epoch 26/60
# steps before lr change:  15
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.9969 - acc: 0.4993 - val_loss: 2.7349 - val_acc: 0.3744
#
# Epoch 00026: val_acc improved from 0.37420 to 0.37440, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 27/60
# steps before lr change:  14
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.9558 - acc: 0.5070 - val_loss: 2.7754 - val_acc: 0.3680
#
# Epoch 00027: val_acc did not improve from 0.37440
# Epoch 28/60
# steps before lr change:  13
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.9208 - acc: 0.5175 - val_loss: 2.7319 - val_acc: 0.3824
#
# Epoch 00028: val_acc improved from 0.37440 to 0.38240, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 29/60
# steps before lr change:  12
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.8737 - acc: 0.5278 - val_loss: 2.7326 - val_acc: 0.3772
#
# Epoch 00029: val_acc did not improve from 0.38240
# Epoch 30/60
# steps before lr change:  11
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.8493 - acc: 0.5298 - val_loss: 2.7456 - val_acc: 0.3808
#
# Epoch 00030: val_acc did not improve from 0.38240
# Epoch 31/60
# steps before lr change:  10
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.8098 - acc: 0.5408 - val_loss: 2.7699 - val_acc: 0.3774
#
# Epoch 00031: val_acc did not improve from 0.38240
# Epoch 32/60
# steps before lr change:  9
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.7578 - acc: 0.5498 - val_loss: 2.7696 - val_acc: 0.3848
#
# Epoch 00032: val_acc improved from 0.38240 to 0.38480, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 33/60
# steps before lr change:  8
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.7375 - acc: 0.5544 - val_loss: 2.8632 - val_acc: 0.3688
#
# Epoch 00033: val_acc did not improve from 0.38480
# Epoch 34/60
# steps before lr change:  7
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.6987 - acc: 0.5633 - val_loss: 2.8513 - val_acc: 0.3696
#
# Epoch 00034: val_acc did not improve from 0.38480
# Epoch 35/60
# steps before lr change:  6
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.6593 - acc: 0.5693 - val_loss: 2.8353 - val_acc: 0.3774
#
# Epoch 00035: val_acc did not improve from 0.38480
# Epoch 36/60
# steps before lr change:  5
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.6219 - acc: 0.5768 - val_loss: 2.8901 - val_acc: 0.3732
#
# Epoch 00036: val_acc did not improve from 0.38480
# Epoch 37/60
# steps before lr change:  4
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 125s 171ms/step - loss: 1.5663 - acc: 0.5930 - val_loss: 2.9212 - val_acc: 0.3724
#
# Epoch 00037: val_acc did not improve from 0.38480
# Epoch 38/60
# steps before lr change:  3
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.5288 - acc: 0.5984 - val_loss: 2.9441 - val_acc: 0.3694
#
# Epoch 00038: val_acc did not improve from 0.38480
# Epoch 39/60
# steps before lr change:  2
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 125s 173ms/step - loss: 1.4959 - acc: 0.6071 - val_loss: 2.9117 - val_acc: 0.3864
#
# Epoch 00039: val_acc improved from 0.38480 to 0.38640, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 40/60
# steps before lr change:  1
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 126s 173ms/step - loss: 1.4525 - acc: 0.6169 - val_loss: 2.9905 - val_acc: 0.3748
#
# Epoch 00040: val_acc did not improve from 0.38640
# Epoch 41/60
# steps before lr change:  20
# new learning rate:  0.06000000238418579
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.006000000238418579.
# 727/727 [==============================] - 123s 169ms/step - loss: 1.3507 - acc: 0.6416 - val_loss: 2.9457 - val_acc: 0.3894
#
# Epoch 00041: val_acc improved from 0.38640 to 0.38940, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 42/60
# steps before lr change:  19
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 123s 169ms/step - loss: 1.2763 - acc: 0.6643 - val_loss: 2.9678 - val_acc: 0.3878
#
# Epoch 00042: val_acc did not improve from 0.38940
# Epoch 43/60
# steps before lr change:  18
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 126s 174ms/step - loss: 1.2444 - acc: 0.6665 - val_loss: 2.9885 - val_acc: 0.3900
#
# Epoch 00043: val_acc improved from 0.38940 to 0.39000, saving model to ./models/tinyImageNet/resnet_34_aug_best.hdf5
# Epoch 44/60
# steps before lr change:  17
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 125s 172ms/step - loss: 1.2285 - acc: 0.6705 - val_loss: 3.0036 - val_acc: 0.3860
#
# Epoch 00044: val_acc did not improve from 0.39000
# Epoch 45/60
# steps before lr change:  16
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 123s 168ms/step - loss: 1.2036 - acc: 0.6776 - val_loss: 3.0359 - val_acc: 0.3830
#
# Epoch 00045: val_acc did not improve from 0.39000
# Epoch 46/60
# steps before lr change:  15
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 122s 168ms/step - loss: 1.1871 - acc: 0.6822 - val_loss: 3.0381 - val_acc: 0.3856
#
# Epoch 00046: val_acc did not improve from 0.39000
# Epoch 47/60
# steps before lr change:  14
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 122s 168ms/step - loss: 1.1770 - acc: 0.6859 - val_loss: 3.0527 - val_acc: 0.3834
#
# Epoch 00047: val_acc did not improve from 0.39000
# Epoch 48/60
# steps before lr change:  13
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 123s 169ms/step - loss: 1.1668 - acc: 0.6876 - val_loss: 3.0686 - val_acc: 0.3862
#
# Epoch 00048: val_acc did not improve from 0.39000
# Epoch 49/60
# steps before lr change:  12
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.1574 - acc: 0.6888 - val_loss: 3.0759 - val_acc: 0.3854
#
# Epoch 00049: val_acc did not improve from 0.39000
# Epoch 50/60
# steps before lr change:  11
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.1382 - acc: 0.6939 - val_loss: 3.0919 - val_acc: 0.3836
#
# Epoch 00050: val_acc did not improve from 0.39000
# Epoch 51/60
# steps before lr change:  10
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 123s 170ms/step - loss: 1.1323 - acc: 0.6929 - val_loss: 3.1222 - val_acc: 0.3806
#
# Epoch 00051: val_acc did not improve from 0.39000
# Epoch 52/60
# steps before lr change:  9
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 123s 170ms/step - loss: 1.1179 - acc: 0.6975 - val_loss: 3.1225 - val_acc: 0.3806
#
# Epoch 00052: val_acc did not improve from 0.39000
# Epoch 53/60
# steps before lr change:  8
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.0855 - acc: 0.7078 - val_loss: 3.1266 - val_acc: 0.3850
#
# Epoch 00053: val_acc did not improve from 0.39000
# Epoch 54/60
# steps before lr change:  7
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 125s 172ms/step - loss: 1.0758 - acc: 0.7095 - val_loss: 3.1332 - val_acc: 0.3864
#
# Epoch 00054: val_acc did not improve from 0.39000
# Epoch 55/60
# steps before lr change:  6
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 127s 174ms/step - loss: 1.0838 - acc: 0.7087 - val_loss: 3.1529 - val_acc: 0.3846
#
# Epoch 00055: val_acc did not improve from 0.39000
# Epoch 56/60
# steps before lr change:  5
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 122s 168ms/step - loss: 1.0689 - acc: 0.7098 - val_loss: 3.1559 - val_acc: 0.3822
#
# Epoch 00056: val_acc did not improve from 0.39000
# Epoch 57/60
# steps before lr change:  4
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 123s 168ms/step - loss: 1.0597 - acc: 0.7120 - val_loss: 3.1906 - val_acc: 0.3818
#
# Epoch 00057: val_acc did not improve from 0.39000
# Epoch 58/60
# steps before lr change:  3
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.0461 - acc: 0.7159 - val_loss: 3.1911 - val_acc: 0.3800
#
# Epoch 00058: val_acc did not improve from 0.39000
# Epoch 59/60
# steps before lr change:  2
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 123s 169ms/step - loss: 1.0372 - acc: 0.7202 - val_loss: 3.2151 - val_acc: 0.3818
#
# Epoch 00059: val_acc did not improve from 0.39000
# Epoch 60/60
# steps before lr change:  1
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 122s 168ms/step - loss: 1.0245 - acc: 0.7208 - val_loss: 3.2124 - val_acc: 0.3808
#
# Epoch 00060: val_acc did not improve from 0.39000

# %% [markdown]
# ## Early stopping, learning rate reduction was used, best model was saved

# %%
plot_model(history_resnet_34_aug)

# %%
# reload from saved weights:
from utils.custom_resnet import custom_resnet34 #
path='./models/tinyImageNet/resnet_34_aug_best.hdf5' #
model = custom_resnet34(input_shape=(64,64,3),n_classes=200)
model.load_weights(path)

model.save('./full_models/tinyImageNet/resnet_34_aug_best.h5')#
del model  # deletes the existing model       #
model = tf.keras.models.load_model('./full_models/tinyImageNet/resnet_34_aug_best.h5')#

# Evaluate the model
from utils.evaluate_model import score
score(model,X_test,y_test,[1,3,5])
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 308/308 - 5s - loss: 3.0376 - acc: 0.3834
# custom_resnet34
# model accuracy: 38.34%
# top 1 accuracy: 38.344183564186096
# top 3 accuracy: 55.736368894577026
# top 5 accuracy: 63.84255290031433

# %% [markdown]
# # 2. SE-ResNet18

# %% [markdown]
# ## 2.1 SE-ResNet34 without data augmentation

# %%
from utils.SE_resnet import SE_resnet34

SE_resnet34=SE_resnet34(input_shape=(64,64,3),n_classes=200,name='SE_resnet34')
SE_resnet34.summary()
# Out:
# Model: "SE_ResNet34"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 32, 32, 64)   256         conv1_conv[1][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 32, 32, 64)   0           conv1_bn[1][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 16, 16, 64)   0           conv1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 16, 16, 64)   36928       pool1[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (ReLU)      (None, 16, 16, 64)   0           conv2_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_squeeze (Global (None, 64)           0           conv2_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_fc1 (Dense)     (None, 4)            260         conv2_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_fc2 (Dense)     (None, 64)           320         conv2_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 16, 16, 64)   36928       pool1[1][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None, 1, 1, 64)     0           conv2_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_scaling (Multip (None, 16, 16, 64)   0           conv2_block1_2_bn[1][0]
#                                                                  tf.reshape[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 16, 16, 64)   0           conv2_block1_0_bn[1][0]
#                                                                  conv2_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block1_relu (ReLU)        (None, 16, 16, 64)   0           conv2_block1_add[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (ReLU)      (None, 16, 16, 64)   0           conv2_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_squeeze (Global (None, 64)           0           conv2_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_fc1 (Dense)     (None, 4)            260         conv2_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_fc2 (Dense)     (None, 64)           320         conv2_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_1 (TFOpLambda)       (None, 1, 1, 64)     0           conv2_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_scaling (Multip (None, 16, 16, 64)   0           conv2_block2_2_bn[1][0]
#                                                                  tf.reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 16, 16, 64)   0           conv2_block1_relu[1][0]
#                                                                  conv2_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block2_relu (ReLU)        (None, 16, 16, 64)   0           conv2_block2_add[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (ReLU)      (None, 16, 16, 64)   0           conv2_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_squeeze (Global (None, 64)           0           conv2_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_fc1 (Dense)     (None, 4)            260         conv2_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_fc2 (Dense)     (None, 64)           320         conv2_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_2 (TFOpLambda)       (None, 1, 1, 64)     0           conv2_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_scaling (Multip (None, 16, 16, 64)   0           conv2_block3_2_bn[1][0]
#                                                                  tf.reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 16, 16, 64)   0           conv2_block2_relu[1][0]
#                                                                  conv2_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block3_relu (ReLU)        (None, 16, 16, 64)   0           conv2_block3_add[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 8, 8, 128)    73856       conv2_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (ReLU)      (None, 8, 8, 128)    0           conv3_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_squeeze (Global (None, 128)          0           conv3_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc1 (Dense)     (None, 8)            1032        conv3_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc2 (Dense)     (None, 128)          1152        conv3_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 8, 8, 128)    73856       conv2_block3_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_3 (TFOpLambda)       (None, 1, 1, 128)    0           conv3_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_scaling (Multip (None, 8, 8, 128)    0           conv3_block1_2_bn[1][0]
#                                                                  tf.reshape_3[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 8, 8, 128)    0           conv3_block1_0_bn[1][0]
#                                                                  conv3_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block1_relu (ReLU)        (None, 8, 8, 128)    0           conv3_block1_add[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (ReLU)      (None, 8, 8, 128)    0           conv3_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_squeeze (Global (None, 128)          0           conv3_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc1 (Dense)     (None, 8)            1032        conv3_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc2 (Dense)     (None, 128)          1152        conv3_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_4 (TFOpLambda)       (None, 1, 1, 128)    0           conv3_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_scaling (Multip (None, 8, 8, 128)    0           conv3_block2_2_bn[1][0]
#                                                                  tf.reshape_4[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 8, 8, 128)    0           conv3_block1_relu[1][0]
#                                                                  conv3_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block2_relu (ReLU)        (None, 8, 8, 128)    0           conv3_block2_add[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (ReLU)      (None, 8, 8, 128)    0           conv3_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_squeeze (Global (None, 128)          0           conv3_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc1 (Dense)     (None, 8)            1032        conv3_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc2 (Dense)     (None, 128)          1152        conv3_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_5 (TFOpLambda)       (None, 1, 1, 128)    0           conv3_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_scaling (Multip (None, 8, 8, 128)    0           conv3_block3_2_bn[1][0]
#                                                                  tf.reshape_5[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 8, 8, 128)    0           conv3_block2_relu[1][0]
#                                                                  conv3_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block3_relu (ReLU)        (None, 8, 8, 128)    0           conv3_block3_add[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (ReLU)      (None, 8, 8, 128)    0           conv3_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_squeeze (Global (None, 128)          0           conv3_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc1 (Dense)     (None, 8)            1032        conv3_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc2 (Dense)     (None, 128)          1152        conv3_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_6 (TFOpLambda)       (None, 1, 1, 128)    0           conv3_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_scaling (Multip (None, 8, 8, 128)    0           conv3_block4_2_bn[1][0]
#                                                                  tf.reshape_6[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 8, 8, 128)    0           conv3_block3_relu[1][0]
#                                                                  conv3_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block4_relu (ReLU)        (None, 8, 8, 128)    0           conv3_block4_add[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 4, 4, 256)    295168      conv3_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_squeeze (Global (None, 256)          0           conv4_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc1 (Dense)     (None, 16)           4112        conv4_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc2 (Dense)     (None, 256)          4352        conv4_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 4, 4, 256)    295168      conv3_block4_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_7 (TFOpLambda)       (None, 1, 1, 256)    0           conv4_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_scaling (Multip (None, 4, 4, 256)    0           conv4_block1_2_bn[1][0]
#                                                                  tf.reshape_7[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 4, 4, 256)    0           conv4_block1_0_bn[1][0]
#                                                                  conv4_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block1_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block1_add[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_squeeze (Global (None, 256)          0           conv4_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc1 (Dense)     (None, 16)           4112        conv4_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc2 (Dense)     (None, 256)          4352        conv4_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_8 (TFOpLambda)       (None, 1, 1, 256)    0           conv4_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_scaling (Multip (None, 4, 4, 256)    0           conv4_block2_2_bn[1][0]
#                                                                  tf.reshape_8[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 4, 4, 256)    0           conv4_block1_relu[1][0]
#                                                                  conv4_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block2_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block2_add[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_squeeze (Global (None, 256)          0           conv4_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc1 (Dense)     (None, 16)           4112        conv4_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc2 (Dense)     (None, 256)          4352        conv4_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_9 (TFOpLambda)       (None, 1, 1, 256)    0           conv4_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_scaling (Multip (None, 4, 4, 256)    0           conv4_block3_2_bn[1][0]
#                                                                  tf.reshape_9[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 4, 4, 256)    0           conv4_block2_relu[1][0]
#                                                                  conv4_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block3_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block3_add[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_squeeze (Global (None, 256)          0           conv4_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc1 (Dense)     (None, 16)           4112        conv4_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc2 (Dense)     (None, 256)          4352        conv4_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_10 (TFOpLambda)      (None, 1, 1, 256)    0           conv4_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_scaling (Multip (None, 4, 4, 256)    0           conv4_block4_2_bn[1][0]
#                                                                  tf.reshape_10[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 4, 4, 256)    0           conv4_block3_relu[1][0]
#                                                                  conv4_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block4_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block4_add[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block5_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block5_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block5_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block5_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_squeeze (Global (None, 256)          0           conv4_block5_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc1 (Dense)     (None, 16)           4112        conv4_block5_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc2 (Dense)     (None, 256)          4352        conv4_block5_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_11 (TFOpLambda)      (None, 1, 1, 256)    0           conv4_block5_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_scaling (Multip (None, 4, 4, 256)    0           conv4_block5_2_bn[1][0]
#                                                                  tf.reshape_11[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 4, 4, 256)    0           conv4_block4_relu[1][0]
#                                                                  conv4_block5_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block5_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block5_add[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block5_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block6_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block6_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block6_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block6_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_squeeze (Global (None, 256)          0           conv4_block6_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc1 (Dense)     (None, 16)           4112        conv4_block6_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc2 (Dense)     (None, 256)          4352        conv4_block6_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_12 (TFOpLambda)      (None, 1, 1, 256)    0           conv4_block6_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_scaling (Multip (None, 4, 4, 256)    0           conv4_block6_2_bn[1][0]
#                                                                  tf.reshape_12[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 4, 4, 256)    0           conv4_block5_relu[1][0]
#                                                                  conv4_block6_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block6_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block6_add[1][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 2, 2, 512)    1180160     conv4_block6_relu[1][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (ReLU)      (None, 2, 2, 512)    0           conv5_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv5_block1_SE_squeeze (Global (None, 512)          0           conv5_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv5_block1_SE_fc1 (Dense)     (None, 32)           16416       conv5_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv5_block1_SE_fc2 (Dense)     (None, 512)          16896       conv5_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 2, 2, 512)    1180160     conv4_block6_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_13 (TFOpLambda)      (None, 1, 1, 512)    0           conv5_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv5_block1_SE_scaling (Multip (None, 2, 2, 512)    0           conv5_block1_2_bn[1][0]
#                                                                  tf.reshape_13[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 2, 2, 512)    0           conv5_block1_0_bn[1][0]
#                                                                  conv5_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv5_block1_relu (ReLU)        (None, 2, 2, 512)    0           conv5_block1_add[1][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (ReLU)      (None, 2, 2, 512)    0           conv5_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv5_block2_SE_squeeze (Global (None, 512)          0           conv5_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv5_block2_SE_fc1 (Dense)     (None, 32)           16416       conv5_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv5_block2_SE_fc2 (Dense)     (None, 512)          16896       conv5_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_14 (TFOpLambda)      (None, 1, 1, 512)    0           conv5_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv5_block2_SE_scaling (Multip (None, 2, 2, 512)    0           conv5_block2_2_bn[1][0]
#                                                                  tf.reshape_14[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 2, 2, 512)    0           conv5_block1_relu[1][0]
#                                                                  conv5_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv5_block2_relu (ReLU)        (None, 2, 2, 512)    0           conv5_block2_add[1][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (ReLU)      (None, 2, 2, 512)    0           conv5_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv5_block3_SE_squeeze (Global (None, 512)          0           conv5_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv5_block3_SE_fc1 (Dense)     (None, 32)           16416       conv5_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv5_block3_SE_fc2 (Dense)     (None, 512)          16896       conv5_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_15 (TFOpLambda)      (None, 1, 1, 512)    0           conv5_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv5_block3_SE_scaling (Multip (None, 2, 2, 512)    0           conv5_block3_2_bn[1][0]
#                                                                  tf.reshape_15[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 2, 2, 512)    0           conv5_block2_relu[1][0]
#                                                                  conv5_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv5_block3_relu (ReLU)        (None, 2, 2, 512)    0           conv5_block3_add[1][0]
# __________________________________________________________________________________________________
# pool_out (GlobalAveragePooling2 (None, 512)          0           conv5_block3_relu[1][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 200)          102600      pool_out[1][0]
# ==================================================================================================
# Total params: 22,987,444
# Trainable params: 22,970,292
# Non-trainable params: 17,152
# __________________________________________________________________________________________________

# %%
path='./models/tinyImageNet/SE-resnet_34_best.hdf5'
history_SEresnet_34= tinyImageNet_resnet_train(SE_resnet34,
                          path, #path for weights of best model
                          X_train,y_train,
                          X_val,
                          y_val,
                          data_aug=False, #no data aug
                          learning_rate=0.6, #starting learning rate
                          steps=20, #number of epochs between learning rate modification (* 0.1)
                          epochs=60,
                          batch_size=128,
                          es_patience=20) #early stopping
# Out:
# Epoch 1/60
# steps before lr change:  20
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 86s 106ms/step - loss: 5.4674 - acc: 0.0071 - val_loss: 5.1274 - val_acc: 0.0142
#
# Epoch 00001: val_acc improved from -inf to 0.01420, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 2/60
# steps before lr change:  19
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 4.8530 - acc: 0.0311 - val_loss: 5.4505 - val_acc: 0.0314
#
# Epoch 00002: val_acc improved from 0.01420 to 0.03140, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 3/60
# steps before lr change:  18
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 4.1994 - acc: 0.1042 - val_loss: 4.1591 - val_acc: 0.1122
#
# Epoch 00003: val_acc improved from 0.03140 to 0.11220, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 4/60
# steps before lr change:  17
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 3.6700 - acc: 0.1834 - val_loss: 5.0352 - val_acc: 0.0900
#
# Epoch 00004: val_acc did not improve from 0.11220
# Epoch 5/60
# steps before lr change:  16
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 3.3210 - acc: 0.2411 - val_loss: 4.4692 - val_acc: 0.1310
#
# Epoch 00005: val_acc improved from 0.11220 to 0.13100, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 6/60
# steps before lr change:  15
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 3.0567 - acc: 0.2915 - val_loss: 3.6436 - val_acc: 0.2164
#
# Epoch 00006: val_acc improved from 0.13100 to 0.21640, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 7/60
# steps before lr change:  14
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 2.8079 - acc: 0.3354 - val_loss: 3.8169 - val_acc: 0.2220
#
# Epoch 00007: val_acc improved from 0.21640 to 0.22200, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 8/60
# steps before lr change:  13
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 2.5256 - acc: 0.3898 - val_loss: 3.9015 - val_acc: 0.2080
#
# Epoch 00008: val_acc did not improve from 0.22200
# Epoch 9/60
# steps before lr change:  12
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 2.3681 - acc: 0.4227 - val_loss: 3.5074 - val_acc: 0.2658
#
# Epoch 00009: val_acc improved from 0.22200 to 0.26580, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 10/60
# steps before lr change:  11
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 1.9774 - acc: 0.5004 - val_loss: 4.4864 - val_acc: 0.1526
#
# Epoch 00010: val_acc did not improve from 0.26580
# Epoch 11/60
# steps before lr change:  10
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 1.8619 - acc: 0.5228 - val_loss: 3.7327 - val_acc: 0.2502
#
# Epoch 00011: val_acc did not improve from 0.26580
# Epoch 12/60
# steps before lr change:  9
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 1.4974 - acc: 0.6013 - val_loss: 4.4421 - val_acc: 0.2096
#
# Epoch 00012: val_acc did not improve from 0.26580
# Epoch 13/60
# steps before lr change:  8
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 1.1227 - acc: 0.6892 - val_loss: 4.5585 - val_acc: 0.2224
#
# Epoch 00013: val_acc did not improve from 0.26580
# Epoch 14/60
# steps before lr change:  7
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.7705 - acc: 0.7777 - val_loss: 5.3256 - val_acc: 0.2134
#
# Epoch 00014: val_acc did not improve from 0.26580
# Epoch 15/60
# steps before lr change:  6
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.5799 - acc: 0.8273 - val_loss: 5.2931 - val_acc: 0.2358
#
# Epoch 00015: val_acc did not improve from 0.26580
# Epoch 16/60
# steps before lr change:  5
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.4414 - acc: 0.8631 - val_loss: 6.2254 - val_acc: 0.2104
#
# Epoch 00016: val_acc did not improve from 0.26580
# Epoch 17/60
# steps before lr change:  4
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.3376 - acc: 0.8954 - val_loss: 6.1500 - val_acc: 0.2278
#
# Epoch 00017: val_acc did not improve from 0.26580
# Epoch 18/60
# steps before lr change:  3
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.2799 - acc: 0.9124 - val_loss: 6.2008 - val_acc: 0.2498
#
# Epoch 00018: val_acc did not improve from 0.26580
# Epoch 19/60
# steps before lr change:  2
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.2287 - acc: 0.9283 - val_loss: 6.8092 - val_acc: 0.2508
#
# Epoch 00019: val_acc did not improve from 0.26580
# Epoch 20/60
# steps before lr change:  1
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.1946 - acc: 0.9386 - val_loss: 6.8297 - val_acc: 0.2554
#
# Epoch 00020: val_acc did not improve from 0.26580
# Epoch 21/60
# steps before lr change:  20
# new learning rate:  0.6000000238418579
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 102ms/step - loss: 0.1230 - acc: 0.9617 - val_loss: 6.2257 - val_acc: 0.2996
#
# Epoch 00021: val_acc improved from 0.26580 to 0.29960, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 22/60
# steps before lr change:  19
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0188 - acc: 0.9965 - val_loss: 6.3260 - val_acc: 0.3062
#
# Epoch 00022: val_acc improved from 0.29960 to 0.30620, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 23/60
# steps before lr change:  18
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0108 - acc: 0.9991 - val_loss: 6.4067 - val_acc: 0.3052
#
# Epoch 00023: val_acc did not improve from 0.30620
# Epoch 24/60
# steps before lr change:  17
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0075 - acc: 0.9994 - val_loss: 6.4653 - val_acc: 0.3064
#
# Epoch 00024: val_acc improved from 0.30620 to 0.30640, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 25/60
# steps before lr change:  16
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0058 - acc: 0.9995 - val_loss: 6.5308 - val_acc: 0.3082
#
# Epoch 00025: val_acc improved from 0.30640 to 0.30820, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 26/60
# steps before lr change:  15
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0053 - acc: 0.9995 - val_loss: 6.5860 - val_acc: 0.3056
#
# Epoch 00026: val_acc did not improve from 0.30820
# Epoch 27/60
# steps before lr change:  14
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0042 - acc: 0.9996 - val_loss: 6.6110 - val_acc: 0.3092
#
# Epoch 00027: val_acc improved from 0.30820 to 0.30920, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 28/60
# steps before lr change:  13
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0037 - acc: 0.9997 - val_loss: 6.6542 - val_acc: 0.3088
#
# Epoch 00028: val_acc did not improve from 0.30920
# Epoch 29/60
# steps before lr change:  12
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 74s 102ms/step - loss: 0.0033 - acc: 0.9997 - val_loss: 6.6898 - val_acc: 0.3102
#
# Epoch 00029: val_acc improved from 0.30920 to 0.31020, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 30/60
# steps before lr change:  11
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0031 - acc: 0.9997 - val_loss: 6.7128 - val_acc: 0.3122
#
# Epoch 00030: val_acc improved from 0.31020 to 0.31220, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 31/60
# steps before lr change:  10
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0028 - acc: 0.9997 - val_loss: 6.7401 - val_acc: 0.3116
#
# Epoch 00031: val_acc did not improve from 0.31220
# Epoch 32/60
# steps before lr change:  9
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0027 - acc: 0.9997 - val_loss: 6.7739 - val_acc: 0.3082
#
# Epoch 00032: val_acc did not improve from 0.31220
# Epoch 33/60
# steps before lr change:  8
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0026 - acc: 0.9997 - val_loss: 6.7859 - val_acc: 0.3116
#
# Epoch 00033: val_acc did not improve from 0.31220
# Epoch 34/60
# steps before lr change:  7
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0023 - acc: 0.9997 - val_loss: 6.8143 - val_acc: 0.3116
#
# Epoch 00034: val_acc did not improve from 0.31220
# Epoch 35/60
# steps before lr change:  6
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 74s 102ms/step - loss: 0.0022 - acc: 0.9998 - val_loss: 6.8372 - val_acc: 0.3092
#
# Epoch 00035: val_acc did not improve from 0.31220
# Epoch 36/60
# steps before lr change:  5
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0024 - acc: 0.9997 - val_loss: 6.8591 - val_acc: 0.3114
#
# Epoch 00036: val_acc did not improve from 0.31220
# Epoch 37/60
# steps before lr change:  4
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0020 - acc: 0.9998 - val_loss: 6.8739 - val_acc: 0.3110
#
# Epoch 00037: val_acc did not improve from 0.31220
# Epoch 38/60
# steps before lr change:  3
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0021 - acc: 0.9996 - val_loss: 6.8913 - val_acc: 0.3108
#
# Epoch 00038: val_acc did not improve from 0.31220
# Epoch 39/60
# steps before lr change:  2
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0021 - acc: 0.9996 - val_loss: 6.9076 - val_acc: 0.3118
#
# Epoch 00039: val_acc did not improve from 0.31220
# Epoch 40/60
# steps before lr change:  1
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 74s 102ms/step - loss: 0.0020 - acc: 0.9996 - val_loss: 6.9312 - val_acc: 0.3116
#
# Epoch 00040: val_acc did not improve from 0.31220
# Epoch 41/60
# steps before lr change:  20
# new learning rate:  0.06000000238418579
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.006000000238418579.
# 727/727 [==============================] - 74s 102ms/step - loss: 0.0017 - acc: 0.9997 - val_loss: 6.9261 - val_acc: 0.3122
#
# Epoch 00041: val_acc did not improve from 0.31220
# Epoch 42/60
# steps before lr change:  19
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0015 - acc: 0.9999 - val_loss: 6.9253 - val_acc: 0.3128
#
# Epoch 00042: val_acc improved from 0.31220 to 0.31280, saving model to ./models/tinyImageNet/SE-resnet_34_best.hdf5
# Epoch 43/60
# steps before lr change:  18
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0016 - acc: 0.9998 - val_loss: 6.9266 - val_acc: 0.3108
#
# Epoch 00043: val_acc did not improve from 0.31280
# Epoch 44/60
# steps before lr change:  17
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0015 - acc: 0.9998 - val_loss: 6.9283 - val_acc: 0.3102
#
# Epoch 00044: val_acc did not improve from 0.31280
# Epoch 45/60
# steps before lr change:  16
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0017 - acc: 0.9997 - val_loss: 6.9418 - val_acc: 0.3114
#
# Epoch 00045: val_acc did not improve from 0.31280
# Epoch 46/60
# steps before lr change:  15
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 102ms/step - loss: 0.0016 - acc: 0.9997 - val_loss: 6.9294 - val_acc: 0.3114
#
# Epoch 00046: val_acc did not improve from 0.31280
# Epoch 47/60
# steps before lr change:  14
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0017 - acc: 0.9997 - val_loss: 6.9307 - val_acc: 0.3118
#
# Epoch 00047: val_acc did not improve from 0.31280
# Epoch 48/60
# steps before lr change:  13
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0018 - acc: 0.9996 - val_loss: 6.9334 - val_acc: 0.3122
#
# Epoch 00048: val_acc did not improve from 0.31280
# Epoch 49/60
# steps before lr change:  12
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0015 - acc: 0.9998 - val_loss: 6.9350 - val_acc: 0.3120
#
# Epoch 00049: val_acc did not improve from 0.31280
# Epoch 50/60
# steps before lr change:  11
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0014 - acc: 0.9998 - val_loss: 6.9428 - val_acc: 0.3120
#
# Epoch 00050: val_acc did not improve from 0.31280
# Epoch 51/60
# steps before lr change:  10
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0016 - acc: 0.9998 - val_loss: 6.9411 - val_acc: 0.3128
#
# Epoch 00051: val_acc did not improve from 0.31280
# Epoch 52/60
# steps before lr change:  9
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 74s 102ms/step - loss: 0.0016 - acc: 0.9999 - val_loss: 6.9390 - val_acc: 0.3110
#
# Epoch 00052: val_acc did not improve from 0.31280
# Epoch 53/60
# steps before lr change:  8
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0015 - acc: 0.9998 - val_loss: 6.9470 - val_acc: 0.3106
#
# Epoch 00053: val_acc did not improve from 0.31280
# Epoch 54/60
# steps before lr change:  7
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0016 - acc: 0.9997 - val_loss: 6.9511 - val_acc: 0.3108
#
# Epoch 00054: val_acc did not improve from 0.31280
# Epoch 55/60
# steps before lr change:  6
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0016 - acc: 0.9997 - val_loss: 6.9438 - val_acc: 0.3112
#
# Epoch 00055: val_acc did not improve from 0.31280
# Epoch 56/60
# steps before lr change:  5
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0015 - acc: 0.9998 - val_loss: 6.9507 - val_acc: 0.3108
#
# Epoch 00056: val_acc did not improve from 0.31280
# Epoch 57/60
# steps before lr change:  4
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0015 - acc: 0.9999 - val_loss: 6.9580 - val_acc: 0.3102
#
# Epoch 00057: val_acc did not improve from 0.31280
# Epoch 58/60
# steps before lr change:  3
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 74s 102ms/step - loss: 0.0015 - acc: 0.9998 - val_loss: 6.9540 - val_acc: 0.3116
#
# Epoch 00058: val_acc did not improve from 0.31280
# Epoch 59/60
# steps before lr change:  2
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0015 - acc: 0.9997 - val_loss: 6.9512 - val_acc: 0.3108
#
# Epoch 00059: val_acc did not improve from 0.31280
# Epoch 60/60
# steps before lr change:  1
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 75s 103ms/step - loss: 0.0015 - acc: 0.9998 - val_loss: 6.9511 - val_acc: 0.3120
#
# Epoch 00060: val_acc did not improve from 0.31280

# %% [markdown]
# ## Early stopping, learning rate reduction was used, best model was saved

# %%
plot_model(history_SEresnet_34)

# %%
# reload from saved weights:
path='./models/tinyImageNet/SE-resnet_34_best.hdf5' #
from utils.SE_resnet import SE_resnet34
model = SE_resnet34(input_shape=(64,64,3),n_classes=200,name='SE_resnet34')
model.load_weights(path)


model.save('./full_models/tinyImageNet/SE-resnet_34_best.h5')#
del model  # deletes the existing model       #
model = tf.keras.models.load_model('./full_models/tinyImageNet/SE-resnet_34_best.h5')#

# Evaluate the model
from utils.evaluate_model import score
score(model,X_test,y_test,[1,3,5])
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 308/308 - 6s - loss: 6.8804 - acc: 0.3112
# SE_ResNet34
# model accuracy: 31.12%
# top 1 accuracy: 31.122863292694092
# top 3 accuracy: 48.01667928695679
# top 5 accuracy: 55.96013069152832

# %% [markdown]
# ## 2.2  SE-ResNet34 with data augmentation

# %%
from utils.SE_resnet import SE_resnet34

SE_resnet34_aug=SE_resnet34(input_shape=(64,64,3),n_classes=200,name='SE_resnet34_aug')

path='./models/tinyImageNet/SE-resnet_34_aug_best.hdf5'
history_SEresnet_34_aug= tinyImageNet_resnet_train(SE_resnet34_aug,
                          path, #path for weights of best model
                          X_train,y_train,
                          X_val,
                          y_val,
                          data_aug=True, #no data aug
                          learning_rate=0.6, #starting learning rate
                          steps=20, #number of epochs between learning rate modification (* 0.1)
                          epochs=60,
                          batch_size=128,
                          es_patience=20) #early stopping
# Out:
# Epoch 1/60
# steps before lr change:  20
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 129s 171ms/step - loss: 5.5045 - acc: 0.0097 - val_loss: 5.0431 - val_acc: 0.0184
#
# Epoch 00001: val_acc improved from -inf to 0.01840, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 2/60
# steps before lr change:  19
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 123s 170ms/step - loss: 4.9879 - acc: 0.0234 - val_loss: 4.9133 - val_acc: 0.0272
#
# Epoch 00002: val_acc improved from 0.01840 to 0.02720, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 3/60
# steps before lr change:  18
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 123s 169ms/step - loss: 4.6685 - acc: 0.0473 - val_loss: 4.6607 - val_acc: 0.0546
#
# Epoch 00003: val_acc improved from 0.02720 to 0.05460, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 4/60
# steps before lr change:  17
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 123s 170ms/step - loss: 4.3046 - acc: 0.0898 - val_loss: 4.4854 - val_acc: 0.0808
#
# Epoch 00004: val_acc improved from 0.05460 to 0.08080, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 5/60
# steps before lr change:  16
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 3.9757 - acc: 0.1328 - val_loss: 4.2679 - val_acc: 0.1092
#
# Epoch 00005: val_acc improved from 0.08080 to 0.10920, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 6/60
# steps before lr change:  15
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 123s 169ms/step - loss: 3.7620 - acc: 0.1655 - val_loss: 4.1285 - val_acc: 0.1358
#
# Epoch 00006: val_acc improved from 0.10920 to 0.13580, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 7/60
# steps before lr change:  14
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 123s 170ms/step - loss: 3.6107 - acc: 0.1947 - val_loss: 4.0041 - val_acc: 0.1520
#
# Epoch 00007: val_acc improved from 0.13580 to 0.15200, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 8/60
# steps before lr change:  13
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 3.4627 - acc: 0.2204 - val_loss: 4.4528 - val_acc: 0.1184
#
# Epoch 00008: val_acc did not improve from 0.15200
# Epoch 9/60
# steps before lr change:  12
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 3.3967 - acc: 0.2280 - val_loss: 3.6188 - val_acc: 0.1960
#
# Epoch 00009: val_acc improved from 0.15200 to 0.19600, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 10/60
# steps before lr change:  11
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 123s 170ms/step - loss: 3.2459 - acc: 0.2561 - val_loss: 3.7284 - val_acc: 0.1978
#
# Epoch 00010: val_acc improved from 0.19600 to 0.19780, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 11/60
# steps before lr change:  10
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 123s 169ms/step - loss: 3.1366 - acc: 0.2757 - val_loss: 3.3245 - val_acc: 0.2512
#
# Epoch 00011: val_acc improved from 0.19780 to 0.25120, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 12/60
# steps before lr change:  9
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 3.0401 - acc: 0.2947 - val_loss: 3.2139 - val_acc: 0.2736
#
# Epoch 00012: val_acc improved from 0.25120 to 0.27360, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 13/60
# steps before lr change:  8
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 123s 170ms/step - loss: 2.9569 - acc: 0.3098 - val_loss: 3.4986 - val_acc: 0.2460
#
# Epoch 00013: val_acc did not improve from 0.27360
# Epoch 14/60
# steps before lr change:  7
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 125s 171ms/step - loss: 2.8641 - acc: 0.3264 - val_loss: 3.0222 - val_acc: 0.2978
#
# Epoch 00014: val_acc improved from 0.27360 to 0.29780, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 15/60
# steps before lr change:  6
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 2.7719 - acc: 0.3444 - val_loss: 3.2355 - val_acc: 0.2780
#
# Epoch 00015: val_acc did not improve from 0.29780
# Epoch 16/60
# steps before lr change:  5
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 2.7152 - acc: 0.3547 - val_loss: 3.0611 - val_acc: 0.3018
#
# Epoch 00016: val_acc improved from 0.29780 to 0.30180, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 17/60
# steps before lr change:  4
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 2.6387 - acc: 0.3656 - val_loss: 3.1057 - val_acc: 0.2904
#
# Epoch 00017: val_acc did not improve from 0.30180
# Epoch 18/60
# steps before lr change:  3
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 123s 169ms/step - loss: 2.5691 - acc: 0.3795 - val_loss: 3.1664 - val_acc: 0.2902
#
# Epoch 00018: val_acc did not improve from 0.30180
# Epoch 19/60
# steps before lr change:  2
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 2.4934 - acc: 0.3968 - val_loss: 3.0170 - val_acc: 0.3184
#
# Epoch 00019: val_acc improved from 0.30180 to 0.31840, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 20/60
# steps before lr change:  1
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 2.4494 - acc: 0.4044 - val_loss: 3.3454 - val_acc: 0.2750
#
# Epoch 00020: val_acc did not improve from 0.31840
# Epoch 21/60
# steps before lr change:  20
# new learning rate:  0.6000000238418579
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 125s 172ms/step - loss: 2.2094 - acc: 0.4552 - val_loss: 2.6105 - val_acc: 0.3888
#
# Epoch 00021: val_acc improved from 0.31840 to 0.38880, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 22/60
# steps before lr change:  19
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.9890 - acc: 0.5014 - val_loss: 2.6000 - val_acc: 0.3970
#
# Epoch 00022: val_acc improved from 0.38880 to 0.39700, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 23/60
# steps before lr change:  18
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.9329 - acc: 0.5130 - val_loss: 2.6205 - val_acc: 0.3960
#
# Epoch 00023: val_acc did not improve from 0.39700
# Epoch 24/60
# steps before lr change:  17
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 123s 169ms/step - loss: 1.8887 - acc: 0.5217 - val_loss: 2.6062 - val_acc: 0.4008
#
# Epoch 00024: val_acc improved from 0.39700 to 0.40080, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 25/60
# steps before lr change:  16
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.8471 - acc: 0.5334 - val_loss: 2.6248 - val_acc: 0.3952
#
# Epoch 00025: val_acc did not improve from 0.40080
# Epoch 26/60
# steps before lr change:  15
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.8032 - acc: 0.5399 - val_loss: 2.6015 - val_acc: 0.4060
#
# Epoch 00026: val_acc improved from 0.40080 to 0.40600, saving model to ./models/tinyImageNet/SE-resnet_34_aug_best.hdf5
# Epoch 27/60
# steps before lr change:  14
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 125s 171ms/step - loss: 1.7721 - acc: 0.5483 - val_loss: 2.6588 - val_acc: 0.3952
#
# Epoch 00027: val_acc did not improve from 0.40600
# Epoch 28/60
# steps before lr change:  13
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.7340 - acc: 0.5556 - val_loss: 2.6688 - val_acc: 0.4032
#
# Epoch 00028: val_acc did not improve from 0.40600
# Epoch 29/60
# steps before lr change:  12
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.6966 - acc: 0.5625 - val_loss: 2.7097 - val_acc: 0.3944
#
# Epoch 00029: val_acc did not improve from 0.40600
# Epoch 30/60
# steps before lr change:  11
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.6659 - acc: 0.5715 - val_loss: 2.6758 - val_acc: 0.4000
#
# Epoch 00030: val_acc did not improve from 0.40600
# Epoch 31/60
# steps before lr change:  10
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 123s 169ms/step - loss: 1.6264 - acc: 0.5794 - val_loss: 2.7549 - val_acc: 0.3892
#
# Epoch 00031: val_acc did not improve from 0.40600
# Epoch 32/60
# steps before lr change:  9
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 123s 170ms/step - loss: 1.6006 - acc: 0.5848 - val_loss: 2.7411 - val_acc: 0.3980
#
# Epoch 00032: val_acc did not improve from 0.40600
# Epoch 33/60
# steps before lr change:  8
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.5636 - acc: 0.5929 - val_loss: 2.7277 - val_acc: 0.3982
#
# Epoch 00033: val_acc did not improve from 0.40600
# Epoch 34/60
# steps before lr change:  7
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.5126 - acc: 0.6023 - val_loss: 2.7761 - val_acc: 0.3942
#
# Epoch 00034: val_acc did not improve from 0.40600
# Epoch 35/60
# steps before lr change:  6
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 123s 169ms/step - loss: 1.4866 - acc: 0.6086 - val_loss: 2.8748 - val_acc: 0.3870
#
# Epoch 00035: val_acc did not improve from 0.40600
# Epoch 36/60
# steps before lr change:  5
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.4425 - acc: 0.6165 - val_loss: 2.7908 - val_acc: 0.3968
#
# Epoch 00036: val_acc did not improve from 0.40600
# Epoch 37/60
# steps before lr change:  4
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 123s 169ms/step - loss: 1.4065 - acc: 0.6283 - val_loss: 2.8731 - val_acc: 0.3932
#
# Epoch 00037: val_acc did not improve from 0.40600
# Epoch 38/60
# steps before lr change:  3
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 123s 170ms/step - loss: 1.3531 - acc: 0.6375 - val_loss: 2.8464 - val_acc: 0.3974
#
# Epoch 00038: val_acc did not improve from 0.40600
# Epoch 39/60
# steps before lr change:  2
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 123s 169ms/step - loss: 1.3128 - acc: 0.6465 - val_loss: 2.9974 - val_acc: 0.3850
#
# Epoch 00039: val_acc did not improve from 0.40600
# Epoch 40/60
# steps before lr change:  1
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.2873 - acc: 0.6536 - val_loss: 3.1451 - val_acc: 0.3662
#
# Epoch 00040: val_acc did not improve from 0.40600
# Epoch 41/60
# steps before lr change:  20
# new learning rate:  0.06000000238418579
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.006000000238418579.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.1993 - acc: 0.6742 - val_loss: 2.9065 - val_acc: 0.4008
#
# Epoch 00041: val_acc did not improve from 0.40600
# Epoch 42/60
# steps before lr change:  19
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.1042 - acc: 0.6992 - val_loss: 2.9430 - val_acc: 0.4020
#
# Epoch 00042: val_acc did not improve from 0.40600
# Epoch 43/60
# steps before lr change:  18
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 124s 171ms/step - loss: 1.0689 - acc: 0.7093 - val_loss: 2.9775 - val_acc: 0.4030
#
# Epoch 00043: val_acc did not improve from 0.40600
# Epoch 44/60
# steps before lr change:  17
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 124s 170ms/step - loss: 1.0581 - acc: 0.7124 - val_loss: 2.9954 - val_acc: 0.4046
#
# Epoch 00044: val_acc did not improve from 0.40600
# Epoch 45/60
# steps before lr change:  16
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 123s 170ms/step - loss: 1.0321 - acc: 0.7171 - val_loss: 3.0154 - val_acc: 0.4014
#
# Epoch 00045: val_acc did not improve from 0.40600
# Epoch 46/60
# steps before lr change:  15
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 123s 169ms/step - loss: 1.0127 - acc: 0.7233 - val_loss: 3.0347 - val_acc: 0.3984
#
# Epoch 00046: val_acc did not improve from 0.40600

# %% [markdown]
# ## Early stopping, learning rate reduction was used, best model was saved

# %%
plot_model(history_SEresnet_34_aug)

# %%
# reload from saved weights:
from utils.SE_resnet import SE_resnet34
path='./models/tinyImageNet/SE-resnet_34_aug_best.hdf5' #
model = SE_resnet34(input_shape=(64,64,3),n_classes=200,name='SE_resnet34_aug')
model.load_weights(path)

model.save('./full_models/tinyImageNet/SE-resnet_34_aug_best.h5')#
del model  # deletes the existing model       #
model = tf.keras.models.load_model('./full_models/tinyImageNet/SE-resnet_34_aug_best.h5')#

# Evaluate the model
from utils.evaluate_model import score
score(model,X_test,y_test,[1,3,5])
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 308/308 - 6s - loss: 2.5866 - acc: 0.4138
# SE_ResNet34
# model accuracy: 41.38%
# top 1 accuracy: 41.37510061264038
# top 3 accuracy: 59.06224846839905
# top 5 accuracy: 67.28031039237976
