# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
from tensorflow.python.client import device_lib
def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]
print(get_available_devices()) 

import os
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# ['/device:CPU:0', '/device:GPU:0']

# %% [markdown]
# # 0. Loading the data

# %% [markdown]
# ### TinyImageNet does not have labels for the testing data. We will use the 10k validation images for the testing data.

# %%
from tensorflow.keras.utils import to_categorical  

#load cifar-10 dataset
(X_tot, y_tot), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
#one hot encoding
y_test=to_categorical(y_test, num_classes=10)
y_tot=to_categorical(y_tot, num_classes=10)

print(X_tot.shape)
print(y_tot.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)
# (10000, 32, 32, 3)
# (10000, 10)

# %%
#shuffle data and split data to generate validation data
shuffler = np.random.RandomState(seed=42).permutation(len(X_tot))
X_tot = X_tot[shuffler]
y_tot = y_tot[shuffler]
 

#validation data
X_val=X_tot[0:2000]
y_val=y_tot[0:2000]

X_train=X_tot[2000:]
y_train=y_tot[2000:]

# %% [markdown]
# # 1. Using ResNet with ImageNet

# %% [markdown]
# ### We use our custom resnet model generator to get any resnet
#
# CIFAR 10 has 10 different labels

# %% [markdown]
# We use a custom resnet model, because the images are 32x32 we do not need to go as deep to get good results.The CNN layers go to 2x2 resolution instead to 1x1 in a traditional resnet model.

# %%
from utils.custom_resnet import custom_resnet
from utils.train_CIFAR_ResNet import cifar_resnet_train
# tinyImageNet_resnet_train(model,path,X_train,y_train,X_val,y_val,data_aug=False,learning_rate=0.6,steps=14,epochs=45,batch_size=128,es_patience=8)
resnet_46=custom_resnet(res_model=[[[3,3],[64,64],4],[[3,3],[128,128],6],[[1,3,1],[256,256,1024],8]],custom_input=(32,32,3),n_classes=10)
resnet_46.summary()
#tf.keras.utils.plot_model(resnet_18, to_file='test.png',show_shapes=True)
# Out:
# Model: "custom_resnet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        input_9[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 16, 16, 64)   0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 8, 8, 64)     0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 8, 8, 64)     36928       pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 8, 8, 64)     36928       pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 8, 8, 64)     0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 8, 8, 64)     0           conv2_block1_relu[0][0]
#                                                                  conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 8, 8, 64)     0           conv2_block2_relu[0][0]
#                                                                  conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block3_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_add (Add)          (None, 8, 8, 64)     0           conv2_block3_relu[0][0]
#                                                                  conv2_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block4_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 4, 4, 128)    0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 4, 4, 128)    0           conv3_block1_relu[0][0]
#                                                                  conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 4, 4, 128)    0           conv3_block2_relu[0][0]
#                                                                  conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 4, 4, 128)    0           conv3_block3_relu[0][0]
#                                                                  conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_add (Add)          (None, 4, 4, 128)    0           conv3_block4_relu[0][0]
#                                                                  conv3_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block5_add[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_add (Add)          (None, 4, 4, 128)    0           conv3_block5_relu[0][0]
#                                                                  conv3_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block6_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 2, 2, 256)    33024       conv3_block6_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 2, 2, 1024)   132096      conv3_block6_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_relu[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 2, 2, 1024)   0           conv4_block2_relu[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 2, 2, 1024)   0           conv4_block3_relu[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block4_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 2, 2, 1024)   0           conv4_block4_relu[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block5_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 2, 2, 1024)   0           conv4_block5_relu[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block6_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_add (Add)          (None, 2, 2, 1024)   0           conv4_block6_relu[0][0]
#                                                                  conv4_block7_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block7_add[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block7_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, 2, 2, 1024)   0           conv4_block7_relu[0][0]
#                                                                  conv4_block8_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block8_add[0][0]
# __________________________________________________________________________________________________
# pool_out (GlobalAveragePooling2 (None, 1024)         0           conv4_block8_relu[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 10)           10250       pool_out[0][0]
# ==================================================================================================
# Total params: 11,013,578
# Trainable params: 10,982,346
# Non-trainable params: 31,232
# __________________________________________________________________________________________________

# %% [markdown]
# ## 1.1 Resnet

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler,ModelCheckpoint,ReduceLROnPlateau
import matplotlib.pyplot as plt

path='./models/cifar10/resnet_18_best.hdf5'
train_datagen = ImageDataGenerator(
        horizontal_flip=True,
        width_shift_range=4, #+-8 pixel shift max
        height_shift_range=4)#+-8 pixel shift max


reduce_lr = ReduceLROnPlateau(monitor='val_acc', mode='max',factor=0.1,
                              patience=5, min_lr=0.001, verbose=1)

#Early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_acc', mode='max', patience=10)
# checkpoints
checkpoint = ModelCheckpoint(path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
resnet_46.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01,momentum=0.9),loss='categorical_crossentropy', metrics = ['acc'])


train_generator = train_datagen.flow(X_train, y_train, batch_size=128)
step_size_train=train_generator.n//train_generator.batch_size

history=resnet_46.fit(train_generator,
                    steps_per_epoch=step_size_train,
                    epochs=200,
                    validation_data=(X_val,y_val),
                    callbacks=[reduce_lr,es,checkpoint])
# Out:
# Epoch 1/200
# 375/375 [==============================] - 23s 53ms/step - loss: 3.7163 - acc: 0.2009 - val_loss: 1.7420 - val_acc: 0.3485
#
# Epoch 00001: val_acc improved from -inf to 0.34850, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 2/200
# 375/375 [==============================] - 19s 52ms/step - loss: 1.6566 - acc: 0.4096 - val_loss: 1.5096 - val_acc: 0.4545
#
# Epoch 00002: val_acc improved from 0.34850 to 0.45450, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 3/200
# 375/375 [==============================] - 19s 51ms/step - loss: 1.4398 - acc: 0.4825 - val_loss: 1.3209 - val_acc: 0.5260
#
# Epoch 00003: val_acc improved from 0.45450 to 0.52600, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 4/200
# 375/375 [==============================] - 19s 52ms/step - loss: 1.3209 - acc: 0.5317 - val_loss: 1.6396 - val_acc: 0.4570
#
# Epoch 00004: val_acc did not improve from 0.52600
# Epoch 5/200
# 375/375 [==============================] - 20s 53ms/step - loss: 1.2371 - acc: 0.5669 - val_loss: 1.3747 - val_acc: 0.5035
#
# Epoch 00005: val_acc did not improve from 0.52600
# Epoch 6/200
# 375/375 [==============================] - 20s 52ms/step - loss: 1.1542 - acc: 0.5951 - val_loss: 1.0799 - val_acc: 0.6140
#
# Epoch 00006: val_acc improved from 0.52600 to 0.61400, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 7/200
# 375/375 [==============================] - 20s 52ms/step - loss: 1.0744 - acc: 0.6203 - val_loss: 1.1387 - val_acc: 0.5880
#
# Epoch 00007: val_acc did not improve from 0.61400
# Epoch 8/200
# 375/375 [==============================] - 20s 52ms/step - loss: 1.0079 - acc: 0.6444 - val_loss: 1.1145 - val_acc: 0.6070
#
# Epoch 00008: val_acc did not improve from 0.61400
# Epoch 9/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.9530 - acc: 0.6681 - val_loss: 0.9101 - val_acc: 0.6730
#
# Epoch 00009: val_acc improved from 0.61400 to 0.67300, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 10/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.9487 - acc: 0.6668 - val_loss: 1.0534 - val_acc: 0.6450
#
# Epoch 00010: val_acc did not improve from 0.67300
# Epoch 11/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.8817 - acc: 0.6908 - val_loss: 0.9508 - val_acc: 0.6710
#
# Epoch 00011: val_acc did not improve from 0.67300
# Epoch 12/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.8204 - acc: 0.7096 - val_loss: 0.9988 - val_acc: 0.6600
#
# Epoch 00012: val_acc did not improve from 0.67300
# Epoch 13/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.7989 - acc: 0.7191 - val_loss: 0.8375 - val_acc: 0.7055
#
# Epoch 00013: val_acc improved from 0.67300 to 0.70550, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 14/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.7740 - acc: 0.7302 - val_loss: 0.9359 - val_acc: 0.6880
#
# Epoch 00014: val_acc did not improve from 0.70550
# Epoch 15/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.7394 - acc: 0.7381 - val_loss: 0.9169 - val_acc: 0.6885
#
# Epoch 00015: val_acc did not improve from 0.70550
# Epoch 16/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.7447 - acc: 0.7409 - val_loss: 0.8787 - val_acc: 0.6905
#
# Epoch 00016: val_acc did not improve from 0.70550
# Epoch 17/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.7016 - acc: 0.7550 - val_loss: 1.0198 - val_acc: 0.6805
#
# Epoch 00017: val_acc did not improve from 0.70550
# Epoch 18/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.6654 - acc: 0.7661 - val_loss: 0.7953 - val_acc: 0.7270
#
# Epoch 00018: val_acc improved from 0.70550 to 0.72700, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 19/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.6412 - acc: 0.7753 - val_loss: 0.8024 - val_acc: 0.7245
#
# Epoch 00019: val_acc did not improve from 0.72700
# Epoch 20/200
# 375/375 [==============================] - 20s 52ms/step - loss: 0.6460 - acc: 0.7742 - val_loss: 0.7737 - val_acc: 0.7410
#
# Epoch 00020: val_acc improved from 0.72700 to 0.74100, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 21/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.5991 - acc: 0.7929 - val_loss: 0.7102 - val_acc: 0.7570
#
# Epoch 00021: val_acc improved from 0.74100 to 0.75700, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 22/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.5785 - acc: 0.7982 - val_loss: 0.7307 - val_acc: 0.7480
#
# Epoch 00022: val_acc did not improve from 0.75700
# Epoch 23/200
# 375/375 [==============================] - 20s 52ms/step - loss: 0.5718 - acc: 0.8001 - val_loss: 0.8444 - val_acc: 0.7235
#
# Epoch 00023: val_acc did not improve from 0.75700
# Epoch 24/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.5475 - acc: 0.8060 - val_loss: 0.8116 - val_acc: 0.7430
#
# Epoch 00024: val_acc did not improve from 0.75700
# Epoch 25/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.5153 - acc: 0.8210 - val_loss: 0.9047 - val_acc: 0.7495
#
# Epoch 00025: val_acc did not improve from 0.75700
# Epoch 26/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.5195 - acc: 0.8144 - val_loss: 0.6687 - val_acc: 0.7780
#
# Epoch 00026: val_acc improved from 0.75700 to 0.77800, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 27/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.4937 - acc: 0.8275 - val_loss: 0.8743 - val_acc: 0.7170
#
# Epoch 00027: val_acc did not improve from 0.77800
# Epoch 28/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.4855 - acc: 0.8318 - val_loss: 0.6814 - val_acc: 0.7690
#
# Epoch 00028: val_acc did not improve from 0.77800
# Epoch 29/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.4691 - acc: 0.8386 - val_loss: 0.7133 - val_acc: 0.7690
#
# Epoch 00029: val_acc did not improve from 0.77800
# Epoch 30/200
# 375/375 [==============================] - 20s 52ms/step - loss: 0.4611 - acc: 0.8384 - val_loss: 0.6402 - val_acc: 0.7890
#
# Epoch 00030: val_acc improved from 0.77800 to 0.78900, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 31/200
# 375/375 [==============================] - 20s 52ms/step - loss: 0.4305 - acc: 0.8469 - val_loss: 0.7124 - val_acc: 0.7675
#
# Epoch 00031: val_acc did not improve from 0.78900
# Epoch 32/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.4252 - acc: 0.8506 - val_loss: 0.8103 - val_acc: 0.7605
#
# Epoch 00032: val_acc did not improve from 0.78900
# Epoch 33/200
# 375/375 [==============================] - 20s 52ms/step - loss: 0.4110 - acc: 0.8570 - val_loss: 0.6321 - val_acc: 0.7945
#
# Epoch 00033: val_acc improved from 0.78900 to 0.79450, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 34/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.3971 - acc: 0.8618 - val_loss: 0.6515 - val_acc: 0.7915
#
# Epoch 00034: val_acc did not improve from 0.79450
# Epoch 35/200
# 375/375 [==============================] - 20s 52ms/step - loss: 0.3802 - acc: 0.8658 - val_loss: 0.6418 - val_acc: 0.7985
#
# Epoch 00035: val_acc improved from 0.79450 to 0.79850, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 36/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.3837 - acc: 0.8638 - val_loss: 0.6406 - val_acc: 0.7875
#
# Epoch 00036: val_acc did not improve from 0.79850
# Epoch 37/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.3576 - acc: 0.8758 - val_loss: 0.6513 - val_acc: 0.7880
#
# Epoch 00037: val_acc did not improve from 0.79850
# Epoch 38/200
# 375/375 [==============================] - 20s 52ms/step - loss: 0.3560 - acc: 0.8744 - val_loss: 0.6043 - val_acc: 0.8140
#
# Epoch 00038: val_acc improved from 0.79850 to 0.81400, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 39/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.3355 - acc: 0.8838 - val_loss: 0.7000 - val_acc: 0.7820
#
# Epoch 00039: val_acc did not improve from 0.81400
# Epoch 40/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.3431 - acc: 0.8794 - val_loss: 0.7200 - val_acc: 0.7805
#
# Epoch 00040: val_acc did not improve from 0.81400
# Epoch 41/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.3308 - acc: 0.8828 - val_loss: 0.6623 - val_acc: 0.7905
#
# Epoch 00041: val_acc did not improve from 0.81400
# Epoch 42/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.3246 - acc: 0.8858 - val_loss: 0.8193 - val_acc: 0.7965
#
# Epoch 00042: val_acc did not improve from 0.81400
# Epoch 43/200
# 375/375 [==============================] - 20s 52ms/step - loss: 0.3051 - acc: 0.8930 - val_loss: 0.6332 - val_acc: 0.8110
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00043: val_acc did not improve from 0.81400
# Epoch 44/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.2686 - acc: 0.9073 - val_loss: 0.5433 - val_acc: 0.8375
#
# Epoch 00044: val_acc improved from 0.81400 to 0.83750, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 45/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.1982 - acc: 0.9313 - val_loss: 0.5731 - val_acc: 0.8360
#
# Epoch 00045: val_acc did not improve from 0.83750
# Epoch 46/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.1875 - acc: 0.9367 - val_loss: 0.5755 - val_acc: 0.8330
#
# Epoch 00046: val_acc did not improve from 0.83750
# Epoch 47/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.1675 - acc: 0.9442 - val_loss: 0.5747 - val_acc: 0.8385
#
# Epoch 00047: val_acc improved from 0.83750 to 0.83850, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 48/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.1687 - acc: 0.9426 - val_loss: 0.5982 - val_acc: 0.8375
#
# Epoch 00048: val_acc did not improve from 0.83850
# Epoch 49/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.1537 - acc: 0.9461 - val_loss: 0.6135 - val_acc: 0.8360
#
# Epoch 00049: val_acc did not improve from 0.83850
# Epoch 50/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.1539 - acc: 0.9480 - val_loss: 0.6200 - val_acc: 0.8315
#
# Epoch 00050: val_acc did not improve from 0.83850
# Epoch 51/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.1446 - acc: 0.9507 - val_loss: 0.6236 - val_acc: 0.8355
#
# Epoch 00051: val_acc did not improve from 0.83850
# Epoch 52/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.1416 - acc: 0.9520 - val_loss: 0.6440 - val_acc: 0.8390
#
# Epoch 00052: val_acc improved from 0.83850 to 0.83900, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 53/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.1368 - acc: 0.9535 - val_loss: 0.6313 - val_acc: 0.8360
#
# Epoch 00053: val_acc did not improve from 0.83900
# Epoch 54/200
# 375/375 [==============================] - 20s 52ms/step - loss: 0.1315 - acc: 0.9545 - val_loss: 0.6449 - val_acc: 0.8355
#
# Epoch 00054: val_acc did not improve from 0.83900
# Epoch 55/200
# 375/375 [==============================] - 20s 52ms/step - loss: 0.1286 - acc: 0.9571 - val_loss: 0.6451 - val_acc: 0.8345
#
# Epoch 00055: val_acc did not improve from 0.83900
# Epoch 56/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.1316 - acc: 0.9564 - val_loss: 0.6453 - val_acc: 0.8400
#
# Epoch 00056: val_acc improved from 0.83900 to 0.84000, saving model to ./models/cifar10/resnet_18_best.hdf5
# Epoch 57/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.1267 - acc: 0.9586 - val_loss: 0.6499 - val_acc: 0.8340
#
# Epoch 00057: val_acc did not improve from 0.84000
# Epoch 58/200
# 375/375 [==============================] - 20s 52ms/step - loss: 0.1181 - acc: 0.9606 - val_loss: 0.6506 - val_acc: 0.8370
#
# Epoch 00058: val_acc did not improve from 0.84000
# Epoch 59/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.1173 - acc: 0.9593 - val_loss: 0.6746 - val_acc: 0.8335
#
# Epoch 00059: val_acc did not improve from 0.84000
# Epoch 60/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.1095 - acc: 0.9635 - val_loss: 0.7035 - val_acc: 0.8350
#
# Epoch 00060: val_acc did not improve from 0.84000
# Epoch 61/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.1137 - acc: 0.9611 - val_loss: 0.6869 - val_acc: 0.8330
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00061: val_acc did not improve from 0.84000
# Epoch 62/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.1094 - acc: 0.9640 - val_loss: 0.6934 - val_acc: 0.8365
#
# Epoch 00062: val_acc did not improve from 0.84000
# Epoch 63/200
# 375/375 [==============================] - 20s 52ms/step - loss: 0.1017 - acc: 0.9663 - val_loss: 0.6948 - val_acc: 0.8325
#
# Epoch 00063: val_acc did not improve from 0.84000
# Epoch 64/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.1039 - acc: 0.9652 - val_loss: 0.7049 - val_acc: 0.8365
#
# Epoch 00064: val_acc did not improve from 0.84000
# Epoch 65/200
# 375/375 [==============================] - 19s 51ms/step - loss: 0.1008 - acc: 0.9650 - val_loss: 0.7030 - val_acc: 0.8270
#
# Epoch 00065: val_acc did not improve from 0.84000
# Epoch 66/200
# 375/375 [==============================] - 19s 52ms/step - loss: 0.0974 - acc: 0.9674 - val_loss: 0.7162 - val_acc: 0.8315
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00066: val_acc did not improve from 0.84000

# %% [markdown]
# ## Best model weights was saved

# %% [markdown]
# Accuracy and loss graphs

# %%
from utils.train_CIFAR_ResNet import plot_model
plot_model(history)

# %%
from utils.custom_resnet import custom_resnet
# reload from saved weights:

model=custom_resnet(res_model=[[[3,3],[64,64],4],[[3,3],[128,128],6],[[1,3,1],[256,256,1024],8]],custom_input=(32,32,3),n_classes=10)
model.load_weights(path)

if not os.path.exists('./full_models/cifar10'):
    os.makedirs('./full_models/cifar10')
model.save('./full_models/cifar10/resnet_best.h5')
del model  # deletes the existing model
model = tf.keras.models.load_model('./full_models/cifar10/resnet_best.h5')

score(model,X_test,y_test,top_n=[3,5])
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 313/313 - 6s - loss: 0.7722 - acc: 0.8070
# custom_resnet
# model accuracy: 80.70%
# top 3 accuracy: 95.85999846458435
# top 5 accuracy: 98.7500011920929

# %% [markdown]
# ## 1.2 SE-Resnet

# %%
from utils.SE_resnet import SE_custom_resnet

SE_resnet=SE_custom_resnet(res_model=[[[3,3],[64,64],4],[[3,3],[128,128],6],[[1,3,1],[256,256,1024],8]],custom_input=(32,32,3),n_classes=10,ratio=16,model_name='custom_resnet46',debug=False)
SE_resnet.summary()
# Out:
# Model: "SE_custom_resnet46"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        input_11[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[1][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 16, 16, 64)   0           conv1_bn[1][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 8, 8, 64)     0           conv1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 8, 8, 64)     36928       pool1[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_squeeze (Global (None, 64)           0           conv2_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_fc1 (Dense)     (None, 4)            260         conv2_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_fc2 (Dense)     (None, 64)           320         conv2_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 8, 8, 64)     36928       pool1[1][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None, 1, 1, 64)     0           conv2_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block1_2_bn[1][0]
#                                                                  tf.reshape[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 8, 8, 64)     0           conv2_block1_0_bn[1][0]
#                                                                  conv2_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block1_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block1_add[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_squeeze (Global (None, 64)           0           conv2_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_fc1 (Dense)     (None, 4)            260         conv2_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_fc2 (Dense)     (None, 64)           320         conv2_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_1 (TFOpLambda)       (None, 1, 1, 64)     0           conv2_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block2_2_bn[1][0]
#                                                                  tf.reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 8, 8, 64)     0           conv2_block1_relu[1][0]
#                                                                  conv2_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block2_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block2_add[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_squeeze (Global (None, 64)           0           conv2_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_fc1 (Dense)     (None, 4)            260         conv2_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_fc2 (Dense)     (None, 64)           320         conv2_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_2 (TFOpLambda)       (None, 1, 1, 64)     0           conv2_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block3_2_bn[1][0]
#                                                                  tf.reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 8, 8, 64)     0           conv2_block2_relu[1][0]
#                                                                  conv2_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block3_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block3_add[1][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block4_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_squeeze (Global (None, 64)           0           conv2_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_fc1 (Dense)     (None, 4)            260         conv2_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_fc2 (Dense)     (None, 64)           320         conv2_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_3 (TFOpLambda)       (None, 1, 1, 64)     0           conv2_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block4_2_bn[1][0]
#                                                                  tf.reshape_3[0][0]
# __________________________________________________________________________________________________
# conv2_block4_add (Add)          (None, 8, 8, 64)     0           conv2_block3_relu[1][0]
#                                                                  conv2_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block4_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block4_add[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_squeeze (Global (None, 128)          0           conv3_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc1 (Dense)     (None, 8)            1032        conv3_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc2 (Dense)     (None, 128)          1152        conv3_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_4 (TFOpLambda)       (None, 1, 1, 128)    0           conv3_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block1_2_bn[1][0]
#                                                                  tf.reshape_4[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 4, 4, 128)    0           conv3_block1_0_bn[1][0]
#                                                                  conv3_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block1_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block1_add[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_squeeze (Global (None, 128)          0           conv3_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc1 (Dense)     (None, 8)            1032        conv3_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc2 (Dense)     (None, 128)          1152        conv3_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_5 (TFOpLambda)       (None, 1, 1, 128)    0           conv3_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block2_2_bn[1][0]
#                                                                  tf.reshape_5[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 4, 4, 128)    0           conv3_block1_relu[1][0]
#                                                                  conv3_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block2_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block2_add[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_squeeze (Global (None, 128)          0           conv3_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc1 (Dense)     (None, 8)            1032        conv3_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc2 (Dense)     (None, 128)          1152        conv3_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_6 (TFOpLambda)       (None, 1, 1, 128)    0           conv3_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block3_2_bn[1][0]
#                                                                  tf.reshape_6[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 4, 4, 128)    0           conv3_block2_relu[1][0]
#                                                                  conv3_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block3_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block3_add[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_squeeze (Global (None, 128)          0           conv3_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc1 (Dense)     (None, 8)            1032        conv3_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc2 (Dense)     (None, 128)          1152        conv3_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_7 (TFOpLambda)       (None, 1, 1, 128)    0           conv3_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block4_2_bn[1][0]
#                                                                  tf.reshape_7[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 4, 4, 128)    0           conv3_block3_relu[1][0]
#                                                                  conv3_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block4_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block4_add[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block5_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block5_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_squeeze (Global (None, 128)          0           conv3_block5_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_fc1 (Dense)     (None, 8)            1032        conv3_block5_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_fc2 (Dense)     (None, 128)          1152        conv3_block5_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_8 (TFOpLambda)       (None, 1, 1, 128)    0           conv3_block5_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block5_2_bn[1][0]
#                                                                  tf.reshape_8[0][0]
# __________________________________________________________________________________________________
# conv3_block5_add (Add)          (None, 4, 4, 128)    0           conv3_block4_relu[1][0]
#                                                                  conv3_block5_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block5_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block5_add[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block6_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block6_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block6_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_squeeze (Global (None, 128)          0           conv3_block6_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_fc1 (Dense)     (None, 8)            1032        conv3_block6_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_fc2 (Dense)     (None, 128)          1152        conv3_block6_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_9 (TFOpLambda)       (None, 1, 1, 128)    0           conv3_block6_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block6_2_bn[1][0]
#                                                                  tf.reshape_9[0][0]
# __________________________________________________________________________________________________
# conv3_block6_add (Add)          (None, 4, 4, 128)    0           conv3_block5_relu[1][0]
#                                                                  conv3_block6_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block6_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block6_add[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 2, 2, 256)    33024       conv3_block6_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block1_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_squeeze (Global (None, 1024)         0           conv4_block1_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc1 (Dense)     (None, 64)           65600       conv4_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc2 (Dense)     (None, 1024)         66560       conv4_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 2, 2, 1024)   132096      conv3_block6_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_10 (TFOpLambda)      (None, 1, 1, 1024)   0           conv4_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block1_3_bn[1][0]
#                                                                  tf.reshape_10[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_0_bn[1][0]
#                                                                  conv4_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block1_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block1_add[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block2_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block2_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_squeeze (Global (None, 1024)         0           conv4_block2_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc1 (Dense)     (None, 64)           65600       conv4_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc2 (Dense)     (None, 1024)         66560       conv4_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_11 (TFOpLambda)      (None, 1, 1, 1024)   0           conv4_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block2_3_bn[1][0]
#                                                                  tf.reshape_11[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_relu[1][0]
#                                                                  conv4_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block2_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block2_add[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block3_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block3_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_squeeze (Global (None, 1024)         0           conv4_block3_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc1 (Dense)     (None, 64)           65600       conv4_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc2 (Dense)     (None, 1024)         66560       conv4_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_12 (TFOpLambda)      (None, 1, 1, 1024)   0           conv4_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block3_3_bn[1][0]
#                                                                  tf.reshape_12[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 2, 2, 1024)   0           conv4_block2_relu[1][0]
#                                                                  conv4_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block3_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block3_add[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block4_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block4_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_squeeze (Global (None, 1024)         0           conv4_block4_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc1 (Dense)     (None, 64)           65600       conv4_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc2 (Dense)     (None, 1024)         66560       conv4_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_13 (TFOpLambda)      (None, 1, 1, 1024)   0           conv4_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block4_3_bn[1][0]
#                                                                  tf.reshape_13[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 2, 2, 1024)   0           conv4_block3_relu[1][0]
#                                                                  conv4_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block4_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block4_add[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block5_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block5_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block5_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_squeeze (Global (None, 1024)         0           conv4_block5_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc1 (Dense)     (None, 64)           65600       conv4_block5_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc2 (Dense)     (None, 1024)         66560       conv4_block5_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_14 (TFOpLambda)      (None, 1, 1, 1024)   0           conv4_block5_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block5_3_bn[1][0]
#                                                                  tf.reshape_14[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 2, 2, 1024)   0           conv4_block4_relu[1][0]
#                                                                  conv4_block5_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block5_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block5_add[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block5_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block6_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block6_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block6_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_squeeze (Global (None, 1024)         0           conv4_block6_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc1 (Dense)     (None, 64)           65600       conv4_block6_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc2 (Dense)     (None, 1024)         66560       conv4_block6_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_15 (TFOpLambda)      (None, 1, 1, 1024)   0           conv4_block6_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block6_3_bn[1][0]
#                                                                  tf.reshape_15[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 2, 2, 1024)   0           conv4_block5_relu[1][0]
#                                                                  conv4_block6_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block6_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block6_add[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block6_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block7_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block7_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block7_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block7_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block7_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block7_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block7_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block7_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block7_SE_squeeze (Global (None, 1024)         0           conv4_block7_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block7_SE_fc1 (Dense)     (None, 64)           65600       conv4_block7_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block7_SE_fc2 (Dense)     (None, 1024)         66560       conv4_block7_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_16 (TFOpLambda)      (None, 1, 1, 1024)   0           conv4_block7_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block7_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block7_3_bn[1][0]
#                                                                  tf.reshape_16[0][0]
# __________________________________________________________________________________________________
# conv4_block7_add (Add)          (None, 2, 2, 1024)   0           conv4_block6_relu[1][0]
#                                                                  conv4_block7_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block7_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block7_add[1][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block7_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block8_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block8_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block8_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block8_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block8_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block8_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block8_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_squeeze (Global (None, 1024)         0           conv4_block8_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_fc1 (Dense)     (None, 64)           65600       conv4_block8_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_fc2 (Dense)     (None, 1024)         66560       conv4_block8_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_17 (TFOpLambda)      (None, 1, 1, 1024)   0           conv4_block8_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block8_3_bn[1][0]
#                                                                  tf.reshape_17[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, 2, 2, 1024)   0           conv4_block7_relu[1][0]
#                                                                  conv4_block8_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block8_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block8_add[1][0]
# __________________________________________________________________________________________________
# pool_out (GlobalAveragePooling2 (None, 1024)         0           conv4_block8_relu[1][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 10)           10250       pool_out[1][0]
# ==================================================================================================
# Total params: 12,086,282
# Trainable params: 12,055,050
# Non-trainable params: 31,232
# __________________________________________________________________________________________________

# %%
path='./models/cifar10/se_resnet_best.hdf5'
train_datagen = ImageDataGenerator(
        horizontal_flip=True,
        width_shift_range=4, #+-8 pixel shift max
        height_shift_range=4)#+-8 pixel shift max


reduce_lr = ReduceLROnPlateau(monitor='val_acc', mode='max',factor=0.1,
                              patience=5, min_lr=0.001, verbose=1)

#Early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_acc', mode='max', patience=10)
# checkpoints
checkpoint = ModelCheckpoint(path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
SE_resnet.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01,momentum=0.9),loss='categorical_crossentropy', metrics = ['acc'])


train_generator = train_datagen.flow(X_train, y_train, batch_size=128)
step_size_train=train_generator.n//train_generator.batch_size

history=SE_resnet.fit(train_generator,
                    steps_per_epoch=step_size_train,
                    epochs=200,
                    validation_data=(X_val,y_val),
                    callbacks=[reduce_lr,es,checkpoint])
# Out:
# Epoch 1/200
# 375/375 [==============================] - 28s 60ms/step - loss: 2.1084 - acc: 0.3106 - val_loss: 1.5016 - val_acc: 0.4520
#
# Epoch 00001: val_acc improved from -inf to 0.45200, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 2/200
# 375/375 [==============================] - 22s 57ms/step - loss: 1.4222 - acc: 0.4986 - val_loss: 1.4695 - val_acc: 0.4880
#
# Epoch 00002: val_acc improved from 0.45200 to 0.48800, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 3/200
# 375/375 [==============================] - 21s 57ms/step - loss: 1.2026 - acc: 0.5724 - val_loss: 1.3612 - val_acc: 0.5035
#
# Epoch 00003: val_acc improved from 0.48800 to 0.50350, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 4/200
# 375/375 [==============================] - 21s 57ms/step - loss: 1.0711 - acc: 0.6219 - val_loss: 1.0842 - val_acc: 0.6130
#
# Epoch 00004: val_acc improved from 0.50350 to 0.61300, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 5/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.9418 - acc: 0.6663 - val_loss: 1.2039 - val_acc: 0.6060
#
# Epoch 00005: val_acc did not improve from 0.61300
# Epoch 6/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.8607 - acc: 0.7009 - val_loss: 0.8763 - val_acc: 0.7020
#
# Epoch 00006: val_acc improved from 0.61300 to 0.70200, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 7/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.8047 - acc: 0.7173 - val_loss: 1.1737 - val_acc: 0.6165
#
# Epoch 00007: val_acc did not improve from 0.70200
# Epoch 8/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.7483 - acc: 0.7342 - val_loss: 0.8258 - val_acc: 0.7120
#
# Epoch 00008: val_acc improved from 0.70200 to 0.71200, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 9/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.6935 - acc: 0.7559 - val_loss: 0.7402 - val_acc: 0.7365
#
# Epoch 00009: val_acc improved from 0.71200 to 0.73650, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 10/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.6638 - acc: 0.7650 - val_loss: 0.9875 - val_acc: 0.6705
#
# Epoch 00010: val_acc did not improve from 0.73650
# Epoch 11/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.6358 - acc: 0.7743 - val_loss: 0.7124 - val_acc: 0.7565
#
# Epoch 00011: val_acc improved from 0.73650 to 0.75650, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 12/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.6135 - acc: 0.7805 - val_loss: 0.7417 - val_acc: 0.7480
#
# Epoch 00012: val_acc did not improve from 0.75650
# Epoch 13/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.5804 - acc: 0.7937 - val_loss: 0.7529 - val_acc: 0.7415
#
# Epoch 00013: val_acc did not improve from 0.75650
# Epoch 14/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.5580 - acc: 0.8027 - val_loss: 0.6976 - val_acc: 0.7625
#
# Epoch 00014: val_acc improved from 0.75650 to 0.76250, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 15/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.5314 - acc: 0.8133 - val_loss: 0.8920 - val_acc: 0.7185
#
# Epoch 00015: val_acc did not improve from 0.76250
# Epoch 16/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.5226 - acc: 0.8166 - val_loss: 0.6881 - val_acc: 0.7675
#
# Epoch 00016: val_acc improved from 0.76250 to 0.76750, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 17/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.4938 - acc: 0.8255 - val_loss: 0.5996 - val_acc: 0.7975
#
# Epoch 00017: val_acc improved from 0.76750 to 0.79750, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 18/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.4823 - acc: 0.8304 - val_loss: 0.8675 - val_acc: 0.7185
#
# Epoch 00018: val_acc did not improve from 0.79750
# Epoch 19/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.4591 - acc: 0.8370 - val_loss: 0.7144 - val_acc: 0.7650
#
# Epoch 00019: val_acc did not improve from 0.79750
# Epoch 20/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.4329 - acc: 0.8463 - val_loss: 0.6323 - val_acc: 0.7850
#
# Epoch 00020: val_acc did not improve from 0.79750
# Epoch 21/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.4147 - acc: 0.8554 - val_loss: 0.7056 - val_acc: 0.7680
#
# Epoch 00021: val_acc did not improve from 0.79750
# Epoch 22/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.4044 - acc: 0.8569 - val_loss: 0.7072 - val_acc: 0.7715
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00022: val_acc did not improve from 0.79750
# Epoch 23/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.3682 - acc: 0.8718 - val_loss: 0.4836 - val_acc: 0.8335
#
# Epoch 00023: val_acc improved from 0.79750 to 0.83350, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 24/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.2916 - acc: 0.8989 - val_loss: 0.4963 - val_acc: 0.8385
#
# Epoch 00024: val_acc improved from 0.83350 to 0.83850, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 25/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.2758 - acc: 0.9030 - val_loss: 0.4924 - val_acc: 0.8395
#
# Epoch 00025: val_acc improved from 0.83850 to 0.83950, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 26/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.2687 - acc: 0.9061 - val_loss: 0.4943 - val_acc: 0.8430
#
# Epoch 00026: val_acc improved from 0.83950 to 0.84300, saving model to ./models/cifar10/se_resnet_best.hdf5
# Epoch 27/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.2472 - acc: 0.9151 - val_loss: 0.5301 - val_acc: 0.8360
#
# Epoch 00027: val_acc did not improve from 0.84300
# Epoch 28/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.2458 - acc: 0.9136 - val_loss: 0.4947 - val_acc: 0.8400
#
# Epoch 00028: val_acc did not improve from 0.84300
# Epoch 29/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.2364 - acc: 0.9193 - val_loss: 0.5065 - val_acc: 0.8390
#
# Epoch 00029: val_acc did not improve from 0.84300
# Epoch 30/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.2249 - acc: 0.9224 - val_loss: 0.5091 - val_acc: 0.8400
#
# Epoch 00030: val_acc did not improve from 0.84300
# Epoch 31/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.2240 - acc: 0.9213 - val_loss: 0.5105 - val_acc: 0.8385
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00031: val_acc did not improve from 0.84300
# Epoch 32/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.2251 - acc: 0.9234 - val_loss: 0.5181 - val_acc: 0.8410
#
# Epoch 00032: val_acc did not improve from 0.84300
# Epoch 33/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.2110 - acc: 0.9265 - val_loss: 0.5206 - val_acc: 0.8350
#
# Epoch 00033: val_acc did not improve from 0.84300
# Epoch 34/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.2063 - acc: 0.9290 - val_loss: 0.5310 - val_acc: 0.8385
#
# Epoch 00034: val_acc did not improve from 0.84300
# Epoch 35/200
# 375/375 [==============================] - 21s 56ms/step - loss: 0.2010 - acc: 0.9310 - val_loss: 0.5226 - val_acc: 0.8375
#
# Epoch 00035: val_acc did not improve from 0.84300
# Epoch 36/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.1986 - acc: 0.9323 - val_loss: 0.5244 - val_acc: 0.8385
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00036: val_acc did not improve from 0.84300

# %% [markdown]
# ## Best model weights was saved

# %%
plot_model(history)

# %%
from utils.evaluate_model import score
# reload from saved weights:
from utils.SE_resnet import SE_custom_resnet
path='./models/cifar10/se_resnet_best.hdf5'
model=SE_custom_resnet(res_model=[[[3,3],[64,64],4],[[3,3],[128,128],6],[[1,3,1],[256,256,1024],8]],custom_input=(32,32,3),n_classes=10,ratio=16,model_name='custom_resnet46',debug=False)
model.load_weights(path)

model.save('./full_models/cifar10/SE_resnet_best.h5')
del model  # deletes the existing model
model = tf.keras.models.load_model('./full_models/cifar10/SE_resnet_best.h5')

score(model,X_test,y_test,top_n=[3,5])
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 313/313 - 5s - loss: 0.5569 - acc: 0.8261
# SE_custom_resnet46
# model accuracy: 82.61%
# top 3 accuracy: 96.66000008583069
# top 5 accuracy: 98.989999294281
