# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
from tensorflow.python.client import device_lib
def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]
print(get_available_devices()) 

import os
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# ['/device:CPU:0', '/device:GPU:0']

# %% [markdown]
# # 0. Loading the data

# %% [markdown]
# ### TinyImageNet does not have labels for the testing data. We will use the 10k validation images for the testing data.

# %%
from tensorflow.keras.utils import to_categorical  

#load cifar-10 dataset
(X_tot, y_tot), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
#one hot encoding
y_test=to_categorical(y_test, num_classes=10)
y_tot=to_categorical(y_tot, num_classes=10)

print(X_tot.shape)
print(y_tot.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)
# (10000, 32, 32, 3)
# (10000, 10)

# %%
#shuffle data and split data to generate validation data
shuffler = np.random.RandomState(seed=42).permutation(len(X_tot))
X_tot = X_tot[shuffler]
y_tot = y_tot[shuffler]
 

#validation data
X_val=X_tot[0:2000]
y_val=y_tot[0:2000]

X_train=X_tot[2000:]
y_train=y_tot[2000:]

# %% [markdown]
# ### training function

# %%
from utils.train_ratio import train_ratio

# %%
train_ratio(1,X_train,y_train,X_val,y_val,X_test, y_test)
# Out:
# Model: "SE_custom_resnet46_ratio1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        input_6[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[1][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 16, 16, 64)   0           conv1_bn[1][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 8, 8, 64)     0           conv1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 8, 8, 64)     36928       pool1[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_squeeze (Global (None, 64)           0           conv2_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_fc1 (Dense)     (None, 64)           4160        conv2_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_fc2 (Dense)     (None, 64)           4160        conv2_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 8, 8, 64)     36928       pool1[1][0]
# __________________________________________________________________________________________________
# tf.reshape_90 (TFOpLambda)      (None, 1, 1, 64)     0           conv2_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block1_2_bn[1][0]
#                                                                  tf.reshape_90[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 8, 8, 64)     0           conv2_block1_0_bn[1][0]
#                                                                  conv2_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block1_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block1_add[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_squeeze (Global (None, 64)           0           conv2_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_fc1 (Dense)     (None, 64)           4160        conv2_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_fc2 (Dense)     (None, 64)           4160        conv2_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_91 (TFOpLambda)      (None, 1, 1, 64)     0           conv2_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block2_2_bn[1][0]
#                                                                  tf.reshape_91[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 8, 8, 64)     0           conv2_block1_relu[1][0]
#                                                                  conv2_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block2_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block2_add[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_squeeze (Global (None, 64)           0           conv2_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_fc1 (Dense)     (None, 64)           4160        conv2_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_fc2 (Dense)     (None, 64)           4160        conv2_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_92 (TFOpLambda)      (None, 1, 1, 64)     0           conv2_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block3_2_bn[1][0]
#                                                                  tf.reshape_92[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 8, 8, 64)     0           conv2_block2_relu[1][0]
#                                                                  conv2_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block3_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block3_add[1][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block4_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_squeeze (Global (None, 64)           0           conv2_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_fc1 (Dense)     (None, 64)           4160        conv2_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_fc2 (Dense)     (None, 64)           4160        conv2_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_93 (TFOpLambda)      (None, 1, 1, 64)     0           conv2_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block4_2_bn[1][0]
#                                                                  tf.reshape_93[0][0]
# __________________________________________________________________________________________________
# conv2_block4_add (Add)          (None, 8, 8, 64)     0           conv2_block3_relu[1][0]
#                                                                  conv2_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block4_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block4_add[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_squeeze (Global (None, 128)          0           conv3_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc1 (Dense)     (None, 128)          16512       conv3_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc2 (Dense)     (None, 128)          16512       conv3_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_94 (TFOpLambda)      (None, 1, 1, 128)    0           conv3_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block1_2_bn[1][0]
#                                                                  tf.reshape_94[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 4, 4, 128)    0           conv3_block1_0_bn[1][0]
#                                                                  conv3_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block1_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block1_add[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_squeeze (Global (None, 128)          0           conv3_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc1 (Dense)     (None, 128)          16512       conv3_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc2 (Dense)     (None, 128)          16512       conv3_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_95 (TFOpLambda)      (None, 1, 1, 128)    0           conv3_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block2_2_bn[1][0]
#                                                                  tf.reshape_95[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 4, 4, 128)    0           conv3_block1_relu[1][0]
#                                                                  conv3_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block2_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block2_add[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_squeeze (Global (None, 128)          0           conv3_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc1 (Dense)     (None, 128)          16512       conv3_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc2 (Dense)     (None, 128)          16512       conv3_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_96 (TFOpLambda)      (None, 1, 1, 128)    0           conv3_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block3_2_bn[1][0]
#                                                                  tf.reshape_96[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 4, 4, 128)    0           conv3_block2_relu[1][0]
#                                                                  conv3_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block3_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block3_add[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_squeeze (Global (None, 128)          0           conv3_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc1 (Dense)     (None, 128)          16512       conv3_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc2 (Dense)     (None, 128)          16512       conv3_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_97 (TFOpLambda)      (None, 1, 1, 128)    0           conv3_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block4_2_bn[1][0]
#                                                                  tf.reshape_97[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 4, 4, 128)    0           conv3_block3_relu[1][0]
#                                                                  conv3_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block4_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block4_add[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block5_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block5_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_squeeze (Global (None, 128)          0           conv3_block5_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_fc1 (Dense)     (None, 128)          16512       conv3_block5_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_fc2 (Dense)     (None, 128)          16512       conv3_block5_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_98 (TFOpLambda)      (None, 1, 1, 128)    0           conv3_block5_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block5_2_bn[1][0]
#                                                                  tf.reshape_98[0][0]
# __________________________________________________________________________________________________
# conv3_block5_add (Add)          (None, 4, 4, 128)    0           conv3_block4_relu[1][0]
#                                                                  conv3_block5_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block5_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block5_add[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block6_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block6_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block6_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_squeeze (Global (None, 128)          0           conv3_block6_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_fc1 (Dense)     (None, 128)          16512       conv3_block6_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_fc2 (Dense)     (None, 128)          16512       conv3_block6_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_99 (TFOpLambda)      (None, 1, 1, 128)    0           conv3_block6_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block6_2_bn[1][0]
#                                                                  tf.reshape_99[0][0]
# __________________________________________________________________________________________________
# conv3_block6_add (Add)          (None, 4, 4, 128)    0           conv3_block5_relu[1][0]
#                                                                  conv3_block6_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block6_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block6_add[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 2, 2, 256)    33024       conv3_block6_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block1_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_squeeze (Global (None, 1024)         0           conv4_block1_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc1 (Dense)     (None, 1024)         1049600     conv4_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc2 (Dense)     (None, 1024)         1049600     conv4_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 2, 2, 1024)   132096      conv3_block6_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_100 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block1_3_bn[1][0]
#                                                                  tf.reshape_100[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_0_bn[1][0]
#                                                                  conv4_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block1_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block1_add[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block2_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block2_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_squeeze (Global (None, 1024)         0           conv4_block2_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc1 (Dense)     (None, 1024)         1049600     conv4_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc2 (Dense)     (None, 1024)         1049600     conv4_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_101 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block2_3_bn[1][0]
#                                                                  tf.reshape_101[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_relu[1][0]
#                                                                  conv4_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block2_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block2_add[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block3_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block3_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_squeeze (Global (None, 1024)         0           conv4_block3_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc1 (Dense)     (None, 1024)         1049600     conv4_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc2 (Dense)     (None, 1024)         1049600     conv4_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_102 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block3_3_bn[1][0]
#                                                                  tf.reshape_102[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 2, 2, 1024)   0           conv4_block2_relu[1][0]
#                                                                  conv4_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block3_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block3_add[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block4_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block4_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_squeeze (Global (None, 1024)         0           conv4_block4_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc1 (Dense)     (None, 1024)         1049600     conv4_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc2 (Dense)     (None, 1024)         1049600     conv4_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_103 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block4_3_bn[1][0]
#                                                                  tf.reshape_103[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 2, 2, 1024)   0           conv4_block3_relu[1][0]
#                                                                  conv4_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block4_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block4_add[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block5_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block5_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block5_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_squeeze (Global (None, 1024)         0           conv4_block5_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc1 (Dense)     (None, 1024)         1049600     conv4_block5_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc2 (Dense)     (None, 1024)         1049600     conv4_block5_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_104 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block5_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block5_3_bn[1][0]
#                                                                  tf.reshape_104[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 2, 2, 1024)   0           conv4_block4_relu[1][0]
#                                                                  conv4_block5_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block5_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block5_add[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block5_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block6_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block6_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block6_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_squeeze (Global (None, 1024)         0           conv4_block6_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc1 (Dense)     (None, 1024)         1049600     conv4_block6_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc2 (Dense)     (None, 1024)         1049600     conv4_block6_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_105 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block6_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block6_3_bn[1][0]
#                                                                  tf.reshape_105[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 2, 2, 1024)   0           conv4_block5_relu[1][0]
#                                                                  conv4_block6_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block6_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block6_add[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block6_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block7_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block7_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block7_1_relu[1][0]
# ...
# conv4_block8_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block8_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block8_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_squeeze (Global (None, 1024)         0           conv4_block8_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_fc1 (Dense)     (None, 1024)         1049600     conv4_block8_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_fc2 (Dense)     (None, 1024)         1049600     conv4_block8_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_107 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block8_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block8_3_bn[1][0]
#                                                                  tf.reshape_107[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, 2, 2, 1024)   0           conv4_block7_relu[1][0]
#                                                                  conv4_block8_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block8_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block8_add[1][0]
# __________________________________________________________________________________________________
# pool_out (GlobalAveragePooling2 (None, 1024)         0           conv4_block8_relu[1][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 10)           10250       pool_out[1][0]
# ==================================================================================================
# Total params: 28,038,602
# Trainable params: 28,007,370
# Non-trainable params: 31,232
# __________________________________________________________________________________________________
# Epoch 1/200
# 375/375 [==============================] - 29s 62ms/step - loss: 2.2095 - acc: 0.3004 - val_loss: 1.6751 - val_acc: 0.4225
#
# Epoch 00001: val_acc improved from -inf to 0.42250, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 2/200
# 375/375 [==============================] - 22s 59ms/step - loss: 1.4412 - acc: 0.4882 - val_loss: 1.3926 - val_acc: 0.5080
#
# Epoch 00002: val_acc improved from 0.42250 to 0.50800, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 3/200
# 375/375 [==============================] - 22s 58ms/step - loss: 1.2329 - acc: 0.5640 - val_loss: 1.1780 - val_acc: 0.5810
#
# Epoch 00003: val_acc improved from 0.50800 to 0.58100, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 4/200
# 375/375 [==============================] - 22s 59ms/step - loss: 1.0916 - acc: 0.6135 - val_loss: 1.4363 - val_acc: 0.5015
#
# Epoch 00004: val_acc did not improve from 0.58100
# Epoch 5/200
# 375/375 [==============================] - 22s 60ms/step - loss: 0.9992 - acc: 0.6464 - val_loss: 1.4951 - val_acc: 0.4985
#
# Epoch 00005: val_acc did not improve from 0.58100
# Epoch 6/200
# 375/375 [==============================] - 22s 59ms/step - loss: 0.8988 - acc: 0.6824 - val_loss: 1.1928 - val_acc: 0.6080
#
# Epoch 00006: val_acc improved from 0.58100 to 0.60800, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 7/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.8384 - acc: 0.7029 - val_loss: 1.3729 - val_acc: 0.5600
#
# Epoch 00007: val_acc did not improve from 0.60800
# Epoch 8/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.7683 - acc: 0.7301 - val_loss: 1.0552 - val_acc: 0.6600
#
# Epoch 00008: val_acc improved from 0.60800 to 0.66000, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 9/200
# 375/375 [==============================] - 22s 59ms/step - loss: 0.7278 - acc: 0.7446 - val_loss: 0.8257 - val_acc: 0.7170
#
# Epoch 00009: val_acc improved from 0.66000 to 0.71700, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 10/200
# 375/375 [==============================] - 22s 59ms/step - loss: 0.6880 - acc: 0.7572 - val_loss: 0.7405 - val_acc: 0.7345
#
# Epoch 00010: val_acc improved from 0.71700 to 0.73450, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 11/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.6431 - acc: 0.7737 - val_loss: 1.2031 - val_acc: 0.6215
#
# Epoch 00011: val_acc did not improve from 0.73450
# Epoch 12/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.6193 - acc: 0.7823 - val_loss: 0.9219 - val_acc: 0.6930
#
# Epoch 00012: val_acc did not improve from 0.73450
# Epoch 13/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.5948 - acc: 0.7895 - val_loss: 0.7117 - val_acc: 0.7525
#
# Epoch 00013: val_acc improved from 0.73450 to 0.75250, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 14/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.5618 - acc: 0.8042 - val_loss: 0.7215 - val_acc: 0.7420
#
# Epoch 00014: val_acc did not improve from 0.75250
# Epoch 15/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.5468 - acc: 0.8084 - val_loss: 0.6866 - val_acc: 0.7705
#
# Epoch 00015: val_acc improved from 0.75250 to 0.77050, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 16/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.5206 - acc: 0.8199 - val_loss: 0.6786 - val_acc: 0.7700
#
# Epoch 00016: val_acc did not improve from 0.77050
# Epoch 17/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4898 - acc: 0.8266 - val_loss: 0.7089 - val_acc: 0.7600
#
# Epoch 00017: val_acc did not improve from 0.77050
# Epoch 18/200
# 375/375 [==============================] - 22s 59ms/step - loss: 0.4805 - acc: 0.8284 - val_loss: 0.6675 - val_acc: 0.7780
#
# Epoch 00018: val_acc improved from 0.77050 to 0.77800, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 19/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4601 - acc: 0.8387 - val_loss: 0.7986 - val_acc: 0.7195
#
# Epoch 00019: val_acc did not improve from 0.77800
# Epoch 20/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4359 - acc: 0.8470 - val_loss: 0.7287 - val_acc: 0.7720
#
# Epoch 00020: val_acc did not improve from 0.77800
# Epoch 21/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4285 - acc: 0.8503 - val_loss: 1.0682 - val_acc: 0.6840
#
# Epoch 00021: val_acc did not improve from 0.77800
# Epoch 22/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4078 - acc: 0.8562 - val_loss: 0.7299 - val_acc: 0.7560
#
# Epoch 00022: val_acc did not improve from 0.77800
# Epoch 23/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.3938 - acc: 0.8621 - val_loss: 0.8209 - val_acc: 0.7735
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00023: val_acc did not improve from 0.77800
# Epoch 24/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.3397 - acc: 0.8802 - val_loss: 0.5015 - val_acc: 0.8345
#
# Epoch 00024: val_acc improved from 0.77800 to 0.83450, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 25/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.2684 - acc: 0.9074 - val_loss: 0.5152 - val_acc: 0.8365
#
# Epoch 00025: val_acc improved from 0.83450 to 0.83650, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 26/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.2441 - acc: 0.9149 - val_loss: 0.5222 - val_acc: 0.8355
#
# Epoch 00026: val_acc did not improve from 0.83650
# Epoch 27/200
# 375/375 [==============================] - 22s 59ms/step - loss: 0.2481 - acc: 0.9149 - val_loss: 0.5248 - val_acc: 0.8360
#
# Epoch 00027: val_acc did not improve from 0.83650
# Epoch 28/200
# 375/375 [==============================] - 22s 59ms/step - loss: 0.2297 - acc: 0.9189 - val_loss: 0.5313 - val_acc: 0.8365
#
# Epoch 00028: val_acc did not improve from 0.83650
# Epoch 29/200
# 375/375 [==============================] - 22s 59ms/step - loss: 0.2217 - acc: 0.9231 - val_loss: 0.5331 - val_acc: 0.8390
#
# Epoch 00029: val_acc improved from 0.83650 to 0.83900, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 30/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.2112 - acc: 0.9280 - val_loss: 0.5363 - val_acc: 0.8390
#
# Epoch 00030: val_acc did not improve from 0.83900
# Epoch 31/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.2077 - acc: 0.9287 - val_loss: 0.5704 - val_acc: 0.8325
#
# Epoch 00031: val_acc did not improve from 0.83900
# Epoch 32/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.2004 - acc: 0.9321 - val_loss: 0.5486 - val_acc: 0.8360
#
# Epoch 00032: val_acc did not improve from 0.83900
# Epoch 33/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.1975 - acc: 0.9339 - val_loss: 0.5571 - val_acc: 0.8380
#
# Epoch 00033: val_acc did not improve from 0.83900
# Epoch 34/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.1882 - acc: 0.9346 - val_loss: 0.5540 - val_acc: 0.8380
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00034: val_acc did not improve from 0.83900
# Epoch 35/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.1802 - acc: 0.9388 - val_loss: 0.5542 - val_acc: 0.8420
#
# Epoch 00035: val_acc improved from 0.83900 to 0.84200, saving model to ./models/ratio/se_resnet_ratio_1.hdf5
# Epoch 36/200
# 375/375 [==============================] - 22s 59ms/step - loss: 0.1752 - acc: 0.9404 - val_loss: 0.5769 - val_acc: 0.8400
#
# Epoch 00036: val_acc did not improve from 0.84200
# Epoch 37/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.
(TFOpLambda)     (None, 1, 1, 64)     0           conv2_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block4_2_bn[1][0]
#                                                                  tf.reshape_129[0][0]
# __________________________________________________________________________________________________
# conv2_block4_add (Add)          (None, 8, 8, 64)     0           conv2_block3_relu[1][0]
#                                                                  conv2_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block4_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block4_add[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_squeeze (Global (None, 128)          0           conv3_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc1 (Dense)     (None, 64)           8256        conv3_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc2 (Dense)     (None, 128)          8320        conv3_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_130 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block1_2_bn[1][0]
#                                                                  tf.reshape_130[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 4, 4, 128)    0           conv3_block1_0_bn[1][0]
#                                                                  conv3_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block1_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block1_add[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_squeeze (Global (None, 128)          0           conv3_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc1 (Dense)     (None, 64)           8256        conv3_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc2 (Dense)     (None, 128)          8320        conv3_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_131 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block2_2_bn[1][0]
#                                                                  tf.reshape_131[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 4, 4, 128)    0           conv3_block1_relu[1][0]
#                                                                  conv3_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block2_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block2_add[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_squeeze (Global (None, 128)          0           conv3_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc1 (Dense)     (None, 64)           8256        conv3_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc2 (Dense)     (None, 128)          8320        conv3_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_132 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block3_2_bn[1][0]
#                                                                  tf.reshape_132[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 4, 4, 128)    0           conv3_block2_relu[1][0]
#                                                                  conv3_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block3_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block3_add[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_squeeze (Global (None, 128)          0           conv3_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc1 (Dense)     (None, 64)           8256        conv3_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc2 (Dense)     (None, 128)          8320        conv3_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_133 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block4_2_bn[1][0]
#                                                                  tf.reshape_133[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 4, 4, 128)    0           conv3_block3_relu[1][0]
#                                                                  conv3_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block4_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block4_add[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block5_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block5_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_squeeze (Global (None, 128)          0           conv3_block5_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_fc1 (Dense)     (None, 64)           8256        conv3_block5_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_fc2 (Dense)     (None, 128)          8320        conv3_block5_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_134 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block5_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block5_2_bn[1][0]
#                                                                  tf.reshape_134[0][0]
# __________________________________________________________________________________________________
# conv3_block5_add (Add)          (None, 4, 4, 128)    0           conv3_block4_relu[1][0]
#                                                                  conv3_block5_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block5_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block5_add[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block6_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block6_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block6_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_squeeze (Global (None, 128)          0           conv3_block6_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_fc1 (Dense)     (None, 64)           8256        conv3_block6_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_fc2 (Dense)     (None, 128)          8320        conv3_block6_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_135 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block6_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block6_2_bn[1][0]
#                                                                  tf.reshape_135[0][0]
# __________________________________________________________________________________________________
# conv3_block6_add (Add)          (None, 4, 4, 128)    0           conv3_block5_relu[1][0]
#                                                                  conv3_block6_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block6_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block6_add[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 2, 2, 256)    33024       conv3_block6_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block1_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_squeeze (Global (None, 1024)         0           conv4_block1_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc1 (Dense)     (None, 512)          524800      conv4_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc2 (Dense)     (None, 1024)         525312      conv4_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 2, 2, 1024)   132096      conv3_block6_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_136 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block1_3_bn[1][0]
#                                                                  tf.reshape_136[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_0_bn[1][0]
#                                                                  conv4_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block1_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block1_add[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block2_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block2_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_squeeze (Global (None, 1024)         0           conv4_block2_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc1 (Dense)     (None, 512)          524800      conv4_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc2 (Dense)     (None, 1024)         525312      conv4_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_137 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block2_3_bn[1][0]
#                                                                  tf.reshape_137[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_relu[1][0]
#                                                                  conv4_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block2_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block2_add[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block3_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block3_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_squeeze (Global (None, 1024)         0           conv4_block3_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc1 (Dense)     (None, 512)          524800      conv4_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc2 (Dense)     (None, 1024)         525312      conv4_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_138 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block3_3_bn[1][0]
#                                                                  tf.reshape_138[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 2, 2, 1024)   0           conv4_block2_relu[1][0]
#                                                                  conv4_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block3_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block3_add[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block4_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block4_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_squeeze (Global (None, 1024)         0           conv4_block4_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc1 (Dense)     (None, 512)          524800      conv4_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc2 (Dense)     (None, 1024)         525312      conv4_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_139 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block4_3_bn[1][0]
#                                                                  tf.reshape_139[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 2, 2, 1024)   0           conv4_block3_relu[1][0]
#                                                                  conv4_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block4_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block4_add[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block5_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block5_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block5_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_squeeze (Global (None, 1024)         0           conv4_block5_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc1 (Dense)     (None, 512)          524800      conv4_block5_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc2 (Dense)     (None, 1024)         525312      conv4_block5_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_140 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block5_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block5_3_bn[1][0]
#                                                                  tf.reshape_140[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 2, 2, 1024)   0           conv4_block4_relu[1][0]
#                                                                  conv4_block5_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block5_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block5_add[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block5_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block6_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block6_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block6_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_squeeze (Global (None, 1024)         0           conv4_block6_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc1 (Dense)     (None, 512)          524800      conv4_block6_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc2 (Dense)     (None, 1024)         525312      conv4_block6_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_141 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block6_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block6_3_bn[1][0]
#                                                                  tf.reshape_141[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 2, 2, 1024)   0           conv4_block5_relu[1][0]
#                                                                  conv4_block6_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block6_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block6_add[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block6_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block7_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block7_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block7_1_relu[1][0]
# ...
# __________________________________________________________________________________________________
# conv4_block8_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block8_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block8_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block8_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_squeeze (Global (None, 1024)         0           conv4_block8_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_fc1 (Dense)     (None, 512)          524800      conv4_block8_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_fc2 (Dense)     (None, 1024)         525312      conv4_block8_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_143 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block8_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block8_3_bn[1][0]
#                                                                  tf.reshape_143[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, 2, 2, 1024)   0           conv4_block7_relu[1][0]
#                                                                  conv4_block8_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block8_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block8_add[1][0]
# __________________________________________________________________________________________________
# pool_out (GlobalAveragePooling2 (None, 1024)         0           conv4_block8_relu[1][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 10)           10250       pool_out[1][0]
# ==================================================================================================
# Total params: 19,530,698
# Trainable params: 19,499,466
# Non-trainable params: 31,232
# __________________________________________________________________________________________________
# Epoch 1/200
# 375/375 [==============================] - 28s 61ms/step - loss: 2.2100 - acc: 0.2974 - val_loss: 1.5027 - val_acc: 0.4755
#
# Epoch 00001: val_acc improved from -inf to 0.47550, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 2/200
# 375/375 [==============================] - 22s 57ms/step - loss: 1.4133 - acc: 0.4962 - val_loss: 1.2261 - val_acc: 0.5485
#
# Epoch 00002: val_acc improved from 0.47550 to 0.54850, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 3/200
# 375/375 [==============================] - 21s 57ms/step - loss: 1.2277 - acc: 0.5653 - val_loss: 1.4559 - val_acc: 0.4820
#
# Epoch 00003: val_acc did not improve from 0.54850
# Epoch 4/200
# 375/375 [==============================] - 22s 57ms/step - loss: 1.0985 - acc: 0.6154 - val_loss: 1.7869 - val_acc: 0.4370
#
# Epoch 00004: val_acc did not improve from 0.54850
# Epoch 5/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.9675 - acc: 0.6593 - val_loss: 1.3698 - val_acc: 0.5390
#
# Epoch 00005: val_acc did not improve from 0.54850
# Epoch 6/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.8950 - acc: 0.6854 - val_loss: 1.1087 - val_acc: 0.6125
#
# Epoch 00006: val_acc improved from 0.54850 to 0.61250, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 7/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.8206 - acc: 0.7100 - val_loss: 1.1043 - val_acc: 0.6470
#
# Epoch 00007: val_acc improved from 0.61250 to 0.64700, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 8/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.7928 - acc: 0.7241 - val_loss: 0.9467 - val_acc: 0.6790
#
# Epoch 00008: val_acc improved from 0.64700 to 0.67900, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 9/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.7338 - acc: 0.7420 - val_loss: 0.7980 - val_acc: 0.7210
#
# Epoch 00009: val_acc improved from 0.67900 to 0.72100, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 10/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.7008 - acc: 0.7541 - val_loss: 1.0984 - val_acc: 0.6510
#
# Epoch 00010: val_acc did not improve from 0.72100
# Epoch 11/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.6757 - acc: 0.7623 - val_loss: 1.0828 - val_acc: 0.7360
#
# Epoch 00011: val_acc improved from 0.72100 to 0.73600, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 12/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.6353 - acc: 0.7736 - val_loss: 0.7576 - val_acc: 0.7450
#
# Epoch 00012: val_acc improved from 0.73600 to 0.74500, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 13/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.6016 - acc: 0.7901 - val_loss: 0.9445 - val_acc: 0.6910
#
# Epoch 00013: val_acc did not improve from 0.74500
# Epoch 14/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.5751 - acc: 0.7995 - val_loss: 1.2883 - val_acc: 0.6020
#
# Epoch 00014: val_acc did not improve from 0.74500
# Epoch 15/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.5650 - acc: 0.8025 - val_loss: 0.7568 - val_acc: 0.7445
#
# Epoch 00015: val_acc did not improve from 0.74500
# Epoch 16/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.5293 - acc: 0.8137 - val_loss: 0.9129 - val_acc: 0.7015
#
# Epoch 00016: val_acc did not improve from 0.74500
# Epoch 17/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.5092 - acc: 0.8210 - val_loss: 0.7226 - val_acc: 0.7605
#
# Epoch 00017: val_acc improved from 0.74500 to 0.76050, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 18/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4896 - acc: 0.8280 - val_loss: 0.7082 - val_acc: 0.7555
#
# Epoch 00018: val_acc did not improve from 0.76050
# Epoch 19/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.4691 - acc: 0.8348 - val_loss: 0.6354 - val_acc: 0.7795
#
# Epoch 00019: val_acc improved from 0.76050 to 0.77950, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 20/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4504 - acc: 0.8402 - val_loss: 0.6667 - val_acc: 0.7825
#
# Epoch 00020: val_acc improved from 0.77950 to 0.78250, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 21/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.4348 - acc: 0.8484 - val_loss: 0.7555 - val_acc: 0.7490
#
# Epoch 00021: val_acc did not improve from 0.78250
# Epoch 22/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.4349 - acc: 0.8477 - val_loss: 0.5992 - val_acc: 0.8065
#
# Epoch 00022: val_acc improved from 0.78250 to 0.80650, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 23/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4065 - acc: 0.8575 - val_loss: 0.7185 - val_acc: 0.7650
#
# Epoch 00023: val_acc did not improve from 0.80650
# Epoch 24/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.3840 - acc: 0.8664 - val_loss: 0.6428 - val_acc: 0.7965
#
# Epoch 00024: val_acc did not improve from 0.80650
# Epoch 25/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.3682 - acc: 0.8697 - val_loss: 0.5911 - val_acc: 0.8065
#
# Epoch 00025: val_acc did not improve from 0.80650
# Epoch 26/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.3673 - acc: 0.8699 - val_loss: 0.5708 - val_acc: 0.8105
#
# Epoch 00026: val_acc improved from 0.80650 to 0.81050, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 27/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.3478 - acc: 0.8802 - val_loss: 0.6762 - val_acc: 0.7925
#
# Epoch 00027: val_acc did not improve from 0.81050
# Epoch 28/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.3394 - acc: 0.8812 - val_loss: 0.5986 - val_acc: 0.8020
#
# Epoch 00028: val_acc did not improve from 0.81050
# Epoch 29/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.3218 - acc: 0.8850 - val_loss: 0.8609 - val_acc: 0.7405
#
# Epoch 00029: val_acc did not improve from 0.81050
# Epoch 30/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.3121 - acc: 0.8903 - val_loss: 0.7019 - val_acc: 0.7835
#
# Epoch 00030: val_acc did not improve from 0.81050
# Epoch 31/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.3028 - acc: 0.8915 - val_loss: 0.7027 - val_acc: 0.7870
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00031: val_acc did not improve from 0.81050
# Epoch 32/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.2709 - acc: 0.9082 - val_loss: 0.5063 - val_acc: 0.8440
#
# Epoch 00032: val_acc improved from 0.81050 to 0.84400, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 33/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.1919 - acc: 0.9343 - val_loss: 0.5071 - val_acc: 0.8420
#
# Epoch 00033: val_acc did not improve from 0.84400
# Epoch 34/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.1847 - acc: 0.9351 - val_loss: 0.5227 - val_acc: 0.8490
#
# Epoch 00034: val_acc improved from 0.84400 to 0.84900, saving model to ./models/ratio/se_resnet_ratio_2.hdf5
# Epoch 35/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.1641 - acc: 0.9436 - val_loss: 0.5276 - val_acc: 0.8445
#
# Epoch 00035: val_acc did not improve from 0.84900
# Epoch 36/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.
# [0.4754999876022339, 0.5485000014305115, 0.4819999933242798, 0.43700000643730164, 0.5389999747276306, 0.612500011920929, 0.6470000147819519, 0.6790000200271606, 0.7210000157356262, 0.6510000228881836, 0.7360000014305115, 0.7450000047683716, 0.6909999847412109, 0.6019999980926514, 0.7444999814033508, 0.7014999985694885, 0.7605000138282776, 0.7555000185966492, 0.7795000076293945, 0.7825000286102295, 0.7490000128746033, 0.8065000176429749, 0.7649999856948853, 0.796500027179718, 0.8065000176429749, 0.8105000257492065, 0.7925000190734863, 0.8019999861717224, 0.7404999732971191, 0.7835000157356262, 0.7870000004768372, 0.843999981880188, 0.8420000076293945, 0.8489999771118164, 0.8445000052452087, 0.840499997138977, 0.8489999771118164, 0.8410000205039978, 0.8389999866485596, 0.843500018119812, 0.8420000076293945, 0.840499997138977, 0.8395000100135803, 0.8424999713897705]
# [1.502726674079895, 1.2261242866516113, 1.4558537006378174, 1.7869044542312622, 1.3697572946548462, 1.1087337732315063, 1.1043411493301392, 0.9466767311096191, 0.7979993224143982, 1.0983737707138062, 1.0828156471252441, 0.7576411366462708, 0.9444815516471863, 1.2882581949234009, 0.75682133436203, 0.9129453897476196, 0.7225518822669983, 0.7081774473190308, 0.6353615522384644, 0.6667465567588806, 0.7555319666862488, 0.5992415547370911, 0.7184692025184631, 0.6427887678146362, 0.591091513633728, 0.5707556009292603, 0.676175594329834, 0.5986208319664001, 0.8608676195144653, 0.7019097208976746, 0.7027131915092468, 0.5062956213951111, 0.5071276426315308, 0.5227305889129639, 0.5275546908378601, 0.5349428057670593, 0.543186366558075, 0.558827817440033, 0.5607100129127502, 0.5789968371391296, 0.5623409748077393, 0.5775858163833618, 0.587091326713562, 0.5951508283615112]
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 313/313 - 4s - loss: 0.5784 - acc: 0.8267
# SE_custom_resnet46_ratio1
# model accuracy: 82.67%
# top 3 accuracy: 96.46000266075134
# top 5 accuracy: 99.09999966621399

# %%
train_ratio(4,X_train,y_train,X_val,y_val,X_test, y_test)
# Out:
# Model: "SE_custom_resnet46_ratio1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        input_10[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[1][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 16, 16, 64)   0           conv1_bn[1][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 8, 8, 64)     0           conv1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 8, 8, 64)     36928       pool1[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_squeeze (Global (None, 64)           0           conv2_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_fc1 (Dense)     (None, 16)           1040        conv2_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_fc2 (Dense)     (None, 64)           1088        conv2_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 8, 8, 64)     36928       pool1[1][0]
# __________________________________________________________________________________________________
# tf.reshape_162 (TFOpLambda)     (None, 1, 1, 64)     0           conv2_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block1_2_bn[1][0]
#                                                                  tf.reshape_162[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 8, 8, 64)     0           conv2_block1_0_bn[1][0]
#                                                                  conv2_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block1_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block1_add[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_squeeze (Global (None, 64)           0           conv2_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_fc1 (Dense)     (None, 16)           1040        conv2_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_fc2 (Dense)     (None, 64)           1088        conv2_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_163 (TFOpLambda)     (None, 1, 1, 64)     0           conv2_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block2_2_bn[1][0]
#                                                                  tf.reshape_163[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 8, 8, 64)     0           conv2_block1_relu[1][0]
#                                                                  conv2_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block2_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block2_add[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_squeeze (Global (None, 64)           0           conv2_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_fc1 (Dense)     (None, 16)           1040        conv2_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_fc2 (Dense)     (None, 64)           1088        conv2_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_164 (TFOpLambda)     (None, 1, 1, 64)     0           conv2_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block3_2_bn[1][0]
#                                                                  tf.reshape_164[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 8, 8, 64)     0           conv2_block2_relu[1][0]
#                                                                  conv2_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block3_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block3_add[1][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block4_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_squeeze (Global (None, 64)           0           conv2_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_fc1 (Dense)     (None, 16)           1040        conv2_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_fc2 (Dense)     (None, 64)           1088        conv2_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_165 (TFOpLambda)     (None, 1, 1, 64)     0           conv2_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block4_2_bn[1][0]
#                                                                  tf.reshape_165[0][0]
# __________________________________________________________________________________________________
# conv2_block4_add (Add)          (None, 8, 8, 64)     0           conv2_block3_relu[1][0]
#                                                                  conv2_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block4_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block4_add[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_squeeze (Global (None, 128)          0           conv3_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc1 (Dense)     (None, 32)           4128        conv3_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc2 (Dense)     (None, 128)          4224        conv3_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_166 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block1_2_bn[1][0]
#                                                                  tf.reshape_166[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 4, 4, 128)    0           conv3_block1_0_bn[1][0]
#                                                                  conv3_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block1_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block1_add[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_squeeze (Global (None, 128)          0           conv3_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc1 (Dense)     (None, 32)           4128        conv3_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc2 (Dense)     (None, 128)          4224        conv3_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_167 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block2_2_bn[1][0]
#                                                                  tf.reshape_167[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 4, 4, 128)    0           conv3_block1_relu[1][0]
#                                                                  conv3_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block2_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block2_add[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_squeeze (Global (None, 128)          0           conv3_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc1 (Dense)     (None, 32)           4128        conv3_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc2 (Dense)     (None, 128)          4224        conv3_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_168 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block3_2_bn[1][0]
#                                                                  tf.reshape_168[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 4, 4, 128)    0           conv3_block2_relu[1][0]
#                                                                  conv3_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block3_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block3_add[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_squeeze (Global (None, 128)          0           conv3_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc1 (Dense)     (None, 32)           4128        conv3_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc2 (Dense)     (None, 128)          4224        conv3_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_169 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block4_2_bn[1][0]
#                                                                  tf.reshape_169[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 4, 4, 128)    0           conv3_block3_relu[1][0]
#                                                                  conv3_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block4_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block4_add[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block5_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block5_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_squeeze (Global (None, 128)          0           conv3_block5_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_fc1 (Dense)     (None, 32)           4128        conv3_block5_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_fc2 (Dense)     (None, 128)          4224        conv3_block5_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_170 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block5_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block5_2_bn[1][0]
#                                                                  tf.reshape_170[0][0]
# __________________________________________________________________________________________________
# conv3_block5_add (Add)          (None, 4, 4, 128)    0           conv3_block4_relu[1][0]
#                                                                  conv3_block5_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block5_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block5_add[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block6_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block6_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block6_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_squeeze (Global (None, 128)          0           conv3_block6_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_fc1 (Dense)     (None, 32)           4128        conv3_block6_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_fc2 (Dense)     (None, 128)          4224        conv3_block6_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_171 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block6_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block6_2_bn[1][0]
#                                                                  tf.reshape_171[0][0]
# __________________________________________________________________________________________________
# conv3_block6_add (Add)          (None, 4, 4, 128)    0           conv3_block5_relu[1][0]
#                                                                  conv3_block6_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block6_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block6_add[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 2, 2, 256)    33024       conv3_block6_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block1_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_squeeze (Global (None, 1024)         0           conv4_block1_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc1 (Dense)     (None, 256)          262400      conv4_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc2 (Dense)     (None, 1024)         263168      conv4_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 2, 2, 1024)   132096      conv3_block6_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_172 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block1_3_bn[1][0]
#                                                                  tf.reshape_172[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_0_bn[1][0]
#                                                                  conv4_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block1_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block1_add[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block2_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block2_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_squeeze (Global (None, 1024)         0           conv4_block2_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc1 (Dense)     (None, 256)          262400      conv4_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc2 (Dense)     (None, 1024)         263168      conv4_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_173 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block2_3_bn[1][0]
#                                                                  tf.reshape_173[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_relu[1][0]
#                                                                  conv4_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block2_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block2_add[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block3_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block3_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_squeeze (Global (None, 1024)         0           conv4_block3_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc1 (Dense)     (None, 256)          262400      conv4_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc2 (Dense)     (None, 1024)         263168      conv4_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_174 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block3_3_bn[1][0]
#                                                                  tf.reshape_174[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 2, 2, 1024)   0           conv4_block2_relu[1][0]
#                                                                  conv4_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block3_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block3_add[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block4_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block4_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_squeeze (Global (None, 1024)         0           conv4_block4_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc1 (Dense)     (None, 256)          262400      conv4_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc2 (Dense)     (None, 1024)         263168      conv4_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_175 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block4_3_bn[1][0]
#                                                                  tf.reshape_175[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 2, 2, 1024)   0           conv4_block3_relu[1][0]
#                                                                  conv4_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block4_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block4_add[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block5_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block5_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block5_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_squeeze (Global (None, 1024)         0           conv4_block5_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc1 (Dense)     (None, 256)          262400      conv4_block5_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc2 (Dense)     (None, 1024)         263168      conv4_block5_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_176 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block5_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block5_3_bn[1][0]
#                                                                  tf.reshape_176[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 2, 2, 1024)   0           conv4_block4_relu[1][0]
#                                                                  conv4_block5_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block5_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block5_add[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block5_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block6_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block6_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block6_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_squeeze (Global (None, 1024)         0           conv4_block6_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc1 (Dense)     (None, 256)          262400      conv4_block6_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc2 (Dense)     (None, 1024)         263168      conv4_block6_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_177 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block6_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block6_3_bn[1][0]
#                                                                  tf.reshape_177[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 2, 2, 1024)   0           conv4_block5_relu[1][0]
#                                                                  conv4_block6_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block6_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block6_add[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block6_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block7_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block7_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block7_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block7_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block7_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block7_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block7_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block7_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block7_SE_squeeze (Global (None, 1024)         0           conv4_block7_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block7_SE_fc1 (Dense)     (None, 256)          262400      conv4_block7_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block7_SE_fc2 (Dense)     (None, 1024)         263168      conv4_block7_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_178 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block7_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block7_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block7_3_bn[1][0]
#                                                                  tf.reshape_178[0][0]
# __________________________________________________________________________________________________
# conv4_block7_add (Add)          (None, 2, 2, 1024)   0           conv4_block6_relu[1][0]
#                                                                  conv4_block7_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block7_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block7_add[1][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block7_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block8_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block8_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block8_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block8_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block8_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block8_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block8_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_squeeze (Global (None, 1024)         0           conv4_block8_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_fc1 (Dense)     (None, 256)          262400      conv4_block8_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_fc2 (Dense)     (None, 1024)         263168      conv4_block8_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_179 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block8_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block8_3_bn[1][0]
#                                                                  tf.reshape_179[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, 2, 2, 1024)   0           conv4_block7_relu[1][0]
#                                                                  conv4_block8_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block8_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block8_add[1][0]
# __________________________________________________________________________________________________
# pool_out (GlobalAveragePooling2 (None, 1024)         0           conv4_block8_relu[1][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 10)           10250       pool_out[1][0]
# ==================================================================================================
# Total params: 15,276,746
# Trainable params: 15,245,514
# Non-trainable params: 31,232
# __________________________________________________________________________________________________
# Epoch 1/200
# 375/375 [==============================] - 29s 61ms/step - loss: 2.2180 - acc: 0.3016 - val_loss: 1.4353 - val_acc: 0.4925
#
# Epoch 00001: val_acc improved from -inf to 0.49250, saving model to ./models/ratio/se_resnet_ratio_4.hdf5
# Epoch 2/200
# 375/375 [==============================] - 22s 58ms/step - loss: 1.4076 - acc: 0.5027 - val_loss: 1.7213 - val_acc: 0.4295
#
# Epoch 00002: val_acc did not improve from 0.49250
# Epoch 3/200
# 375/375 [==============================] - 22s 57ms/step - loss: 1.2142 - acc: 0.5713 - val_loss: 1.2379 - val_acc: 0.5705
#
# Epoch 00003: val_acc improved from 0.49250 to 0.57050, saving model to ./models/ratio/se_resnet_ratio_4.hdf5
# Epoch 4/200
# 375/375 [==============================] - 22s 58ms/step - loss: 1.1132 - acc: 0.6064 - val_loss: 1.3389 - val_acc: 0.5625
#
# Epoch 00004: val_acc did not improve from 0.57050
# Epoch 5/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.9716 - acc: 0.6526 - val_loss: 1.2249 - val_acc: 0.6545
#
# Epoch 00005: val_acc improved from 0.57050 to 0.65450, saving model to ./models/ratio/se_resnet_ratio_4.hdf5
# Epoch 6/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.8887 - acc: 0.6881 - val_loss: 1.0274 - val_acc: 0.6535
#
# Epoch 00006: val_acc did not improve from 0.65450
# Epoch 7/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.8428 - acc: 0.7035 - val_loss: 1.1686 - val_acc: 0.6290
#
# Epoch 00007: val_acc did not improve from 0.65450
# Epoch 8/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.7884 - acc: 0.7248 - val_loss: 0.8487 - val_acc: 0.7185
#
# Epoch 00008: val_acc improved from 0.65450 to 0.71850, saving model to ./models/ratio/se_resnet_ratio_4.hdf5
# Epoch 9/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.7386 - acc: 0.7440 - val_loss: 0.8192 - val_acc: 0.7030
#
# Epoch 00009: val_acc did not improve from 0.71850
# Epoch 10/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.6909 - acc: 0.7594 - val_loss: 1.1374 - val_acc: 0.6575
#
# Epoch 00010: val_acc did not improve from 0.71850
# Epoch 11/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.6670 - acc: 0.7654 - val_loss: 0.8482 - val_acc: 0.7045
#
# Epoch 00011: val_acc did not improve from 0.71850
# Epoch 12/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.6375 - acc: 0.7790 - val_loss: 0.9310 - val_acc: 0.6865
#
# Epoch 00012: val_acc did not improve from 0.71850
# Epoch 13/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.6072 - acc: 0.7856 - val_loss: 0.8747 - val_acc: 0.7090
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00013: val_acc did not improve from 0.71850
# Epoch 14/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.5471 - acc: 0.8057 - val_loss: 0.5375 - val_acc: 0.8115
#
# Epoch 00014: val_acc improved from 0.71850 to 0.81150, saving model to ./models/ratio/se_resnet_ratio_4.hdf5
# Epoch 15/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4730 - acc: 0.8339 - val_loss: 0.5327 - val_acc: 0.8090
#
# Epoch 00015: val_acc did not improve from 0.81150
# Epoch 16/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4497 - acc: 0.8439 - val_loss: 0.5337 - val_acc: 0.8135
#
# Epoch 00016: val_acc improved from 0.81150 to 0.81350, saving model to ./models/ratio/se_resnet_ratio_4.hdf5
# Epoch 17/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4423 - acc: 0.8467 - val_loss: 0.5363 - val_acc: 0.8065
#
# Epoch 00017: val_acc did not improve from 0.81350
# Epoch 18/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4346 - acc: 0.8480 - val_loss: 0.5466 - val_acc: 0.8085
#
# Epoch 00018: val_acc did not improve from 0.81350
# Epoch 19/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4103 - acc: 0.8575 - val_loss: 0.5195 - val_acc: 0.8110
#
# Epoch 00019: val_acc did not improve from 0.81350
# Epoch 20/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.4042 - acc: 0.8582 - val_loss: 0.5231 - val_acc: 0.8155
#
# Epoch 00020: val_acc improved from 0.81350 to 0.81550, saving model to ./models/ratio/se_resnet_ratio_4.hdf5
# Epoch 21/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.3956 - acc: 0.8622 - val_loss: 0.5329 - val_acc: 0.8175
#
# Epoch 00021: val_acc improved from 0.81550 to 0.81750, saving model to ./models/ratio/se_resnet_ratio_4.hdf5
# Epoch 22/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.3887 - acc: 0.8629 - val_loss: 0.5299 - val_acc: 0.8160
#
# Epoch 00022: val_acc did not improve from 0.81750
# Epoch 23/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.3770 - acc: 0.8653 - val_loss: 0.5537 - val_acc: 0.8105
#
# Epoch 00023: val_acc did not improve from 0.81750
# Epoch 24/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.3629 - acc: 0.8728 - val_loss: 0.5268 - val_acc: 0.8145
#
# Epoch 00024: val_acc did not improve from 0.81750
# Epoch 25/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.3636 - acc: 0.8741 - val_loss: 0.5537 - val_acc: 0.8120
#
# Epoch 00025: val_acc did not improve from 0.81750
# Epoch 26/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.3468 - acc: 0.8777 - val_loss: 0.5456 - val_acc: 0.8175
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00026: val_acc did not improve from 0.81750
# Epoch 27/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.3380 - acc: 0.8828 - val_loss: 0.5421 - val_acc: 0.8160
#
# Epoch 00027: val_acc did not improve from 0.81750
# Epoch 28/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.3347 - acc: 0.8837 - val_loss: 0.5412 - val_acc: 0.8165
#
# Epoch 00028: val_acc did not improve from 0.81750
# Epoch 29/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.3304 - acc: 0.8839 - val_loss: 0.5692 - val_acc: 0.8130
#
# Epoch 00029: val_acc did not improve from 0.81750
# Epoch 30/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.3133 - acc: 0.8918 - val_loss: 0.5433 - val_acc: 0.8175
#
# Epoch 00030: val_acc did not improve from 0.81750
# Epoch 31/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.3173 - acc: 0.8871 - val_loss: 0.5607 - val_acc: 0.8150
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00031: val_acc did not improve from 0.81750
# [0.3800624907016754, 0.5151875019073486, 0.577833354473114, 0.620479166507721, 0.6577083468437195, 0.6859999895095825, 0.7015625238418579, 0.7263749837875366, 0.7405208349227905, 0.7557916641235352, 0.7678333520889282, 0.7759166955947876, 0.7817083597183228, 0.8194375038146973, 0.8367291688919067, 0.8417500257492065, 0.8468124866485596, 0.8484583497047424, 0.8549583554267883, 0.8586041927337646, 0.8612916469573975, 0.8648124933242798, 0.8663958311080933, 0.8714583516120911, 0.8749374747276306, 0.878250002861023, 0.8806250095367432, 0.8806874752044678, 0.883062481880188, 0.8881250023841858, 0.8872291445732117]
block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_fc1 (Dense)     (None, 8)            520         conv2_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_fc2 (Dense)     (None, 64)           576         conv2_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_201 (TFOpLambda)     (None, 1, 1, 64)     0           conv2_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block4_2_bn[1][0]
#                                                                  tf.reshape_201[0][0]
# __________________________________________________________________________________________________
# conv2_block4_add (Add)          (None, 8, 8, 64)     0           conv2_block3_relu[1][0]
#                                                                  conv2_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block4_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block4_add[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_squeeze (Global (None, 128)          0           conv3_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc1 (Dense)     (None, 16)           2064        conv3_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc2 (Dense)     (None, 128)          2176        conv3_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_202 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block1_2_bn[1][0]
#                                                                  tf.reshape_202[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 4, 4, 128)    0           conv3_block1_0_bn[1][0]
#                                                                  conv3_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block1_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block1_add[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_squeeze (Global (None, 128)          0           conv3_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc1 (Dense)     (None, 16)           2064        conv3_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc2 (Dense)     (None, 128)          2176        conv3_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_203 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block2_2_bn[1][0]
#                                                                  tf.reshape_203[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 4, 4, 128)    0           conv3_block1_relu[1][0]
#                                                                  conv3_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block2_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block2_add[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_squeeze (Global (None, 128)          0           conv3_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc1 (Dense)     (None, 16)           2064        conv3_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc2 (Dense)     (None, 128)          2176        conv3_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_204 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block3_2_bn[1][0]
#                                                                  tf.reshape_204[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 4, 4, 128)    0           conv3_block2_relu[1][0]
#                                                                  conv3_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block3_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block3_add[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_squeeze (Global (None, 128)          0           conv3_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc1 (Dense)     (None, 16)           2064        conv3_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc2 (Dense)     (None, 128)          2176        conv3_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_205 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block4_2_bn[1][0]
#                                                                  tf.reshape_205[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 4, 4, 128)    0           conv3_block3_relu[1][0]
#                                                                  conv3_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block4_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block4_add[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block5_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block5_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_squeeze (Global (None, 128)          0           conv3_block5_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_fc1 (Dense)     (None, 16)           2064        conv3_block5_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_fc2 (Dense)     (None, 128)          2176        conv3_block5_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_206 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block5_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block5_2_bn[1][0]
#                                                                  tf.reshape_206[0][0]
# __________________________________________________________________________________________________
# conv3_block5_add (Add)          (None, 4, 4, 128)    0           conv3_block4_relu[1][0]
#                                                                  conv3_block5_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block5_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block5_add[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block6_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block6_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block6_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_squeeze (Global (None, 128)          0           conv3_block6_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_fc1 (Dense)     (None, 16)           2064        conv3_block6_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_fc2 (Dense)     (None, 128)          2176        conv3_block6_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_207 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block6_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block6_2_bn[1][0]
#                                                                  tf.reshape_207[0][0]
# __________________________________________________________________________________________________
# conv3_block6_add (Add)          (None, 4, 4, 128)    0           conv3_block5_relu[1][0]
#                                                                  conv3_block6_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block6_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block6_add[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 2, 2, 256)    33024       conv3_block6_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block1_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_squeeze (Global (None, 1024)         0           conv4_block1_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc1 (Dense)     (None, 128)          131200      conv4_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc2 (Dense)     (None, 1024)         132096      conv4_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 2, 2, 1024)   132096      conv3_block6_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_208 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block1_3_bn[1][0]
#                                                                  tf.reshape_208[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_0_bn[1][0]
#                                                                  conv4_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block1_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block1_add[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block2_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block2_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_squeeze (Global (None, 1024)         0           conv4_block2_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc1 (Dense)     (None, 128)          131200      conv4_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc2 (Dense)     (None, 1024)         132096      conv4_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_209 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block2_3_bn[1][0]
#                                                                  tf.reshape_209[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_relu[1][0]
#                                                                  conv4_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block2_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block2_add[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block3_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block3_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_squeeze (Global (None, 1024)         0           conv4_block3_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc1 (Dense)     (None, 128)          131200      conv4_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc2 (Dense)     (None, 1024)         132096      conv4_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_210 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block3_3_bn[1][0]
#                                                                  tf.reshape_210[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 2, 2, 1024)   0           conv4_block2_relu[1][0]
#                                                                  conv4_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block3_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block3_add[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block4_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block4_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_squeeze (Global (None, 1024)         0           conv4_block4_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc1 (Dense)     (None, 128)          131200      conv4_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc2 (Dense)     (None, 1024)         132096      conv4_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_211 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block4_3_bn[1][0]
#                                                                  tf.reshape_211[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 2, 2, 1024)   0           conv4_block3_relu[1][0]
#                                                                  conv4_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block4_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block4_add[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block5_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block5_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block5_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_squeeze (Global (None, 1024)         0           conv4_block5_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc1 (Dense)     (None, 128)          131200      conv4_block5_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc2 (Dense)     (None, 1024)         132096      conv4_block5_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_212 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block5_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block5_3_bn[1][0]
#                                                                  tf.reshape_212[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 2, 2, 1024)   0           conv4_block4_relu[1][0]
#                                                                  conv4_block5_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block5_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block5_add[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block5_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block6_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block6_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block6_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_squeeze (Global (None, 1024)         0           conv4_block6_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc1 (Dense)     (None, 128)          131200      conv4_block6_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc2 (Dense)     (None, 1024)         132096      conv4_block6_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_213 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block6_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block6_3_bn[1][0]
#                                                                  tf.reshape_213[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 2, 2, 1024)   0           conv4_block5_relu[1][0]
#                                                                  conv4_block6_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block6_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block6_add[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block6_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block7_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block7_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block7_1_relu[1][0]
# ...
# __________________________________________________________________________________________________
# conv4_block8_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block8_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block8_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block8_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block8_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block8_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block8_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_squeeze (Global (None, 1024)         0           conv4_block8_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_fc1 (Dense)     (None, 128)          131200      conv4_block8_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_fc2 (Dense)     (None, 1024)         132096      conv4_block8_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_215 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block8_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block8_3_bn[1][0]
#                                                                  tf.reshape_215[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, 2, 2, 1024)   0           conv4_block7_relu[1][0]
#                                                                  conv4_block8_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block8_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block8_add[1][0]
# __________________________________________________________________________________________________
# pool_out (GlobalAveragePooling2 (None, 1024)         0           conv4_block8_relu[1][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 10)           10250       pool_out[1][0]
# ==================================================================================================
# Total params: 13,149,770
# Trainable params: 13,118,538
# Non-trainable params: 31,232
# __________________________________________________________________________________________________
# Epoch 1/200
# 375/375 [==============================] - 29s 61ms/step - loss: 2.3382 - acc: 0.2891 - val_loss: 1.5171 - val_acc: 0.4515
#
# Epoch 00001: val_acc improved from -inf to 0.45150, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 2/200
# 375/375 [==============================] - 22s 58ms/step - loss: 1.4644 - acc: 0.4745 - val_loss: 1.3077 - val_acc: 0.5395
#
# Epoch 00002: val_acc improved from 0.45150 to 0.53950, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 3/200
# 375/375 [==============================] - 22s 57ms/step - loss: 1.2946 - acc: 0.5363 - val_loss: 1.2716 - val_acc: 0.5480
#
# Epoch 00003: val_acc improved from 0.53950 to 0.54800, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 4/200
# 375/375 [==============================] - 21s 57ms/step - loss: 1.1423 - acc: 0.5928 - val_loss: 1.3663 - val_acc: 0.5300
#
# Epoch 00004: val_acc did not improve from 0.54800
# Epoch 5/200
# 375/375 [==============================] - 22s 58ms/step - loss: 1.0462 - acc: 0.6297 - val_loss: 1.0230 - val_acc: 0.6410
#
# Epoch 00005: val_acc improved from 0.54800 to 0.64100, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 6/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.9696 - acc: 0.6590 - val_loss: 1.1709 - val_acc: 0.5975
#
# Epoch 00006: val_acc did not improve from 0.64100
# Epoch 7/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.9642 - acc: 0.6552 - val_loss: 1.3126 - val_acc: 0.5665
#
# Epoch 00007: val_acc did not improve from 0.64100
# Epoch 8/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.8673 - acc: 0.6947 - val_loss: 0.9825 - val_acc: 0.6670
#
# Epoch 00008: val_acc improved from 0.64100 to 0.66700, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 9/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.8162 - acc: 0.7130 - val_loss: 1.0463 - val_acc: 0.6375
#
# Epoch 00009: val_acc did not improve from 0.66700
# Epoch 10/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.7639 - acc: 0.7295 - val_loss: 0.8796 - val_acc: 0.7040
#
# Epoch 00010: val_acc improved from 0.66700 to 0.70400, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 11/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.7370 - acc: 0.7386 - val_loss: 0.9063 - val_acc: 0.6840
#
# Epoch 00011: val_acc did not improve from 0.70400
# Epoch 12/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.6745 - acc: 0.7592 - val_loss: 0.7845 - val_acc: 0.7260
#
# Epoch 00012: val_acc improved from 0.70400 to 0.72600, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 13/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.6381 - acc: 0.7735 - val_loss: 0.8433 - val_acc: 0.7035
#
# Epoch 00013: val_acc did not improve from 0.72600
# Epoch 14/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.6099 - acc: 0.7841 - val_loss: 0.7348 - val_acc: 0.7365
#
# Epoch 00014: val_acc improved from 0.72600 to 0.73650, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 15/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.5872 - acc: 0.7925 - val_loss: 0.7696 - val_acc: 0.7325
#
# Epoch 00015: val_acc did not improve from 0.73650
# Epoch 16/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.5654 - acc: 0.8025 - val_loss: 0.6686 - val_acc: 0.7730
#
# Epoch 00016: val_acc improved from 0.73650 to 0.77300, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 17/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.5521 - acc: 0.8050 - val_loss: 1.1180 - val_acc: 0.6135
#
# Epoch 00017: val_acc did not improve from 0.77300
# Epoch 18/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.6015 - acc: 0.7882 - val_loss: 0.9232 - val_acc: 0.7040
#
# Epoch 00018: val_acc did not improve from 0.77300
# Epoch 19/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.5282 - acc: 0.8132 - val_loss: 0.6355 - val_acc: 0.7875
#
# Epoch 00019: val_acc improved from 0.77300 to 0.78750, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 20/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.5020 - acc: 0.8206 - val_loss: 0.7466 - val_acc: 0.7495
#
# Epoch 00020: val_acc did not improve from 0.78750
# Epoch 21/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.5460 - acc: 0.8080 - val_loss: 1.2356 - val_acc: 0.6445
#
# Epoch 00021: val_acc did not improve from 0.78750
# Epoch 22/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.4989 - acc: 0.8248 - val_loss: 1.2647 - val_acc: 0.6525
#
# Epoch 00022: val_acc did not improve from 0.78750
# Epoch 23/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.4433 - acc: 0.8448 - val_loss: 0.6154 - val_acc: 0.7945
#
# Epoch 00023: val_acc improved from 0.78750 to 0.79450, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 24/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.4219 - acc: 0.8508 - val_loss: 0.8199 - val_acc: 0.7540
#
# Epoch 00024: val_acc did not improve from 0.79450
# Epoch 25/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.4218 - acc: 0.8505 - val_loss: 0.8772 - val_acc: 0.7305
#
# Epoch 00025: val_acc did not improve from 0.79450
# Epoch 26/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.3894 - acc: 0.8612 - val_loss: 0.8038 - val_acc: 0.7885
#
# Epoch 00026: val_acc did not improve from 0.79450
# Epoch 27/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.3871 - acc: 0.8619 - val_loss: 1.0450 - val_acc: 0.7410
#
# Epoch 00027: val_acc did not improve from 0.79450
# Epoch 28/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.3689 - acc: 0.8675 - val_loss: 0.6685 - val_acc: 0.7890
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00028: val_acc did not improve from 0.79450
# Epoch 29/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.3236 - acc: 0.8870 - val_loss: 0.5399 - val_acc: 0.8370
#
# Epoch 00029: val_acc improved from 0.79450 to 0.83700, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 30/200
# 375/375 [==============================] - 22s 58ms/step - loss: 0.2522 - acc: 0.9104 - val_loss: 0.6214 - val_acc: 0.8285
#
# Epoch 00030: val_acc did not improve from 0.83700
# Epoch 31/200
# 375/375 [==============================] - 22s 57ms/step - loss: 0.2243 - acc: 0.9214 - val_loss: 0.5947 - val_acc: 0.8415
#
# Epoch 00031: val_acc improved from 0.83700 to 0.84150, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 32/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.2223 - acc: 0.9246 - val_loss: 0.6522 - val_acc: 0.8430
#
# Epoch 00032: val_acc improved from 0.84150 to 0.84300, saving model to ./models/ratio/se_resnet_ratio_8.hdf5
# Epoch 33/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.2152 - acc: 0.9261 - val_loss: 0.6160 - val_acc: 0.8415
#
# Epoch 00033: val_acc did not improve from 0.84300
# Epoch 34/200
# 375/375 [==============================] - 21s 57ms/step - loss: 0.
# [0.4514999985694885, 0.5394999980926514, 0.5479999780654907, 0.5299999713897705, 0.640999972820282, 0.5975000262260437, 0.5665000081062317, 0.6669999957084656, 0.637499988079071, 0.7039999961853027, 0.6840000152587891, 0.7260000109672546, 0.703499972820282, 0.7365000247955322, 0.7325000166893005, 0.7730000019073486, 0.6134999990463257, 0.7039999961853027, 0.7875000238418579, 0.7494999766349792, 0.6445000171661377, 0.6524999737739563, 0.7944999933242798, 0.7540000081062317, 0.7304999828338623, 0.7885000109672546, 0.7409999966621399, 0.7889999747276306, 0.8370000123977661, 0.828499972820282, 0.8414999842643738, 0.8429999947547913, 0.8414999842643738, 0.8345000147819519, 0.8414999842643738, 0.8379999995231628, 0.8305000066757202, 0.8335000276565552, 0.8349999785423279, 0.8299999833106995, 0.8335000276565552, 0.8339999914169312]
# [1.5171183347702026, 1.3076889514923096, 1.2716052532196045, 1.366297960281372, 1.0230355262756348, 1.1709086894989014, 1.3126370906829834, 0.982509195804596, 1.0462963581085205, 0.8795915246009827, 0.9063105583190918, 0.7845312356948853, 0.8433303236961365, 0.7347541451454163, 0.7695673704147339, 0.6685642600059509, 1.1180113554000854, 0.9231860637664795, 0.6355022192001343, 0.7466252446174622, 1.2356269359588623, 1.2647486925125122, 0.6154407858848572, 0.8198914527893066, 0.8772372007369995, 0.8037577271461487, 1.0450352430343628, 0.66848224401474, 0.5398771166801453, 0.6213893890380859, 0.5946568846702576, 0.6521652340888977, 0.6159515976905823, 0.717059850692749, 0.7225168347358704, 0.758665919303894, 0.9708223938941956, 0.8259230256080627, 0.7740533947944641, 0.7932290434837341, 0.7882930040359497, 0.9201768040657043]
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 313/313 - 5s - loss: 0.6322 - acc: 0.8232
# SE_custom_resnet46_ratio1
# model accuracy: 82.32%
# top 3 accuracy: 96.16000056266785
# top 5 accuracy: 98.96000027656555

# %%
train_ratio(32,X_train,y_train,X_val,y_val,X_test, y_test)
# Out:
# Model: "SE_custom_resnet46_ratio1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        input_14[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[1][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 16, 16, 64)   0           conv1_bn[1][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 8, 8, 64)     0           conv1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 8, 8, 64)     36928       pool1[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_squeeze (Global (None, 64)           0           conv2_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_fc1 (Dense)     (None, 2)            130         conv2_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_fc2 (Dense)     (None, 64)           192         conv2_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 8, 8, 64)     36928       pool1[1][0]
# __________________________________________________________________________________________________
# tf.reshape_234 (TFOpLambda)     (None, 1, 1, 64)     0           conv2_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block1_2_bn[1][0]
#                                                                  tf.reshape_234[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 8, 8, 64)     0           conv2_block1_0_bn[1][0]
#                                                                  conv2_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block1_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block1_add[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_squeeze (Global (None, 64)           0           conv2_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_fc1 (Dense)     (None, 2)            130         conv2_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_fc2 (Dense)     (None, 64)           192         conv2_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_235 (TFOpLambda)     (None, 1, 1, 64)     0           conv2_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block2_2_bn[1][0]
#                                                                  tf.reshape_235[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 8, 8, 64)     0           conv2_block1_relu[1][0]
#                                                                  conv2_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block2_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block2_add[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_squeeze (Global (None, 64)           0           conv2_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_fc1 (Dense)     (None, 2)            130         conv2_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_fc2 (Dense)     (None, 64)           192         conv2_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_236 (TFOpLambda)     (None, 1, 1, 64)     0           conv2_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block3_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block3_2_bn[1][0]
#                                                                  tf.reshape_236[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 8, 8, 64)     0           conv2_block2_relu[1][0]
#                                                                  conv2_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block3_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block3_add[1][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (ReLU)      (None, 8, 8, 64)     0           conv2_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block4_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_squeeze (Global (None, 64)           0           conv2_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_fc1 (Dense)     (None, 2)            130         conv2_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_fc2 (Dense)     (None, 64)           192         conv2_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_237 (TFOpLambda)     (None, 1, 1, 64)     0           conv2_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block4_SE_scaling (Multip (None, 8, 8, 64)     0           conv2_block4_2_bn[1][0]
#                                                                  tf.reshape_237[0][0]
# __________________________________________________________________________________________________
# conv2_block4_add (Add)          (None, 8, 8, 64)     0           conv2_block3_relu[1][0]
#                                                                  conv2_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block4_relu (ReLU)        (None, 8, 8, 64)     0           conv2_block4_add[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_squeeze (Global (None, 128)          0           conv3_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc1 (Dense)     (None, 4)            516         conv3_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc2 (Dense)     (None, 128)          640         conv3_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 4, 4, 128)    73856       conv2_block4_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_238 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block1_2_bn[1][0]
#                                                                  tf.reshape_238[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 4, 4, 128)    0           conv3_block1_0_bn[1][0]
#                                                                  conv3_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block1_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block1_add[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_squeeze (Global (None, 128)          0           conv3_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc1 (Dense)     (None, 4)            516         conv3_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc2 (Dense)     (None, 128)          640         conv3_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_239 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block2_2_bn[1][0]
#                                                                  tf.reshape_239[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 4, 4, 128)    0           conv3_block1_relu[1][0]
#                                                                  conv3_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block2_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block2_add[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_squeeze (Global (None, 128)          0           conv3_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc1 (Dense)     (None, 4)            516         conv3_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_fc2 (Dense)     (None, 128)          640         conv3_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_240 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block3_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block3_2_bn[1][0]
#                                                                  tf.reshape_240[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 4, 4, 128)    0           conv3_block2_relu[1][0]
#                                                                  conv3_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block3_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block3_add[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_squeeze (Global (None, 128)          0           conv3_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc1 (Dense)     (None, 4)            516         conv3_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_fc2 (Dense)     (None, 128)          640         conv3_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_241 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block4_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block4_2_bn[1][0]
#                                                                  tf.reshape_241[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 4, 4, 128)    0           conv3_block3_relu[1][0]
#                                                                  conv3_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block4_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block4_add[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block5_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block5_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block5_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_squeeze (Global (None, 128)          0           conv3_block5_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_fc1 (Dense)     (None, 4)            516         conv3_block5_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_fc2 (Dense)     (None, 128)          640         conv3_block5_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_242 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block5_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block5_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block5_2_bn[1][0]
#                                                                  tf.reshape_242[0][0]
# __________________________________________________________________________________________________
# conv3_block5_add (Add)          (None, 4, 4, 128)    0           conv3_block4_relu[1][0]
#                                                                  conv3_block5_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block5_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block5_add[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block5_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (ReLU)      (None, 4, 4, 128)    0           conv3_block6_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block6_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block6_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block6_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_squeeze (Global (None, 128)          0           conv3_block6_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_fc1 (Dense)     (None, 4)            516         conv3_block6_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_fc2 (Dense)     (None, 128)          640         conv3_block6_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_243 (TFOpLambda)     (None, 1, 1, 128)    0           conv3_block6_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block6_SE_scaling (Multip (None, 4, 4, 128)    0           conv3_block6_2_bn[1][0]
#                                                                  tf.reshape_243[0][0]
# __________________________________________________________________________________________________
# conv3_block6_add (Add)          (None, 4, 4, 128)    0           conv3_block5_relu[1][0]
#                                                                  conv3_block6_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block6_relu (ReLU)        (None, 4, 4, 128)    0           conv3_block6_add[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 2, 2, 256)    33024       conv3_block6_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block1_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_squeeze (Global (None, 1024)         0           conv4_block1_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc1 (Dense)     (None, 32)           32800       conv4_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc2 (Dense)     (None, 1024)         33792       conv4_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 2, 2, 1024)   132096      conv3_block6_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_244 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block1_3_bn[1][0]
#                                                                  tf.reshape_244[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_0_bn[1][0]
#                                                                  conv4_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block1_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block1_add[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block2_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block2_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_squeeze (Global (None, 1024)         0           conv4_block2_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc1 (Dense)     (None, 32)           32800       conv4_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc2 (Dense)     (None, 1024)         33792       conv4_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_245 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block2_3_bn[1][0]
#                                                                  tf.reshape_245[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_relu[1][0]
#                                                                  conv4_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block2_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block2_add[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block3_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block3_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block3_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block3_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_squeeze (Global (None, 1024)         0           conv4_block3_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc1 (Dense)     (None, 32)           32800       conv4_block3_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_fc2 (Dense)     (None, 1024)         33792       conv4_block3_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_246 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block3_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block3_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block3_3_bn[1][0]
#                                                                  tf.reshape_246[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 2, 2, 1024)   0           conv4_block2_relu[1][0]
#                                                                  conv4_block3_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block3_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block3_add[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block3_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block4_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block4_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block4_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block4_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_squeeze (Global (None, 1024)         0           conv4_block4_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc1 (Dense)     (None, 32)           32800       conv4_block4_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_fc2 (Dense)     (None, 1024)         33792       conv4_block4_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_247 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block4_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block4_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block4_3_bn[1][0]
#                                                                  tf.reshape_247[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 2, 2, 1024)   0           conv4_block3_relu[1][0]
#                                                                  conv4_block4_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block4_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block4_add[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block4_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block5_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block5_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block5_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block5_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_squeeze (Global (None, 1024)         0           conv4_block5_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc1 (Dense)     (None, 32)           32800       conv4_block5_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_fc2 (Dense)     (None, 1024)         33792       conv4_block5_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_248 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block5_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block5_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block5_3_bn[1][0]
#                                                                  tf.reshape_248[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 2, 2, 1024)   0           conv4_block4_relu[1][0]
#                                                                  conv4_block5_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block5_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block5_add[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block5_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block6_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block6_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block6_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block6_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_squeeze (Global (None, 1024)         0           conv4_block6_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc1 (Dense)     (None, 32)           32800       conv4_block6_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_fc2 (Dense)     (None, 1024)         33792       conv4_block6_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_249 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block6_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block6_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block6_3_bn[1][0]
#                                                                  tf.reshape_249[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 2, 2, 1024)   0           conv4_block5_relu[1][0]
#                                                                  conv4_block6_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block6_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block6_add[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block6_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block7_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block7_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block7_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block7_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block7_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block7_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block7_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block7_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block7_SE_squeeze (Global (None, 1024)         0           conv4_block7_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block7_SE_fc1 (Dense)     (None, 32)           32800       conv4_block7_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block7_SE_fc2 (Dense)     (None, 1024)         33792       conv4_block7_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_250 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block7_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block7_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block7_3_bn[1][0]
#                                                                  tf.reshape_250[0][0]
# __________________________________________________________________________________________________
# conv4_block7_add (Add)          (None, 2, 2, 1024)   0           conv4_block6_relu[1][0]
#                                                                  conv4_block7_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block7_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block7_add[1][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block7_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block8_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block8_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block8_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block8_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (ReLU)      (None, 2, 2, 256)    0           conv4_block8_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block8_2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block8_3_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_squeeze (Global (None, 1024)         0           conv4_block8_3_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_fc1 (Dense)     (None, 32)           32800       conv4_block8_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_fc2 (Dense)     (None, 1024)         33792       conv4_block8_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_251 (TFOpLambda)     (None, 1, 1, 1024)   0           conv4_block8_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block8_SE_scaling (Multip (None, 2, 2, 1024)   0           conv4_block8_3_bn[1][0]
#                                                                  tf.reshape_251[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, 2, 2, 1024)   0           conv4_block7_relu[1][0]
#                                                                  conv4_block8_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block8_relu (ReLU)        (None, 2, 2, 1024)   0           conv4_block8_add[1][0]
# __________________________________________________________________________________________________
# pool_out (GlobalAveragePooling2 (None, 1024)         0           conv4_block8_relu[1][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 10)           10250       pool_out[1][0]
# ==================================================================================================
# Total params: 11,554,538
# Trainable params: 11,523,306
# Non-trainable params: 31,232
# __________________________________________________________________________________________________
# Epoch 1/200
# 153/375 [===========>..................] - ETA: 12s - loss: 2.5216 - acc: 0.2367
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-031361a28bc0> in <module>
# ----> 1 train_ratio(32,X_train,y_train,X_val,y_val,X_test, y_test)
#
# ~/envTF24/e4040-2021fall-project-fren-an3078-wab2138-av3023/utils/train_ratio.py in train_ratio(ratio, X_train, y_train, X_val, y_val, X_test, y_test)
#      39                         epochs=200,
#      40                         validation_data=(X_val,y_val),
# ---> 41                         callbacks=[reduce_lr,es,checkpoint])
#      42
#      43     plot_model(history)
#
# ~/envTF24/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/envTF24/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/envTF24/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/envTF24/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~/envTF24/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~/envTF24/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~/envTF24/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
