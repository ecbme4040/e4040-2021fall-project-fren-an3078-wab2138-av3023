# %% [markdown]
# The dataset Tiny ImageNet has to be in the 'data/' folder

# %% [markdown]
# Instruction to download and extract the data:
#
# wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
#
# unzip tiny-imagenet-200.zip
#
# rm tiny-imagenet-200.zip

# %%
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
from tensorflow.python.client import device_lib
def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]
print(get_available_devices()) 

import os
import pandas as pd
import numpy as np
from PIL import Image
# Out:
# ['/device:CPU:0', '/device:GPU:0']

# %% [markdown]
# # 0. Loading the data

# %% [markdown]
# ### TinyImageNet does not have labels for the testing data. We will use the 10k validation images for the testing data.

# %%
#Generate dataset

###### TRAINING DATA #######
#Load Training images and labels
train_directory = "./data/tiny-imagenet-200/train" 
image_list=[]
label_list=[]

label_dic={} #convert label str to int from 0 



for l,sub_dir in enumerate(os.listdir(train_directory)):
    if not sub_dir in label_dic:
        label_dic[sub_dir]=l
    sub_dir_name=os.path.join(train_directory,sub_dir,'images')
    n=0
    for file in os.listdir(sub_dir_name):
        filename = os.fsdecode(file)
        if filename.endswith(".JPEG")  or filename.endswith(".jpg") or filename.endswith(".png"):
            img=np.array(Image.open(os.path.join(sub_dir_name,file)))
            if(img.shape == (64, 64, 3)): #removing images without 3 channels
                image_list.append(img)
                label_list.append(int(label_dic[sub_dir]))
                n+=1
    print(n,'pictures in folder',sub_dir,sep=' ' )
            
X_tot=np.array(image_list)
y_tot=np.array(label_list)

###### TEST DATA #######

#getting the labels from the txt file
df = pd.read_table('./data/tiny-imagenet-200/val/val_annotations.txt', header=None)
test_labels={} 
for index, row in df.iterrows():
    test_labels[str(row[0])]= row[1]


test_directory = "./data/tiny-imagenet-200/val/images" 

test_image_list=[]
test_label_list=[]

for file in os.listdir(test_directory):
    filename = os.fsdecode(file)
  
    if filename.endswith(".JPEG")  or filename.endswith(".jpg") or filename.endswith(".png"):
        img=np.array(Image.open(os.path.join(test_directory,file)))
        if(img.shape == (64, 64, 3)): #removing images without 3 channels
            test_image_list.append(img)
            test_label_list.append(label_dic[test_labels[filename]])
            
X_test=np.array(test_image_list)
y_test=tf.keras.utils.to_categorical(np.array(test_label_list))
# Out:
# 500 pictures in folder n01443537
# 500 pictures in folder n01629819
# 500 pictures in folder n01641577
# 498 pictures in folder n01644900
# 496 pictures in folder n01698640
# 499 pictures in folder n01742172
# 492 pictures in folder n01768244
# 497 pictures in folder n01770393
# 497 pictures in folder n01774384
# 495 pictures in folder n01774750
# 500 pictures in folder n01784675
# 498 pictures in folder n01855672
# 499 pictures in folder n01882714
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16060/1941096161.py in <module>
#      19         filename = os.fsdecode(file)
#      20         if filename.endswith(".JPEG")  or filename.endswith(".jpg") or filename.endswith(".png"):
# ---> 21             img=np.array(Image.open(os.path.join(sub_dir_name,file)))
#      22             if(img.shape == (64, 64, 3)): #removing images without 3 channels
#      23                 image_list.append(img)
#
# ~\anaconda3\envs\envTF24\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2975         exclusive_fp = True
#    2976
# -> 2977     prefix = fp.read(16)
#    2978
#    2979     preinit()
#
# KeyboardInterrupt:

# %%
shuffler=np.random.RandomState(seed=10).permutation(len(X_tot))
X_tot = X_tot[shuffler]
y_tot = y_tot[shuffler]
y_tot=tf.keras.utils.to_categorical(y_tot)

X_train = X_tot[5000:]
y_train =  y_tot[5000:]
X_val = X_tot[:5000]
y_val =  y_tot[:5000]


print('test data:')
print(X_test.shape)
print(y_test.shape)

print('train data:')
print(X_train.shape)
print(y_train.shape)

print('val data:')
print(X_val.shape)
print(y_val.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16060/731497066.py in <module>
# ----> 1 shuffler=np.random.RandomState(seed=10).permutation(len(X_tot))
#       2 X_tot = X_tot[shuffler]
#       3 y_tot = y_tot[shuffler]
#       4 y_tot=tf.keras.utils.to_categorical(y_tot)
#       5
#
# NameError: name 'X_tot' is not defined

# %% [markdown]
# #### Saving the variables allows faster loading in the future

# %%
#save for future use without having to reload from the images folders
np.save('data/X_test.npy', X_test)
np.save('data/y_test.npy', y_test)
np.save('data/X_train.npy', X_train)
np.save('data/y_train.npy', y_train)
np.save('data/X_val.npy', X_val)
np.save('data/y_val.npy', y_val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16060/2848788757.py in <module>
#       1 #save for future use without having to reload from the images folders
# ----> 2 np.save('data/X_test.npy', X_test)
#       3 np.save('data/y_test.npy', y_test)
#       4 np.save('data/X_train.npy', X_train)
#       5 np.save('data/y_train.npy', y_train)
#
# NameError: name 'X_test' is not defined

# %%
X_test = np.load('data/X_test.npy')
y_test = np.load('data/y_test.npy')
X_train = np.load('data/X_train.npy')
y_train = np.load('data/y_train.npy')
X_val = np.load('data/X_val.npy')
y_val = np.load('data/y_val.npy')

# %% [markdown]
# # 1. Using ResNet18 with ImageNet

# %% [markdown]
# ### We use our custom resnet model generator to get any resnet
#
# Imagenet has 200 different labels and is downsampled from ImageNet to a resolution of 64x64

# %%
from utils.custom_resnet import custom_resnet18

resnet_18=custom_resnet18(input_shape=(64,64,3),n_classes=200)
resnet_18.summary()
# Out:
# Model: "custom_resnet18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 32, 32, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 32, 32, 64)   0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 16, 16, 64)   0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 16, 16, 64)   36928       pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (ReLU)      (None, 16, 16, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 16, 16, 64)   36928       pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 16, 16, 64)   0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_relu (ReLU)        (None, 16, 16, 64)   0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (ReLU)      (None, 16, 16, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 16, 16, 64)   0           conv2_block1_relu[0][0]
#                                                                  conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_relu (ReLU)        (None, 16, 16, 64)   0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 8, 8, 128)    73856       conv2_block2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (ReLU)      (None, 8, 8, 128)    0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 8, 8, 128)    73856       conv2_block2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 8, 8, 128)    0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_relu (ReLU)        (None, 8, 8, 128)    0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (ReLU)      (None, 8, 8, 128)    0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 8, 8, 128)    0           conv3_block1_relu[0][0]
#                                                                  conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_relu (ReLU)        (None, 8, 8, 128)    0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 4, 4, 256)    295168      conv3_block2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 4, 4, 256)    295168      conv3_block2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 4, 4, 256)    0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 4, 4, 256)    0           conv4_block1_relu[0][0]
#                                                                  conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 2, 2, 512)    1180160     conv4_block2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (ReLU)      (None, 2, 2, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 2, 2, 512)    1180160     conv4_block2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 2, 2, 512)    0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_relu (ReLU)        (None, 2, 2, 512)    0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (ReLU)      (None, 2, 2, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 2, 2, 512)    0           conv5_block1_relu[0][0]
#                                                                  conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_relu (ReLU)        (None, 2, 2, 512)    0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# pool_out (GlobalAveragePooling2 (None, 512)          0           conv5_block2_relu[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 200)          102600      pool_out[0][0]
# ==================================================================================================
# Total params: 12,706,952
# Trainable params: 12,697,224
# Non-trainable params: 9,728
# __________________________________________________________________________________________________

# %% [markdown]
# ## 1.1 Resnet without data augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler
base_learning_rate=0.6
epochs=45
batch_size=128

train_datagen = ImageDataGenerator(
    # no augmentation
        )

# CHange learning rate
def change_learning_rate(epoch, lr):
    if epoch % 14 == 0 and epoch:
        print('new learning rate: ',lr)
        return 0.1 *lr
    return lr

lr_callback = [LearningRateScheduler(change_learning_rate, verbose=1)]

#Early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_acc', mode='max', patience=7)

resnet_18.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=base_learning_rate,momentum=0.9),loss='categorical_crossentropy', metrics = ['acc'])


train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
step_size_train=train_generator.n//train_generator.batch_size

history_resnet_18=resnet_18.fit(train_generator,
                   steps_per_epoch = step_size_train,
                   epochs = epochs,
                   validation_data=(X_val, y_val),
                   callbacks=[lr_callback,es])
# Out:
# Epoch 1/45
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 52s 61ms/step - loss: 5.7145 - acc: 0.0057 - val_loss: 5.2335 - val_acc: 0.0082
# Epoch 2/45
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 40s 54ms/step - loss: 5.1289 - acc: 0.0118 - val_loss: 5.6034 - val_acc: 0.0120
# Epoch 3/45
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 40s 55ms/step - loss: 4.8841 - acc: 0.0268 - val_loss: 5.0003 - val_acc: 0.0222
# Epoch 4/45
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 41s 56ms/step - loss: 4.6534 - acc: 0.0446 - val_loss: 6.1477 - val_acc: 0.0242
# Epoch 5/45
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 39s 54ms/step - loss: 4.3227 - acc: 0.0800 - val_loss: 4.6208 - val_acc: 0.0740
# Epoch 6/45
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 40s 55ms/step - loss: 3.9461 - acc: 0.1411 - val_loss: 4.1160 - val_acc: 0.1216
# Epoch 7/45
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 41s 57ms/step - loss: 3.6577 - acc: 0.1828 - val_loss: 4.8459 - val_acc: 0.0862
# Epoch 8/45
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 40s 55ms/step - loss: 3.4018 - acc: 0.2259 - val_loss: 3.5537 - val_acc: 0.2156
# Epoch 9/45
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 39s 54ms/step - loss: 3.1887 - acc: 0.2654 - val_loss: 3.6766 - val_acc: 0.1890
# Epoch 10/45
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 39s 54ms/step - loss: 2.9794 - acc: 0.3025 - val_loss: 4.2532 - val_acc: 0.1634
# Epoch 11/45
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 40s 55ms/step - loss: 2.7750 - acc: 0.3388 - val_loss: 3.5892 - val_acc: 0.2366
# Epoch 12/45
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 39s 53ms/step - loss: 2.5411 - acc: 0.3827 - val_loss: 3.8683 - val_acc: 0.2072
# Epoch 13/45
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 39s 54ms/step - loss: 2.2976 - acc: 0.4308 - val_loss: 3.4800 - val_acc: 0.2610
# Epoch 14/45
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 40s 54ms/step - loss: 2.0593 - acc: 0.4771 - val_loss: 4.0722 - val_acc: 0.2122
# Epoch 15/45
# new learning rate:  0.6000000238418579
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 40s 54ms/step - loss: 1.3943 - acc: 0.6321 - val_loss: 3.4931 - val_acc: 0.3136
# Epoch 16/45
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 39s 54ms/step - loss: 0.8824 - acc: 0.7637 - val_loss: 3.7979 - val_acc: 0.3074
# Epoch 17/45
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 39s 54ms/step - loss: 0.6427 - acc: 0.8299 - val_loss: 4.1884 - val_acc: 0.2888
# Epoch 18/45
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 40s 55ms/step - loss: 0.4409 - acc: 0.8889 - val_loss: 4.5782 - val_acc: 0.2908
# Epoch 19/45
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 40s 55ms/step - loss: 0.2838 - acc: 0.9358 - val_loss: 5.0589 - val_acc: 0.2830
# Epoch 20/45
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 41s 56ms/step - loss: 0.1684 - acc: 0.9663 - val_loss: 5.4225 - val_acc: 0.2856
# Epoch 21/45
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 40s 55ms/step - loss: 0.0981 - acc: 0.9846 - val_loss: 5.7843 - val_acc: 0.2854
# Epoch 22/45
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 40s 55ms/step - loss: 0.0581 - acc: 0.9937 - val_loss: 6.1495 - val_acc: 0.2806

# %% [markdown]
# #### How to save the model and reload it

# %%
# Evaluate the model
loss, acc = resnet_18.evaluate(X_test, y_test, verbose=2)
print(" model, accuracy: {:5.2f}%".format(100 * acc))

# Save the weights

resnet_18.save_weights('./models/tinyImageNet/resnet_18')

# reload from saved weights:
model = custom_resnet18(input_shape=(64,64,3),n_classes=200)
model.load_weights('./models/tinyImageNet/resnet_18')

# Evaluate the model
model.compile(loss='categorical_crossentropy', metrics = ['acc'])
loss, acc = model.evaluate(X_test, y_test, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 308/308 - 2s - loss: 6.1252 - acc: 0.2840
#  model, accuracy: 28.40%
# 308/308 - 2s - loss: 6.1252 - acc: 0.2840
# Restored model, accuracy: 28.40%

# %%
print(history_resnet_18.history.keys())
acc = history_resnet_18.history['acc']
val_acc = history_resnet_18.history['val_acc']

loss = history_resnet_18.history['loss']
val_loss = history_resnet_18.history['val_loss']

import matplotlib.pyplot as plt
plt.plot(acc, label='Training Accuracy', color="blue")
plt.plot(val_acc, label='Validation Accuracy', color="r")
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17076/752647912.py in <module>
# ----> 1 print(history_resnet_18.history.keys())
#       2 acc = history_resnet_18.history['acc']
#       3 val_acc = history_resnet_18.history['val_acc']
#       4
#       5 loss = history_resnet_18.history['loss']
#
# NameError: name 'history_resnet_18' is not defined

# %% [markdown]
# Accuracy and loss graphs

# %%
import matplotlib.pyplot as plt

acc = history_resnet_18.history['acc']
val_acc = history_resnet_18.history['val_acc']

loss = history_resnet_18.history['loss']
val_loss = history_resnet_18.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy', color="blue")
plt.plot(val_acc, label='Validation Accuracy', color="r")
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss', color="blue")
plt.plot(val_loss, label='Validation Loss', color="r")
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')

plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## 1.2 Resnet18 With data augmentation

# %%
from utils.custom_resnet import custom_resnet18
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler

resnet_18_aug=custom_resnet18(input_shape=(64,64,3),n_classes=200)

# %%
base_learning_rate=0.6
epochs=45
batch_size=128

train_datagen = ImageDataGenerator(
    horizontal_flip=True,
    width_shift_range=8, #+-8 pixel shift max
    height_shift_range=8,#+-8 pixel shift max
    brightness_range=[0.8,1.2],
    rotation_range=2 #very little rotation
        )

# CHange learning rate
def change_learning_rate(epoch, lr):
    if epoch % 14 == 0 and epoch:
        print('new learning rate: ',lr)
        return 0.1 *lr
    return lr
lr_callback = [LearningRateScheduler(change_learning_rate, verbose=1)]
#Early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_acc', mode='max', patience=7)

resnet_18_aug.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=base_learning_rate,momentum=0.9),loss='categorical_crossentropy', metrics = ['acc'])


train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
step_size_train=train_generator.n//train_generator.batch_size

history_resnet_18_aug=resnet_18_aug.fit(train_generator,
                   steps_per_epoch = step_size_train,
                   epochs = epochs,
                   validation_data=(X_val, y_val),
                   callbacks=[lr_callback,es])
# Out:
# Epoch 1/45
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 89s 113ms/step - loss: 5.8657 - acc: 0.0061 - val_loss: 5.1698 - val_acc: 0.0138
# Epoch 2/45
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 76s 104ms/step - loss: 5.1088 - acc: 0.0140 - val_loss: 6.1985 - val_acc: 0.0094
# Epoch 3/45
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 79s 108ms/step - loss: 4.8256 - acc: 0.0296 - val_loss: 4.6692 - val_acc: 0.0448
# Epoch 4/45
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 80s 109ms/step - loss: 4.5368 - acc: 0.0561 - val_loss: 4.5398 - val_acc: 0.0572
# Epoch 5/45
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 76s 104ms/step - loss: 4.2320 - acc: 0.0959 - val_loss: 4.3217 - val_acc: 0.0974
# Epoch 6/45
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 77s 106ms/step - loss: 3.9385 - acc: 0.1386 - val_loss: 4.7520 - val_acc: 0.0846
# Epoch 7/45
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 78s 107ms/step - loss: 3.7206 - acc: 0.1729 - val_loss: 3.8954 - val_acc: 0.1624
# Epoch 8/45
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 77s 106ms/step - loss: 3.5651 - acc: 0.1983 - val_loss: 4.8496 - val_acc: 0.1010
# Epoch 9/45
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 77s 106ms/step - loss: 3.4217 - acc: 0.2246 - val_loss: 4.0531 - val_acc: 0.1514
# Epoch 10/45
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 78s 107ms/step - loss: 3.2815 - acc: 0.2502 - val_loss: 3.8756 - val_acc: 0.1782
# Epoch 11/45
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 79s 108ms/step - loss: 3.1685 - acc: 0.2719 - val_loss: 4.7617 - val_acc: 0.1146
# Epoch 12/45
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 77s 105ms/step - loss: 3.0866 - acc: 0.2855 - val_loss: 3.5575 - val_acc: 0.2284
# Epoch 13/45
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 78s 107ms/step - loss: 3.0069 - acc: 0.2975 - val_loss: 3.4237 - val_acc: 0.2442
# Epoch 14/45
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 727/727 [==============================] - 76s 104ms/step - loss: 2.8998 - acc: 0.3174 - val_loss: 3.5107 - val_acc: 0.2290
# Epoch 15/45
# new learning rate:  0.6000000238418579
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 77s 106ms/step - loss: 2.6466 - acc: 0.3684 - val_loss: 2.7642 - val_acc: 0.3578
# Epoch 16/45
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 78s 108ms/step - loss: 2.4447 - acc: 0.4123 - val_loss: 2.8074 - val_acc: 0.3488
# Epoch 17/45
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 78s 107ms/step - loss: 2.3829 - acc: 0.4200 - val_loss: 2.7183 - val_acc: 0.3686
# Epoch 18/45
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 79s 109ms/step - loss: 2.3376 - acc: 0.4323 - val_loss: 2.6969 - val_acc: 0.3726
# Epoch 19/45
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 79s 109ms/step - loss: 2.3082 - acc: 0.4348 - val_loss: 2.7406 - val_acc: 0.3692
# Epoch 20/45
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 77s 106ms/step - loss: 2.2577 - acc: 0.4466 - val_loss: 2.7180 - val_acc: 0.3758
# Epoch 21/45
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 78s 108ms/step - loss: 2.2478 - acc: 0.4468 - val_loss: 2.7204 - val_acc: 0.3758
# Epoch 22/45
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 79s 108ms/step - loss: 2.1876 - acc: 0.4612 - val_loss: 2.7253 - val_acc: 0.3770
# Epoch 23/45
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 77s 105ms/step - loss: 2.1739 - acc: 0.4612 - val_loss: 2.8600 - val_acc: 0.3496
# Epoch 24/45
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 86s 118ms/step - loss: 2.1123 - acc: 0.4745 - val_loss: 2.7383 - val_acc: 0.3746
# Epoch 25/45
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 83s 114ms/step - loss: 2.0874 - acc: 0.4795 - val_loss: 2.6891 - val_acc: 0.3820
# Epoch 26/45
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 79s 108ms/step - loss: 2.0475 - acc: 0.4910 - val_loss: 2.7363 - val_acc: 0.3782
# Epoch 27/45
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 80s 109ms/step - loss: 2.0148 - acc: 0.4951 - val_loss: 2.7767 - val_acc: 0.3770
# Epoch 28/45
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.06000000238418579.
# 727/727 [==============================] - 80s 109ms/step - loss: 1.9653 - acc: 0.5038 - val_loss: 2.7500 - val_acc: 0.3812
# Epoch 29/45
# new learning rate:  0.06000000238418579
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.006000000238418579.
# 727/727 [==============================] - 81s 111ms/step - loss: 1.8831 - acc: 0.5230 - val_loss: 2.6473 - val_acc: 0.4058
# Epoch 30/45
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 78s 107ms/step - loss: 1.8345 - acc: 0.5357 - val_loss: 2.6588 - val_acc: 0.4086
# Epoch 31/45
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 78s 107ms/step - loss: 1.7979 - acc: 0.5426 - val_loss: 2.6524 - val_acc: 0.4104
# Epoch 32/45
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 81s 111ms/step - loss: 1.7910 - acc: 0.5447 - val_loss: 2.6736 - val_acc: 0.4096
# Epoch 33/45
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 80s 109ms/step - loss: 1.7824 - acc: 0.5451 - val_loss: 2.6766 - val_acc: 0.4068
# Epoch 34/45
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 78s 107ms/step - loss: 1.7578 - acc: 0.5520 - val_loss: 2.6762 - val_acc: 0.4056
# Epoch 35/45
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 78s 107ms/step - loss: 1.7554 - acc: 0.5514 - val_loss: 2.6846 - val_acc: 0.4056
# Epoch 36/45
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 76s 105ms/step - loss: 1.7400 - acc: 0.5562 - val_loss: 2.6809 - val_acc: 0.4054
# Epoch 37/45
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 79s 109ms/step - loss: 1.7227 - acc: 0.5614 - val_loss: 2.6878 - val_acc: 0.4052
# Epoch 38/45
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.006000000052154064.
# 727/727 [==============================] - 79s 109ms/step - loss: 1.7168 - acc: 0.5593 - val_loss: 2.7091 - val_acc: 0.3998

# %%
# Evaluate the model
loss, acc = resnet_18_aug.evaluate(X_test, y_test, verbose=2)
print(" model, accuracy: {:5.2f}%".format(100 * acc))

# Save the weights

resnet_18_aug.save_weights('./models/tinyImageNet/resnet_18_aug')

# reload from saved weights:
model = custom_resnet18(input_shape=(64,64,3),n_classes=200)
model.load_weights('./models/tinyImageNet/resnet_18_aug')

# Evaluate the model
model.compile(loss='categorical_crossentropy', metrics = ['acc'])
loss, acc = model.evaluate(X_test, y_test, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 308/308 - 2s - loss: 2.7554 - acc: 0.3845
#  model, accuracy: 38.45%
# 308/308 - 2s - loss: 2.7554 - acc: 0.3845
# Restored model, accuracy: 38.45%

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
acc = [1,6,4,5,4,5,7,8]
val_acc = [1,1,2,5,4,5,7,8]


plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy', color="blue")
plt.plot(val_acc, label='Validation Accuracy', color="r")
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.show()

# %% [markdown]
# # 2. SE-ResNet18

# %% [markdown]
# ## 2.1 SE-ResNet18 without data augmentation

# %%
from utils.SE_resnet import SE_resnet18

SE_resnet18=SE_resnet18(input_shape=(64,64,3),n_classes=200,name='SE_resnet18')
SE_resnet18.summary()
# Out:
# Model: "SE_ResNet18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 32, 32, 64)   256         conv1_conv[1][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 32, 32, 64)   0           conv1_bn[1][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 16, 16, 64)   0           conv1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 16, 16, 64)   36928       pool1[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (ReLU)      (None, 16, 16, 64)   0           conv2_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_squeeze (Global (None, 64)           0           conv2_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_fc1 (Dense)     (None, 4)            260         conv2_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_fc2 (Dense)     (None, 64)           320         conv2_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 16, 16, 64)   36928       pool1[1][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None, 1, 1, 64)     0           conv2_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block1_SE_scaling (Multip (None, 16, 16, 64)   0           conv2_block1_2_bn[1][0]
#                                                                  tf.reshape[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 16, 16, 64)   0           conv2_block1_0_bn[1][0]
#                                                                  conv2_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block1_relu (ReLU)        (None, 16, 16, 64)   0           conv2_block1_add[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (ReLU)      (None, 16, 16, 64)   0           conv2_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_squeeze (Global (None, 64)           0           conv2_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_fc1 (Dense)     (None, 4)            260         conv2_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_fc2 (Dense)     (None, 64)           320         conv2_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_1 (TFOpLambda)       (None, 1, 1, 64)     0           conv2_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv2_block2_SE_scaling (Multip (None, 16, 16, 64)   0           conv2_block2_2_bn[1][0]
#                                                                  tf.reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 16, 16, 64)   0           conv2_block1_relu[1][0]
#                                                                  conv2_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv2_block2_relu (ReLU)        (None, 16, 16, 64)   0           conv2_block2_add[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 8, 8, 128)    73856       conv2_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (ReLU)      (None, 8, 8, 128)    0           conv3_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_squeeze (Global (None, 128)          0           conv3_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc1 (Dense)     (None, 8)            1032        conv3_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_fc2 (Dense)     (None, 128)          1152        conv3_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 8, 8, 128)    73856       conv2_block2_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_2 (TFOpLambda)       (None, 1, 1, 128)    0           conv3_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block1_SE_scaling (Multip (None, 8, 8, 128)    0           conv3_block1_2_bn[1][0]
#                                                                  tf.reshape_2[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 8, 8, 128)    0           conv3_block1_0_bn[1][0]
#                                                                  conv3_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block1_relu (ReLU)        (None, 8, 8, 128)    0           conv3_block1_add[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (ReLU)      (None, 8, 8, 128)    0           conv3_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_squeeze (Global (None, 128)          0           conv3_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc1 (Dense)     (None, 8)            1032        conv3_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_fc2 (Dense)     (None, 128)          1152        conv3_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_3 (TFOpLambda)       (None, 1, 1, 128)    0           conv3_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv3_block2_SE_scaling (Multip (None, 8, 8, 128)    0           conv3_block2_2_bn[1][0]
#                                                                  tf.reshape_3[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 8, 8, 128)    0           conv3_block1_relu[1][0]
#                                                                  conv3_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv3_block2_relu (ReLU)        (None, 8, 8, 128)    0           conv3_block2_add[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 4, 4, 256)    295168      conv3_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_squeeze (Global (None, 256)          0           conv4_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc1 (Dense)     (None, 16)           4112        conv4_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_fc2 (Dense)     (None, 256)          4352        conv4_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 4, 4, 256)    295168      conv3_block2_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_4 (TFOpLambda)       (None, 1, 1, 256)    0           conv4_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block1_SE_scaling (Multip (None, 4, 4, 256)    0           conv4_block1_2_bn[1][0]
#                                                                  tf.reshape_4[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 4, 4, 256)    0           conv4_block1_0_bn[1][0]
#                                                                  conv4_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block1_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block1_add[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (ReLU)      (None, 4, 4, 256)    0           conv4_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_squeeze (Global (None, 256)          0           conv4_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc1 (Dense)     (None, 16)           4112        conv4_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_fc2 (Dense)     (None, 256)          4352        conv4_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_5 (TFOpLambda)       (None, 1, 1, 256)    0           conv4_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv4_block2_SE_scaling (Multip (None, 4, 4, 256)    0           conv4_block2_2_bn[1][0]
#                                                                  tf.reshape_5[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 4, 4, 256)    0           conv4_block1_relu[1][0]
#                                                                  conv4_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv4_block2_relu (ReLU)        (None, 4, 4, 256)    0           conv4_block2_add[1][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 2, 2, 512)    1180160     conv4_block2_relu[1][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_1_conv[1][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (ReLU)      (None, 2, 2, 512)    0           conv5_block1_1_bn[1][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block1_1_relu[1][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_2_conv[1][0]
# __________________________________________________________________________________________________
# conv5_block1_SE_squeeze (Global (None, 512)          0           conv5_block1_2_bn[1][0]
# __________________________________________________________________________________________________
# conv5_block1_SE_fc1 (Dense)     (None, 32)           16416       conv5_block1_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv5_block1_SE_fc2 (Dense)     (None, 512)          16896       conv5_block1_SE_fc1[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 2, 2, 512)    1180160     conv4_block2_relu[1][0]
# __________________________________________________________________________________________________
# tf.reshape_6 (TFOpLambda)       (None, 1, 1, 512)    0           conv5_block1_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_0_conv[1][0]
# __________________________________________________________________________________________________
# conv5_block1_SE_scaling (Multip (None, 2, 2, 512)    0           conv5_block1_2_bn[1][0]
#                                                                  tf.reshape_6[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 2, 2, 512)    0           conv5_block1_0_bn[1][0]
#                                                                  conv5_block1_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv5_block1_relu (ReLU)        (None, 2, 2, 512)    0           conv5_block1_add[1][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block1_relu[1][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_1_conv[1][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (ReLU)      (None, 2, 2, 512)    0           conv5_block2_1_bn[1][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block2_1_relu[1][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_2_conv[1][0]
# __________________________________________________________________________________________________
# conv5_block2_SE_squeeze (Global (None, 512)          0           conv5_block2_2_bn[1][0]
# __________________________________________________________________________________________________
# conv5_block2_SE_fc1 (Dense)     (None, 32)           16416       conv5_block2_SE_squeeze[0][0]
# __________________________________________________________________________________________________
# conv5_block2_SE_fc2 (Dense)     (None, 512)          16896       conv5_block2_SE_fc1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_7 (TFOpLambda)       (None, 1, 1, 512)    0           conv5_block2_SE_fc2[0][0]
# __________________________________________________________________________________________________
# conv5_block2_SE_scaling (Multip (None, 2, 2, 512)    0           conv5_block2_2_bn[1][0]
#                                                                  tf.reshape_7[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 2, 2, 512)    0           conv5_block1_relu[1][0]
#                                                                  conv5_block2_SE_scaling[0][0]
# __________________________________________________________________________________________________
# conv5_block2_relu (ReLU)        (None, 2, 2, 512)    0           conv5_block2_add[1][0]
# __________________________________________________________________________________________________
# pool_out (GlobalAveragePooling2 (None, 512)          0           conv5_block2_relu[1][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 200)          102600      pool_out[1][0]
# ==================================================================================================
# Total params: 12,796,032
# Trainable params: 12,786,304
# Non-trainable params: 9,728
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler
base_learning_rate=0.6
epochs=45
batch_size=128

train_datagen = ImageDataGenerator(
    # no augmentation
        )

# CHange learning rate
def change_learning_rate(epoch, lr):
    if epoch % 14 == 0 and epoch:
        print('new learning rate: ',lr)
        return 0.1 *lr
    return lr

lr_callback = [LearningRateScheduler(change_learning_rate, verbose=1)]

#Early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_acc', mode='max', patience=8)

SE_resnet18.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=base_learning_rate,momentum=0.9),loss='categorical_crossentropy', metrics = ['acc'])


train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
step_size_train=train_generator.n//train_generator.batch_size

history_SE_resnet18=SE_resnet18.fit(train_generator,
                   steps_per_epoch = step_size_train,
                   epochs = epochs,
                   validation_data=(X_val, y_val),
                   callbacks=[lr_callback,es])
# Out:
# Epoch 1/45
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.6000000238418579.
# 138/727 [====>.........................] - ETA: 35s - loss: 0.3671 - acc: 0.8883
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18444/2001563767.py in <module>
#      31                    epochs = epochs,
#      32                    validation_data=(X_val, y_val),
# ---> 33                    callbacks=[lr_callback,es])
#
# ~\anaconda3\envs\envTF24\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~\anaconda3\envs\envTF24\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\envs\envTF24\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\envs\envTF24\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~\anaconda3\envs\envTF24\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~\anaconda3\envs\envTF24\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~\anaconda3\envs\envTF24\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
