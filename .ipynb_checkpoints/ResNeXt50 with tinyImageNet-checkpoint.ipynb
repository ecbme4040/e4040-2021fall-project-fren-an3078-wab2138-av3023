# %% [markdown]
# The dataset Tiny ImageNet has to be in the 'data/' folder

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
from tensorflow.python.client import device_lib
def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]
print(get_available_devices()) 

import os
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# ['/device:CPU:0', '/device:GPU:0']

# %% [markdown]
# Instruction to download and extract the data:
#
# wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
#
# unzip tiny-imagenet-200.zip
#
# rm tiny-imagenet-200.zip

# %% [markdown]
# # 0. Loading the data

# %% [markdown]
# ### TinyImageNet does not have labels for the testing data. We will use the 10k validation images for the testing data.

# %%
#Generate dataset

###### TRAINING DATA #######
#Load Training images and labels
train_directory = "./data/tiny-imagenet-200/train" 
image_list=[]
label_list=[]

label_dic={} #convert label str to int from 0 



for l,sub_dir in enumerate(os.listdir(train_directory)):
    if not sub_dir in label_dic:
        label_dic[sub_dir]=l
    sub_dir_name=os.path.join(train_directory,sub_dir,'images')
    n=0
    for file in os.listdir(sub_dir_name):
        filename = os.fsdecode(file)
        if filename.endswith(".JPEG")  or filename.endswith(".jpg") or filename.endswith(".png"):
            img=np.array(Image.open(os.path.join(sub_dir_name,file)))
            if(img.shape == (64, 64, 3)): #removing images without 3 channels
                image_list.append(img)
                label_list.append(int(label_dic[sub_dir]))
                n+=1
    print(n,'pictures in folder',sub_dir,sep=' ' )
            
X_tot=np.array(image_list)
y_tot=np.array(label_list)

###### TEST DATA #######

#getting the labels from the txt file
df = pd.read_table('./data/tiny-imagenet-200/val/val_annotations.txt', header=None)
test_labels={} 
for index, row in df.iterrows():
    test_labels[str(row[0])]= row[1]


test_directory = "./data/tiny-imagenet-200/val/images" 

test_image_list=[]
test_label_list=[]

for file in os.listdir(test_directory):
    filename = os.fsdecode(file)
  
    if filename.endswith(".JPEG")  or filename.endswith(".jpg") or filename.endswith(".png"):
        img=np.array(Image.open(os.path.join(test_directory,file)))
        if(img.shape == (64, 64, 3)): #removing images without 3 channels
            test_image_list.append(img)
            test_label_list.append(label_dic[test_labels[filename]])
            
X_test=np.array(test_image_list)
y_test=tf.keras.utils.to_categorical(np.array(test_label_list))
# Out:
# 497 pictures in folder n03617480
# 499 pictures in folder n09332890
# 499 pictures in folder n01917289
# 497 pictures in folder n04398044
# 496 pictures in folder n03977966
# 491 pictures in folder n04486054
# 485 pictures in folder n02481823
# 499 pictures in folder n01910747
# 500 pictures in folder n01443537
# 495 pictures in folder n02823428
# 497 pictures in folder n04254777
# 487 pictures in folder n03837869
# 500 pictures in folder n07695742
# 493 pictures in folder n03983396
# 500 pictures in folder n04597913
# 495 pictures in folder n02395406
# 500 pictures in folder n02132136
# 492 pictures in folder n04259630
# 500 pictures in folder n02279972
# 493 pictures in folder n04371430
# 500 pictures in folder n03980874
# 454 pictures in folder n03763968
# 499 pictures in folder n07768694
# 497 pictures in folder n02948072
# 497 pictures in folder n02231487
# 497 pictures in folder n02206856
# 494 pictures in folder n09428293
# 498 pictures in folder n03100240
# 473 pictures in folder n04532670
# 495 pictures in folder n01944390
# 495 pictures in folder n02099712
# 491 pictures in folder n03733131
# 500 pictures in folder n07579787
# 500 pictures in folder n01983481
# 499 pictures in folder n02415577
# 500 pictures in folder n03662601
# 496 pictures in folder n01698640
# 497 pictures in folder n01774384
# 465 pictures in folder n04356056
# 466 pictures in folder n03388043
# 481 pictures in folder n03599486
# 485 pictures in folder n04399382
# 495 pictures in folder n02233338
# 480 pictures in folder n03404251
# 498 pictures in folder n04251144
# 491 pictures in folder n02808440
# 485 pictures in folder n02814860
# 498 pictures in folder n02058221
# 491 pictures in folder n02906734
# 471 pictures in folder n04376876
# 498 pictures in folder n03796401
# 499 pictures in folder n03089624
# 473 pictures in folder n03891332
# 500 pictures in folder n09256479
# 495 pictures in folder n04070727
# 490 pictures in folder n03970156
# 494 pictures in folder n02815834
# 498 pictures in folder n04456115
# 480 pictures in folder n03126707
# 483 pictures in folder n03160309
# 500 pictures in folder n02730930
# 480 pictures in folder n04023962
# 491 pictures in folder n02113799
# 496 pictures in folder n03706229
# 477 pictures in folder n04507155
# 500 pictures in folder n07734744
# 500 pictures in folder n02226429
# 500 pictures in folder n01984695
# 497 pictures in folder n02125311
# 489 pictures in folder n03584254
# 500 pictures in folder n01950731
# 499 pictures in folder n02268443
# 496 pictures in folder n03444034
# 496 pictures in folder n02364673
# 473 pictures in folder n04366367
# 500 pictures in folder n07875152
# 498 pictures in folder n02074367
# 497 pictures in folder n03014705
# 494 pictures in folder n03854065
# 497 pictures in folder n02699494
# 494 pictures in folder n09193705
# 484 pictures in folder n04275548
# 494 pictures in folder n03042490
# 485 pictures in folder n04008634
# 496 pictures in folder n12267677
# 479 pictures in folder n03255030
# 500 pictures in folder n07583066
# 467 pictures in folder n03930313
# 492 pictures in folder n04560804
# 494 pictures in folder n02099601
# 479 pictures in folder n04074963
# 499 pictures in folder n04118538
# 500 pictures in folder n07614500
# 494 pictures in folder n02988304
# 500 pictures in folder n01629819
# 498 pictures in folder n01855672
# 495 pictures in folder n02486410
# 498 pictures in folder n01644900
# 473 pictures in folder n04311004
# 474 pictures in folder n02837789
# 500 pictures in folder n07747607
# 486 pictures in folder n02843684
# 488 pictures in folder n03937543
# 494 pictures in folder n02410509
# 481 pictures in folder n04067472
# 500 pictures in folder n01641577
# 500 pictures in folder n07873807
# 496 pictures in folder n03355925
# 492 pictures in folder n02123394
# 497 pictures in folder n01945685
# 497 pictures in folder n02802426
# 453 pictures in folder n02791270
# 498 pictures in folder n02769748
# 500 pictures in folder n02963159
# 499 pictures in folder n01742172
# 474 pictures in folder n04179913
# 497 pictures in folder n02927161
# 493 pictures in folder n02977058
# 485 pictures in folder n03976657
# 498 pictures in folder n04146614
# 500 pictures in folder n04532106
# 493 pictures in folder n02403003
# 492 pictures in folder n03670208
# 492 pictures in folder n01768244
# 473 pictures in folder n04562935
# 499 pictures in folder n02509815
# 494 pictures in folder n04487081
# 499 pictures in folder n03026506
# 499 pictures in folder n02002724
# 499 pictures in folder n03393912
# 495 pictures in folder n03770439
# 474 pictures in folder n03992509
# 468 pictures in folder n03804744
# 491 pictures in folder n03814639
# 497 pictures in folder n01770393
# 500 pictures in folder n02056570
# 497 pictures in folder n02094433
# 498 pictures in folder n07920052
# 497 pictures in folder n02085620
# 499 pictures in folder n07720875
# 495 pictures in folder n03400231
# 492 pictures in folder n02892201
# 496 pictures in folder n02504458
# 480 pictures in folder n03424325
# 479 pictures in folder n02950826
# 497 pictures in folder n04149813
# 452 pictures in folder n03544143
# 496 pictures in folder n02423022
# 482 pictures in folder n04328186
# 474 pictures in folder n03250847
# 491 pictures in folder n02814533
# 491 pictures in folder n02480495
# 477 pictures in folder n03902125
# 471 pictures in folder n02841315
# 481 pictures in folder n02793495
# 497 pictures in folder n02190166
# 466 pictures in folder n03085013
# 500 pictures in folder n07871810
# 460 pictures in folder n02883205
# 488 pictures in folder n04417672
# 484 pictures in folder n03637318
# 500 pictures in folder n01784675
# 465 pictures in folder n02788148
# 473 pictures in folder n04501370
# 488 pictures in folder n02909870
# 492 pictures in folder n02106662
# 499 pictures in folder n07749582
# 499 pictures in folder n02236044
# 500 pictures in folder n02281406
# 463 pictures in folder n03838899
# 485 pictures in folder n04099969
# 495 pictures in folder n04285008
# 488 pictures in folder n02669723
# 492 pictures in folder n02666196
# 493 pictures in folder n07753592
# 498 pictures in folder n07615774
# 480 pictures in folder n04465501
# 484 pictures in folder n02795169
# 492 pictures in folder n02917067
# 495 pictures in folder n04133789
# 495 pictures in folder n01774750
# 499 pictures in folder n01882714
# 495 pictures in folder n03649909
# 500 pictures in folder n02321529
# 497 pictures in folder n06596364
# 492 pictures in folder n02123045
# 492 pictures in folder n02124075
# 493 pictures in folder n02129165
# 500 pictures in folder n02165456
# 496 pictures in folder n09246464
# 500 pictures in folder n07711569
# 490 pictures in folder n04265275
# 497 pictures in folder n07715103
# 493 pictures in folder n03179701
# 480 pictures in folder n03447447
# 494 pictures in folder n04596742
# 500 pictures in folder n03201208
# 472 pictures in folder n02999410
# 498 pictures in folder n02437312
# 494 pictures in folder n04540053

# %%
shuffler=np.random.RandomState(seed=10).permutation(len(X_tot))
X_tot = X_tot[shuffler]
y_tot = y_tot[shuffler]
y_tot=tf.keras.utils.to_categorical(y_tot)

X_train = X_tot[5000:]
y_train =  y_tot[5000:]
X_val = X_tot[:5000]
y_val =  y_tot[:5000]


print('test data:')
print(X_test.shape)
print(y_test.shape)

print('train data:')
print(X_train.shape)
print(y_train.shape)

print('val data:')
print(X_val.shape)
print(y_val.shape)
# Out:
# test data:
# (9832, 64, 64, 3)
# (9832, 200)
# train data:
# (93179, 64, 64, 3)
# (93179, 200)
# val data:
# (5000, 64, 64, 3)
# (5000, 200)

# %% [markdown]
# #### Saving the variables allows faster loading in the future

# %%
#save for future use without having to reload from the images folders
np.save('data/X_test.npy', X_test)
np.save('data/y_test.npy', y_test)
np.save('data/X_train.npy', X_train)
np.save('data/y_train.npy', y_train)
np.save('data/X_val.npy', X_val)
np.save('data/y_val.npy', y_val)

# %%
print('script running in '+os.path.abspath("."))
X_test = np.load('./data/X_test.npy')
y_test = np.load('./data/y_test.npy')
X_train = np.load('./data/X_train.npy')
y_train = np.load('./data/y_train.npy')
X_val = np.load('./data/X_val.npy')
y_val = np.load('./data/y_val.npy')
# Out:
# script running in /home/anton/e4040-2021fall-project-fren-an3078-wab2138-av3023

# %% [markdown]
# ## 3.1 ResNeXt50 without data augmentation

# %%
from utils.custom_ResNeXt import custom_ResNeXt50
from utils.train_TinyImageNet_SE_ResNeXt import tinyImageNet_ResNeXt_train
# tinyImageNet_resnet_train(model,path,X_train,y_train,X_val,y_val,data_aug=False,learning_rate=0.6,steps=14,epochs=45,batch_size=128,es_patience=8)
ResNeXt_50=custom_ResNeXt50(input_shape=(64,64,3),n_classes=200)
ResNeXt_50.summary()
# Out:
# Model: "custom_ResNeXt50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 32, 32, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 32, 32, 64)   0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_pool (MaxPooling2D)       (None, 16, 16, 64)   0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split1_caal_1_conv (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split2_caal_1_conv (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split3_caal_1_conv (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split4_caal_1_conv (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split5_caal_1_conv (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split6_caal_1_conv (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split7_caal_1_conv (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split8_caal_1_conv (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split9_caal_1_conv (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split10_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split11_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split12_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split13_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split14_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split15_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split16_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split17_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split18_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split19_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split20_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split21_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split22_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split23_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split24_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split25_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split26_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split27_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split28_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split29_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split30_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split31_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split32_caal_1_con (None, 16, 16, 4)    260         conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_split1_caal_1_bn ( (None, 16, 16, 4)    16          conv2_block1_split1_caal_1_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split2_caal_1_bn ( (None, 16, 16, 4)    16          conv2_block1_split2_caal_1_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split3_caal_1_bn ( (None, 16, 16, 4)    16          conv2_block1_split3_caal_1_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split4_caal_1_bn ( (None, 16, 16, 4)    16          conv2_block1_split4_caal_1_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split5_caal_1_bn ( (None, 16, 16, 4)    16          conv2_block1_split5_caal_1_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split6_caal_1_bn ( (None, 16, 16, 4)    16          conv2_block1_split6_caal_1_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split7_caal_1_bn ( (None, 16, 16, 4)    16          conv2_block1_split7_caal_1_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split8_caal_1_bn ( (None, 16, 16, 4)    16          conv2_block1_split8_caal_1_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split9_caal_1_bn ( (None, 16, 16, 4)    16          conv2_block1_split9_caal_1_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split10_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split10_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split11_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split11_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split12_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split12_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split13_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split13_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split14_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split14_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split15_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split15_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split16_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split16_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split17_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split17_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split18_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split18_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split19_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split19_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split20_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split20_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split21_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split21_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split22_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split22_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split23_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split23_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split24_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split24_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split25_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split25_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split26_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split26_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split27_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split27_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split28_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split28_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split29_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split29_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split30_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split30_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split31_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split31_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split32_caal_1_bn  (None, 16, 16, 4)    16          conv2_block1_split32_caal_1_conv[
# __________________________________________________________________________________________________
# conv2_block1_split1_caal_1_relu (None, 16, 16, 4)    0           conv2_block1_split1_caal_1_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split2_caal_1_relu (None, 16, 16, 4)    0           conv2_block1_split2_caal_1_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split3_caal_1_relu (None, 16, 16, 4)    0           conv2_block1_split3_caal_1_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split4_caal_1_relu (None, 16, 16, 4)    0           conv2_block1_split4_caal_1_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split5_caal_1_relu (None, 16, 16, 4)    0           conv2_block1_split5_caal_1_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split6_caal_1_relu (None, 16, 16, 4)    0           conv2_block1_split6_caal_1_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split7_caal_1_relu (None, 16, 16, 4)    0           conv2_block1_split7_caal_1_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split8_caal_1_relu (None, 16, 16, 4)    0           conv2_block1_split8_caal_1_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split9_caal_1_relu (None, 16, 16, 4)    0           conv2_block1_split9_caal_1_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split10_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split10_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split11_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split11_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split12_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split12_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split13_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split13_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split14_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split14_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split15_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split15_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split16_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split16_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split17_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split17_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split18_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split18_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split19_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split19_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split20_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split20_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split21_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split21_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split22_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split22_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split23_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split23_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split24_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split24_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split25_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split25_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split26_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split26_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split27_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split27_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split28_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split28_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split29_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split29_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split30_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split30_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split31_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split31_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split32_caal_1_rel (None, 16, 16, 4)    0           conv2_block1_split32_caal_1_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split1_caal_2_conv (None, 16, 16, 4)    148         conv2_block1_split1_caal_1_relu[0
# __________________________________________________________________________________________________
# conv2_block1_split2_caal_2_conv (None, 16, 16, 4)    148         conv2_block1_split2_caal_1_relu[0
# __________________________________________________________________________________________________
# conv2_block1_split3_caal_2_conv (None, 16, 16, 4)    148         conv2_block1_split3_caal_1_relu[0
# __________________________________________________________________________________________________
# conv2_block1_split4_caal_2_conv (None, 16, 16, 4)    148         conv2_block1_split4_caal_1_relu[0
# __________________________________________________________________________________________________
# conv2_block1_split5_caal_2_conv (None, 16, 16, 4)    148         conv2_block1_split5_caal_1_relu[0
# __________________________________________________________________________________________________
# conv2_block1_split6_caal_2_conv (None, 16, 16, 4)    148         conv2_block1_split6_caal_1_relu[0
# __________________________________________________________________________________________________
# conv2_block1_split7_caal_2_conv (None, 16, 16, 4)    148         conv2_block1_split7_caal_1_relu[0
# __________________________________________________________________________________________________
# conv2_block1_split8_caal_2_conv (None, 16, 16, 4)    148         conv2_block1_split8_caal_1_relu[0
# __________________________________________________________________________________________________
# conv2_block1_split9_caal_2_conv (None, 16, 16, 4)    148         conv2_block1_split9_caal_1_relu[0
# __________________________________________________________________________________________________
# conv2_block1_split10_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split10_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split11_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split11_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split12_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split12_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split13_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split13_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split14_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split14_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split15_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split15_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split16_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split16_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split17_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split17_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split18_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split18_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split19_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split19_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split20_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split20_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split21_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split21_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split22_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split22_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split23_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split23_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split24_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split24_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split25_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split25_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split26_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split26_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split27_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split27_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split28_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split28_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split29_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split29_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split30_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split30_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split31_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split31_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split32_caal_2_con (None, 16, 16, 4)    148         conv2_block1_split32_caal_1_relu[
# __________________________________________________________________________________________________
# conv2_block1_split1_caal_2_bn ( (None, 16, 16, 4)    16          conv2_block1_split1_caal_2_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split2_caal_2_bn ( (None, 16, 16, 4)    16          conv2_block1_split2_caal_2_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split3_caal_2_bn ( (None, 16, 16, 4)    16          conv2_block1_split3_caal_2_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split4_caal_2_bn ( (None, 16, 16, 4)    16          conv2_block1_split4_caal_2_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split5_caal_2_bn ( (None, 16, 16, 4)    16          conv2_block1_split5_caal_2_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split6_caal_2_bn ( (None, 16, 16, 4)    16          conv2_block1_split6_caal_2_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split7_caal_2_bn ( (None, 16, 16, 4)    16          conv2_block1_split7_caal_2_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split8_caal_2_bn ( (None, 16, 16, 4)    16          conv2_block1_split8_caal_2_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split9_caal_2_bn ( (None, 16, 16, 4)    16          conv2_block1_split9_caal_2_conv[0
# __________________________________________________________________________________________________
# conv2_block1_split10_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split10_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split11_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split11_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split12_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split12_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split13_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split13_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split14_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split14_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split15_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split15_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split16_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split16_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split17_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split17_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split18_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split18_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split19_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split19_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split20_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split20_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split21_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split21_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split22_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split22_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split23_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split23_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split24_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split24_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split25_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split25_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split26_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split26_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split27_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split27_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split28_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split28_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split29_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split29_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split30_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split30_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split31_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split31_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split32_caal_2_bn  (None, 16, 16, 4)    16          conv2_block1_split32_caal_2_conv[
# __________________________________________________________________________________________________
# conv2_block1_split1_caal_2_relu (None, 16, 16, 4)    0           conv2_block1_split1_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split2_caal_2_relu (None, 16, 16, 4)    0           conv2_block1_split2_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split3_caal_2_relu (None, 16, 16, 4)    0           conv2_block1_split3_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split4_caal_2_relu (None, 16, 16, 4)    0           conv2_block1_split4_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split5_caal_2_relu (None, 16, 16, 4)    0           conv2_block1_split5_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split6_caal_2_relu (None, 16, 16, 4)    0           conv2_block1_split6_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split7_caal_2_relu (None, 16, 16, 4)    0           conv2_block1_split7_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split8_caal_2_relu (None, 16, 16, 4)    0           conv2_block1_split8_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split9_caal_2_relu (None, 16, 16, 4)    0           conv2_block1_split9_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv2_block1_split10_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split10_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split11_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split11_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split12_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split12_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split13_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split13_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split14_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split14_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split15_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split15_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split16_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split16_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split17_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split17_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split18_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split18_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split19_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split19_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split20_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split20_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split21_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split21_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split22_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split22_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split23_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split23_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split24_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split24_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split25_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split25_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split26_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split26_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split27_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split27_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split28_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split28_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split29_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split29_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split30_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split30_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split31_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split31_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv2_block1_split32_caal_2_rel (None, 16, 16, 4)    0           conv2_block1_split32_caal_2_bn[0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 16, 16, 128)  0           conv2_block1_split1_caal_2_relu[0
#                                                                  conv2_block1_split2_caal_2_relu[0
#                                                                  conv2_block1_split3_caal_2_relu[0
#                                                                  conv2_block1_split4_caal_2_relu[0
#                                                                  conv2_block1_split5_caal_2_relu[0
#                                                                  conv2_block1_split6_caal_2_relu[0
#                                                                  conv2_block1_split7_caal_2_relu[0
#                                                                  conv2_block1_split8_caal_2_relu[0
#                                                                  conv2_block1_split9_caal_2_relu[0
#                                                                  conv2_block1_split10_caal_2_relu[
#                                                                  conv2_block1_split11_caal_2_relu[
#                                                                  conv2_block1_split12_caal_2_relu[
#                                                                  conv2_block1_split13_caal_2_relu[
#                                                                  conv2_block1_split14_caal_2_relu[
#                                                                  conv2_block1_split15_caal_2_relu[
#                                                                  conv2_block1_split16_caal_2_relu[
#                                                                  conv2_block1_split17_caal_2_relu[
#                                                                  conv2_block1_split18_caal_2_relu[
#                                                                  conv2_block1_split19_caal_2_relu[
#                                                                  conv2_block1_split20_caal_2_relu[
#                                                                  conv2_block1_split21_caal_2_relu[
#                                                                  conv2_block1_split22_caal_2_relu[
#                                                                  conv2_block1_split23_caal_2_relu[
#                                                                  conv2_block1_split24_caal_2_relu[
#                                                                  conv2_block1_split25_caal_2_relu[
#                                                                  conv2_block1_split26_caal_2_relu[
#                                                                  conv2_block1_split27_caal_2_relu[
#                                                                  conv2_block1_split28_caal_2_relu[
#                                                                  conv2_block1_split29_caal_2_relu[
#                                                                  conv2_block1_split30_caal_2_relu[
#                                                                  conv2_block1_split31_caal_2_relu[
#                                                                  conv2_block1_split32_caal_2_relu[
# __________________________________________________________________________________________________
# conv2_block1_skip_conv (Conv2D) (None, 16, 16, 256)  16640       conv2_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1transition_conv (Co (None, 16, 16, 256)  33024       tf.concat[0][0]
# __________________________________________________________________________________________________
# conv2_block1skip_bn (BatchNorma (None, 16, 16, 256)  1024        conv2_block1_skip_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_bn (BatchNormaliza (None, 16, 16, 256)  1024        conv2_block1transition_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 16, 16, 256)  0           conv2_block1skip_bn[0][0]
#                                                                  conv2_block1_bn[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu (TFOpLambda)         (None, 16, 16, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split1_caal_1_conv (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split2_caal_1_conv (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split3_caal_1_conv (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split4_caal_1_conv (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split5_caal_1_conv (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split6_caal_1_conv (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split7_caal_1_conv (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split8_caal_1_conv (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split9_caal_1_conv (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split10_caal_1_con (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split11_caal_1_con (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split12_caal_1_con (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split13_caal_1_con (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split14_caal_1_con (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split15_caal_1_con (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split16_caal_1_con (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split17_caal_1_con (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split18_caal_1_con (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split19_caal_1_con (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split20_caal_1_con (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_split21_caal_1_con (None, 16, 16, 4)    1028        tf.nn.relu[0][0]
# ...
# __________________________________________________________________________________________________
# conv5_block3_split9_caal_2_bn ( (None, 2, 2, 32)     128         conv5_block3_split9_caal_2_conv[0
# __________________________________________________________________________________________________
# conv5_block3_split10_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split10_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split11_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split11_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split12_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split12_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split13_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split13_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split14_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split14_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split15_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split15_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split16_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split16_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split17_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split17_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split18_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split18_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split19_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split19_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split20_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split20_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split21_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split21_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split22_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split22_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split23_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split23_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split24_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split24_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split25_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split25_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split26_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split26_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split27_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split27_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split28_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split28_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split29_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split29_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split30_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split30_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split31_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split31_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split32_caal_2_bn  (None, 2, 2, 32)     128         conv5_block3_split32_caal_2_conv[
# __________________________________________________________________________________________________
# conv5_block3_split1_caal_2_relu (None, 2, 2, 32)     0           conv5_block3_split1_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv5_block3_split2_caal_2_relu (None, 2, 2, 32)     0           conv5_block3_split2_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv5_block3_split3_caal_2_relu (None, 2, 2, 32)     0           conv5_block3_split3_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv5_block3_split4_caal_2_relu (None, 2, 2, 32)     0           conv5_block3_split4_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv5_block3_split5_caal_2_relu (None, 2, 2, 32)     0           conv5_block3_split5_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv5_block3_split6_caal_2_relu (None, 2, 2, 32)     0           conv5_block3_split6_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv5_block3_split7_caal_2_relu (None, 2, 2, 32)     0           conv5_block3_split7_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv5_block3_split8_caal_2_relu (None, 2, 2, 32)     0           conv5_block3_split8_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv5_block3_split9_caal_2_relu (None, 2, 2, 32)     0           conv5_block3_split9_caal_2_bn[0][
# __________________________________________________________________________________________________
# conv5_block3_split10_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split10_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split11_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split11_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split12_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split12_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split13_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split13_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split14_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split14_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split15_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split15_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split16_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split16_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split17_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split17_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split18_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split18_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split19_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split19_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split20_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split20_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split21_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split21_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split22_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split22_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split23_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split23_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split24_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split24_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split25_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split25_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split26_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split26_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split27_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split27_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split28_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split28_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split29_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split29_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split30_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split30_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split31_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split31_caal_2_bn[0]
# __________________________________________________________________________________________________
# conv5_block3_split32_caal_2_rel (None, 2, 2, 32)     0           conv5_block3_split32_caal_2_bn[0]
# __________________________________________________________________________________________________
# tf.concat_15 (TFOpLambda)       (None, 2, 2, 1024)   0           conv5_block3_split1_caal_2_relu[0
#                                                                  conv5_block3_split2_caal_2_relu[0
#                                                                  conv5_block3_split3_caal_2_relu[0
#                                                                  conv5_block3_split4_caal_2_relu[0
#                                                                  conv5_block3_split5_caal_2_relu[0
#                                                                  conv5_block3_split6_caal_2_relu[0
#                                                                  conv5_block3_split7_caal_2_relu[0
#                                                                  conv5_block3_split8_caal_2_relu[0
#                                                                  conv5_block3_split9_caal_2_relu[0
#                                                                  conv5_block3_split10_caal_2_relu[
#                                                                  conv5_block3_split11_caal_2_relu[
#                                                                  conv5_block3_split12_caal_2_relu[
#                                                                  conv5_block3_split13_caal_2_relu[
#                                                                  conv5_block3_split14_caal_2_relu[
#                                                                  conv5_block3_split15_caal_2_relu[
#                                                                  conv5_block3_split16_caal_2_relu[
#                                                                  conv5_block3_split17_caal_2_relu[
#                                                                  conv5_block3_split18_caal_2_relu[
#                                                                  conv5_block3_split19_caal_2_relu[
#                                                                  conv5_block3_split20_caal_2_relu[
#                                                                  conv5_block3_split21_caal_2_relu[
#                                                                  conv5_block3_split22_caal_2_relu[
#                                                                  conv5_block3_split23_caal_2_relu[
#                                                                  conv5_block3_split24_caal_2_relu[
#                                                                  conv5_block3_split25_caal_2_relu[
#                                                                  conv5_block3_split26_caal_2_relu[
#                                                                  conv5_block3_split27_caal_2_relu[
#                                                                  conv5_block3_split28_caal_2_relu[
#                                                                  conv5_block3_split29_caal_2_relu[
#                                                                  conv5_block3_split30_caal_2_relu[
#                                                                  conv5_block3_split31_caal_2_relu[
#                                                                  conv5_block3_split32_caal_2_relu[
# __________________________________________________________________________________________________
# conv5_block3transition_conv (Co (None, 2, 2, 2048)   2099200     tf.concat_15[0][0]
# __________________________________________________________________________________________________
# conv5_block3_bn (BatchNormaliza (None, 2, 2, 2048)   8192        conv5_block3transition_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 2, 2, 2048)   0           tf.nn.relu_14[0][0]
#                                                                  conv5_block3_bn[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_15 (TFOpLambda)      (None, 2, 2, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# pool_out (GlobalAveragePooling2 (None, 2048)         0           tf.nn.relu_15[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 200)          409800      pool_out[0][0]
# ==================================================================================================
# Total params: 23,492,040
# Trainable params: 23,423,816
# Non-trainable params: 68,224
# __________________________________________________________________________________________________

# %%
hist_ResNeXt_50= tinyImageNet_ResNeXt_train(ResNeXt_50,
                          './models/tinyImageNet/ResNeXt_50_best.hdf5', #path for weights of best model
                          X_train,y_train,
                          X_val,
                          y_val,
                          data_aug=False, #no data aug
                          learning_rate=0.6, #starting learning rate
                          steps=20, #number of epochs between learning rate modification (* 0.1)
                          epochs=60,
                          batch_size=128,
                          es_patience=20) #early stopping
# Out:
# Epoch 1/60
# steps before lr change:  20
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.6000000238418579.
